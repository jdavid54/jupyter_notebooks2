# %%
import pandas as pd

pdframe = pd.read_csv(r"C:\Users\jeand\Documents\devise_parity.csv")

# %%
pdframe.head()
# Out:
#         Libellé            Monnaie    Dernier     Var
# 0   Afghanistan        Afghani-AFN    75.0804  -0.02%
# 1  AfriqueduSud           Rand-ZAR    19.0317  -0.39%
# 2       Albanie            Lek-ALL    93.6096  -0.64%
# 3       Algérie  DinarAlgérien-DZD   152.5050  +0.02%
# 4        Angola         Kwanza-AOA  1050.7253  -0.36%

# %%
pdframe.tail()
# Out:
#        Libellé            Monnaie      Dernier     Var
# 154    Vanuatu           Vatu-VUV     137.3039  +0.17%
# 155  Vénézuela  BolívarFuerté-VEF  284299.4038   0.00%
# 156    ViêtNam           Dong-VND   30124.3702  -0.18%
# 157      Yémen    RialDuYémen-YER     273.1603  -0.02%
# 158     Zambie         Kwacha-ZMK    6773.5272   0.00%

# %%
pdframe[pdframe['Libellé'] == 'Iran']
# Out:
#    Libellé   Monnaie       Dernier     Var
# 68    Iran  Rial-IRR  1.576419e+06  -0.02%

# %%
pdframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Libellé  159 non-null    object
#  1   Monnaie  159 non-null    object
#  2   Dernier  159 non-null    float64
#  3   Var      159 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.1+ KB

# %%
pdframe['Dernier'] = pd.to_numeric(pdframe['Dernier'], errors='coerce')
pdframe_sorted = pdframe.sort_values('Dernier', ascending=True)
pdframe_sorted = pdframe_sorted.reset_index(drop=True)
pdframe_sorted.head(10)
# Out:
#        Libellé              Monnaie  Dernier     Var
# 0      Bitcoin          Bitcoin-BTC   0.0000  -1.17%
# 1     Ethereum         Ethereum-ETH   0.0006  -1.12%
# 2       Solana           Solana-SOL   0.0155  -1.31%
# 3     Litecoin         Litecoin-LTC   0.0254  -0.99%
# 4       Koweït            Dinar-KWD   0.3559  +0.01%
# 5      Bahreïn   DinarDuBahreïn-BHD   0.4322  +0.06%
# 6         Oman  RialD&apos;Oman-OMR   0.4414  -0.14%
# 7     Jordanie   DinarJordanien-JOD   0.8127   0.00%
# 8   UnitéduFMI              DTS-XDR   0.8455  -0.02%
# 9  Royaume-Uni    LivreSterling-GBP   0.8569  -0.10%

# %%
pdframe_sorted.tail(20)
# Out:
#                            Libellé                     Monnaie       Dernier  \
# 139  RépubliquedémocratiqueduCongo          FrancCongolais-CDF  3.016427e+03
# 140                       Tanzanie      ShillingDeTanzanie-TZS  3.034789e+03
# 141                        Burundi          FrancDuBurundi-BIF  3.403498e+03
# 142                       Colombie          PesoDeColombie-COP  3.670180e+03
# 143                       Mongolie                  Tugrik-MNT  4.121963e+03
# 144                        Ouganda  ShillingD&apos;Ouganda-UGX  4.283136e+03
# 145                       Cambodge                    Riel-KHR  4.612566e+03
# 146                     Madagascar                  Ariary-MGA  4.941831e+03
# 147                         Zambie                  Kwacha-ZMK  6.773527e+03
# 148                       Paraguay                 Guarani-PYG  6.840914e+03
# 149                         Guinée           FrancDeGuinée-GNF  1.004236e+04
# 150                    Ouzbékistan                     Sum-UZS  1.377786e+04
# 151                    SierraLeone                   Leone-SLL  1.423708e+04
# 152                      Indonésie  RoupieD&apos;Indonésie-IDR  2.074106e+04
# 153            SaoTomé-et-Principe                   Dobra-STD  2.432817e+04
# 154                           Laos                     Kip-LAK  2.594265e+04
# 155                        ViêtNam                    Dong-VND  3.012437e+04
# 156                          Liban            LivreDuLiban-LBP  1.020455e+05
# 157                      Vénézuela           BolívarFuerté-VEF  2.842994e+05
# 158                           Iran                    Rial-IRR  1.576419e+06
#
#         Var
# 139   0.00%
# 140  +0.46%
# 141  -0.46%
# 142  -0.03%
# 143  -0.02%
# 144  +0.04%
# 145  -0.46%
# 146  -0.20%
# 147   0.00%
# 148  -0.63%
# 149  -0.12%
# 150  -0.14%
# 151   0.00%
# 152  +0.10%
# 153   0.00%
# 154  -0.16%
# 155  -0.18%
# 156  -0.54%
# 157   0.00%
# 158  -0.02%

# %%
import matplotlib.pyplot as plt
n = 10
pdframe_sorted.tail(n).plot(x='Libellé', y='Dernier', figsize=(12, 6), logy=True,
                             title='Currency Exchange Rates (Sorted)', kind='bar', legend=False)
plt.xticks(rotation=90, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %%
subset = pdframe_sorted.tail(n)
subset
# Out:
#                  Libellé                     Monnaie       Dernier     Var
# 149               Guinée           FrancDeGuinée-GNF  1.004236e+04  -0.12%
# 150          Ouzbékistan                     Sum-UZS  1.377786e+04  -0.14%
# 151          SierraLeone                   Leone-SLL  1.423708e+04   0.00%
# 152            Indonésie  RoupieD&apos;Indonésie-IDR  2.074106e+04  +0.10%
# 153  SaoTomé-et-Principe                   Dobra-STD  2.432817e+04   0.00%
# 154                 Laos                     Kip-LAK  2.594265e+04  -0.16%
# 155              ViêtNam                    Dong-VND  3.012437e+04  -0.18%
# 156                Liban            LivreDuLiban-LBP  1.020455e+05  -0.54%
# 157            Vénézuela           BolívarFuerté-VEF  2.842994e+05   0.00%
# 158                 Iran                    Rial-IRR  1.576419e+06  -0.02%

# %%
plt.figure(figsize=(12, 6))
plt.barh(subset['Libellé'], subset['Dernier'], color='steelblue')
plt.xlabel('Dernier')
plt.ylabel('Libellé')
plt.title('Currency Exchange Rates (Sorted)')
plt.tight_layout()
plt.show()
