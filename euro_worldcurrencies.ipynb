# %%
import pandas as pd

pdframe = pd.read_csv(r"C:\Users\jeand\Documents\devise_parity.csv")

# %%
pdframe.head()
# Out:
#         Libellé            Monnaie    Dernier     Var
# 0   Afghanistan        Afghani-AFN    72.5890  -0.17%
# 1  AfriqueduSud           Rand-ZAR    18.8313  -0.27%
# 2       Albanie            Lek-ALL    94.4349  +0.07%
# 3       Algérie  DinarAlgérien-DZD   153.6935  +0.09%
# 4        Angola         Kwanza-AOA  1055.9581  +0.11%

# %%
pdframe.tail()
# Out:
#        Libellé            Monnaie      Dernier     Var
# 154    Vanuatu           Vatu-VUV     136.8499  +0.39%
# 155  Vénézuela  BolívarFuerté-VEF  284299.4038   0.00%
# 156    ViêtNam           Dong-VND   30326.0750  +0.14%
# 157      Yémen    RialDuYémen-YER     274.9453  +0.15%
# 158     Zambie         Kwacha-ZMK    6773.5272   0.00%

# %%
pdframe[pdframe['Libellé'] == 'Iran']
# Out:
#    Libellé   Monnaie       Dernier     Var
# 68    Iran  Rial-IRR  1.584322e+06  +0.15%

# %%
pdframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Libellé  159 non-null    object
#  1   Monnaie  159 non-null    object
#  2   Dernier  159 non-null    float64
#  3   Var      159 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.1+ KB

# %%
pdframe['Dernier'] = pd.to_numeric(pdframe['Dernier'], errors='coerce')
pdframe_sorted = pdframe.sort_values('Dernier', ascending=True)
pdframe_sorted = pdframe_sorted.reset_index(drop=True)
pdframe_sorted.head(10)
# Out:
#       Libellé               Monnaie  Dernier     Var
# 0     Bitcoin           Bitcoin-BTC   0.0000  +0.44%
# 1    Ethereum          Ethereum-ETH   0.0007  +0.36%
# 2      Solana            Solana-SOL   0.0162  +0.57%
# 3    Litecoin          Litecoin-LTC   0.0260  +1.02%
# 4      Koweït             Dinar-KWD   0.3548  +0.27%
# 5     Bahreïn    DinarDuBahreïn-BHD   0.4345  +0.17%
# 6        Oman   RialD&apos;Oman-OMR   0.4436  +0.18%
# 7    Jordanie    DinarJordanien-JOD   0.8169  +0.16%
# 8  UnitéduFMI               DTS-XDR   0.8431  +0.15%
# 9   Gibraltar  LivreDeGibraltar-GIP   0.8650  -0.10%

# %%
pdframe_sorted.tail(20)
# Out:
#                            Libellé                     Monnaie       Dernier  \
# 139  RépubliquedémocratiqueduCongo          FrancCongolais-CDF  3.016427e+03
# 140                       Tanzanie      ShillingDeTanzanie-TZS  3.021892e+03
# 141                        Burundi          FrancDuBurundi-BIF  3.445710e+03
# 142                       Colombie          PesoDeColombie-COP  3.986617e+03
# 143                       Mongolie                  Tugrik-MNT  4.123747e+03
# 144                        Ouganda  ShillingD&apos;Ouganda-UGX  4.210629e+03
# 145                       Cambodge                    Riel-KHR  4.626112e+03
# 146                     Madagascar                  Ariary-MGA  4.831609e+03
# 147                         Zambie                  Kwacha-ZMK  6.773527e+03
# 148                       Paraguay                 Guarani-PYG  7.050482e+03
# 149                         Guinée           FrancDeGuinée-GNF  1.009576e+04
# 150                    Ouzbékistan                     Sum-UZS  1.388639e+04
# 151                    SierraLeone                   Leone-SLL  1.423708e+04
# 152                      Indonésie  RoupieD&apos;Indonésie-IDR  2.054615e+04
# 153            SaoTomé-et-Principe                   Dobra-STD  2.432817e+04
# 154                           Laos                     Kip-LAK  2.538844e+04
# 155                        ViêtNam                    Dong-VND  3.032608e+04
# 156                          Liban            LivreDuLiban-LBP  1.041175e+05
# 157                      Vénézuela           BolívarFuerté-VEF  2.842994e+05
# 158                           Iran                    Rial-IRR  1.584322e+06
#
#         Var
# 139   0.00%
# 140  -0.04%
# 141  +0.35%
# 142  +0.14%
# 143  +0.15%
# 144  +0.31%
# 145   0.00%
# 146  +0.15%
# 147   0.00%
# 148  +0.15%
# 149  +0.15%
# 150  +0.15%
# 151   0.00%
# 152  -0.16%
# 153   0.00%
# 154  +0.15%
# 155  +0.14%
# 156  +0.99%
# 157   0.00%
# 158  +0.15%

# %%
import matplotlib.pyplot as plt

pdframe_sorted.tail(50).plot(x='Libellé', y='Dernier', figsize=(12, 6), logy=True,
                             title='Currency Exchange Rates (Sorted)', kind='bar', legend=False)
plt.xticks(rotation=90, ha='right', fontsize=8)
plt.tight_layout()
plt.show()
