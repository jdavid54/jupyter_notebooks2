# %%
import pandas as pd

pdframe = pd.read_csv(r"C:\Users\jeand\Documents\devise_parity.csv")

# %%
pdframe.head()
# Out:
#         Libellé            Monnaie    Dernier     Var
# 0   Afghanistan        Afghani-AFN    75.9065  -0.08%
# 1  AfriqueduSud           Rand-ZAR    18.8324  -0.21%
# 2       Albanie            Lek-ALL    93.2233  +0.05%
# 3       Algérie  DinarAlgérien-DZD   153.5265  +0.07%
# 4        Angola         Kwanza-AOA  1058.2112  -0.28%

# %%
pdframe.tail()
# Out:
#        Libellé            Monnaie      Dernier     Var
# 154    Vanuatu           Vatu-VUV     137.4538  -0.15%
# 155  Vénézuela  BolívarFuerté-VEF  284299.4038   0.00%
# 156    ViêtNam           Dong-VND   30317.7101  -0.12%
# 157      Yémen    RialDuYémen-YER     274.3189  -0.08%
# 158     Zambie         Kwacha-ZMK    6773.5272   0.00%

# %%
pdframe[pdframe['Libellé'] == 'Iran']
# Out:
#    Libellé   Monnaie       Dernier     Var
# 68    Iran  Rial-IRR  1.586998e+06  -0.08%

# %%
pdframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Libellé  159 non-null    object
#  1   Monnaie  159 non-null    object
#  2   Dernier  159 non-null    float64
#  3   Var      159 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.1+ KB

# %%
pdframe['Dernier'] = pd.to_numeric(pdframe['Dernier'], errors='coerce')
pdframe_sorted = pdframe.sort_values('Dernier', ascending=True)
pdframe_sorted = pdframe_sorted.reset_index(drop=True)
pdframe_sorted.head(10)
# Out:
#        Libellé              Monnaie  Dernier     Var
# 0      Bitcoin          Bitcoin-BTC   0.0000  +0.09%
# 1     Ethereum         Ethereum-ETH   0.0006  +0.02%
# 2       Solana           Solana-SOL   0.0157  +0.88%
# 3     Litecoin         Litecoin-LTC   0.0257  -0.22%
# 4       Koweït            Dinar-KWD   0.3566  -0.13%
# 5      Bahreïn   DinarDuBahreïn-BHD   0.4353  -0.09%
# 6         Oman  RialD&apos;Oman-OMR   0.4445  -0.08%
# 7     Jordanie   DinarJordanien-JOD   0.8185  -0.06%
# 8   UnitéduFMI              DTS-XDR   0.8448  -0.08%
# 9  Royaume-Uni    LivreSterling-GBP   0.8572  -0.09%

# %%
pdframe_sorted.tail(20)
# Out:
#                            Libellé                     Monnaie       Dernier  \
# 139  RépubliquedémocratiqueduCongo          FrancCongolais-CDF  3.016427e+03
# 140                       Tanzanie      ShillingDeTanzanie-TZS  3.059282e+03
# 141                        Burundi          FrancDuBurundi-BIF  3.450060e+03
# 142                       Colombie          PesoDeColombie-COP  3.673222e+03
# 143                       Mongolie                  Tugrik-MNT  4.152621e+03
# 144                        Ouganda  ShillingD&apos;Ouganda-UGX  4.300072e+03
# 145                       Cambodge                    Riel-KHR  4.682525e+03
# 146                     Madagascar                  Ariary-MGA  4.962428e+03
# 147                         Zambie                  Kwacha-ZMK  6.773527e+03
# 148                       Paraguay                 Guarani-PYG  6.865462e+03
# 149                         Guinée           FrancDeGuinée-GNF  1.013675e+04
# 150                    Ouzbékistan                     Sum-UZS  1.375745e+04
# 151                    SierraLeone                   Leone-SLL  1.423708e+04
# 152                      Indonésie  RoupieD&apos;Indonésie-IDR  2.065689e+04
# 153            SaoTomé-et-Principe                   Dobra-STD  2.432817e+04
# 154                           Laos                     Kip-LAK  2.607882e+04
# 155                        ViêtNam                    Dong-VND  3.031771e+04
# 156                          Liban            LivreDuLiban-LBP  1.034085e+05
# 157                      Vénézuela           BolívarFuerté-VEF  2.842994e+05
# 158                           Iran                    Rial-IRR  1.586998e+06
#
#         Var
# 139   0.00%
# 140  -0.08%
# 141  -0.13%
# 142  -0.09%
# 143  -0.08%
# 144  -0.23%
# 145   0.00%
# 146  -0.19%
# 147   0.00%
# 148  -0.31%
# 149  -0.10%
# 150  +0.16%
# 151   0.00%
# 152  -0.02%
# 153   0.00%
# 154  -0.14%
# 155  -0.12%
# 156  -0.09%
# 157   0.00%
# 158  -0.08%

# %%
import matplotlib.pyplot as plt
n = 10
pdframe_sorted.tail(n).plot(x='Libellé', y='Dernier', figsize=(12, 6), logy=True,
                             title='Currency Exchange Rates (Sorted)', kind='bar', legend=False)
plt.xticks(rotation=90, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %%
subset = pdframe_sorted.tail(n)
subset
# Out:
#                  Libellé                     Monnaie       Dernier     Var
# 149               Guinée           FrancDeGuinée-GNF  1.013675e+04  -0.10%
# 150          Ouzbékistan                     Sum-UZS  1.375745e+04  +0.16%
# 151          SierraLeone                   Leone-SLL  1.423708e+04   0.00%
# 152            Indonésie  RoupieD&apos;Indonésie-IDR  2.065689e+04  -0.02%
# 153  SaoTomé-et-Principe                   Dobra-STD  2.432817e+04   0.00%
# 154                 Laos                     Kip-LAK  2.607882e+04  -0.14%
# 155              ViêtNam                    Dong-VND  3.031771e+04  -0.12%
# 156                Liban            LivreDuLiban-LBP  1.034085e+05  -0.09%
# 157            Vénézuela           BolívarFuerté-VEF  2.842994e+05   0.00%
# 158                 Iran                    Rial-IRR  1.586998e+06  -0.08%

# %%
plt.figure(figsize=(12, 6))
plt.barh(subset['Libellé'], subset['Dernier'], color='steelblue')
plt.xlabel('Dernier')
plt.ylabel('Libellé')
plt.title('Currency Exchange Rates (Sorted)')
plt.tight_layout()
plt.show()
