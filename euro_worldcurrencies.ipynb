# %%
import pandas as pd

pdframe = pd.read_csv(r"C:\Users\jeand\Documents\devise_parity.csv")

# %%
pdframe.head()
# Out:
#         Libellé            Monnaie    Dernier     Var
# 0   Afghanistan        Afghani-AFN    76.3673  -0.05%
# 1  AfriqueduSud           Rand-ZAR    18.6747  -0.08%
# 2       Albanie            Lek-ALL    92.5033  -0.05%
# 3       Algérie  DinarAlgérien-DZD   155.1460  -0.03%
# 4        Angola         Kwanza-AOA  1068.3534  -0.25%

# %%
pdframe.tail()
# Out:
#        Libellé            Monnaie      Dernier     Var
# 154    Vanuatu           Vatu-VUV     137.9257  -0.10%
# 155  Vénézuela  BolívarFuerté-VEF  284299.4038   0.00%
# 156    ViêtNam           Dong-VND   30438.9653  -0.29%
# 157      Yémen    RialDuYémen-YER     276.4312  -0.03%
# 158     Zambie         Kwacha-ZMK    6773.5272   0.00%

# %%
pdframe[pdframe['Libellé'] == 'Iran']
# Out:
#    Libellé   Monnaie       Dernier     Var
# 68    Iran  Rial-IRR  1.602629e+06  -0.03%

# %%
pdframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Libellé  159 non-null    object
#  1   Monnaie  159 non-null    object
#  2   Dernier  159 non-null    float64
#  3   Var      159 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 5.1+ KB

# %%
pdframe['Dernier'] = pd.to_numeric(pdframe['Dernier'], errors='coerce')
pdframe_sorted = pdframe.sort_values('Dernier', ascending=True)
pdframe_sorted = pdframe_sorted.reset_index(drop=True)
pdframe_sorted.head(10)
# Out:
#       Libellé              Monnaie  Dernier     Var
# 0     Bitcoin          Bitcoin-BTC   0.0000  -1.35%
# 1    Ethereum         Ethereum-ETH   0.0005  -0.30%
# 2      Solana           Solana-SOL   0.0116  -3.12%
# 3    Litecoin         Litecoin-LTC   0.0225  -0.10%
# 4      Koweït            Dinar-KWD   0.3600  +0.13%
# 5     Bahreïn   DinarDuBahreïn-BHD   0.4396  -0.06%
# 6        Oman  RialD&apos;Oman-OMR   0.4483  -0.18%
# 7      Ripple           Ripple-XRP   0.7807  -0.91%
# 8    Jordanie   DinarJordanien-JOD   0.8266  -0.04%
# 9  UnitéduFMI              DTS-XDR   0.8496  -0.04%

# %%
pdframe_sorted.tail(20)
# Out:
#                            Libellé                     Monnaie       Dernier  \
# 139  RépubliquedémocratiqueduCongo          FrancCongolais-CDF  3.016427e+03
# 140                       Tanzanie      ShillingDeTanzanie-TZS  3.089600e+03
# 141                        Burundi          FrancDuBurundi-BIF  3.476183e+03
# 142                       Colombie          PesoDeColombie-COP  3.566265e+03
# 143                       Mongolie                  Tugrik-MNT  4.194940e+03
# 144                        Ouganda  ShillingD&apos;Ouganda-UGX  4.350243e+03
# 145                       Cambodge                    Riel-KHR  4.717271e+03
# 146                     Madagascar                  Ariary-MGA  5.017961e+03
# 147                         Zambie                  Kwacha-ZMK  6.773527e+03
# 148                       Paraguay                 Guarani-PYG  7.004504e+03
# 149                         Guinée           FrancDeGuinée-GNF  1.024089e+04
# 150                    Ouzbékistan                     Sum-UZS  1.374974e+04
# 151                    SierraLeone                   Leone-SLL  1.423708e+04
# 152                      Indonésie  RoupieD&apos;Indonésie-IDR  2.066282e+04
# 153            SaoTomé-et-Principe                   Dobra-STD  2.432817e+04
# 154                           Laos                     Kip-LAK  2.618418e+04
# 155                        ViêtNam                    Dong-VND  3.043897e+04
# 156                          Liban            LivreDuLiban-LBP  1.044300e+05
# 157                      Vénézuela           BolívarFuerté-VEF  2.842994e+05
# 158                           Iran                    Rial-IRR  1.602629e+06
#
#         Var
# 139   0.00%
# 140  -0.03%
# 141  -0.36%
# 142  -0.30%
# 143  -0.03%
# 144  +0.13%
# 145  -0.02%
# 146  -0.56%
# 147   0.00%
# 148  -0.07%
# 149  +0.02%
# 150  -0.28%
# 151   0.00%
# 152  -0.04%
# 153   0.00%
# 154  -0.03%
# 155  -0.29%
# 156   0.00%
# 157   0.00%
# 158  -0.03%

# %%
import matplotlib.pyplot as plt
n = 20
pdframe_sorted.tail(n).plot(x='Libellé', y='Dernier', figsize=(12, 6), logy=True,
                             title='Currency Exchange Rates (Sorted)', kind='bar', legend=False)
plt.xticks(rotation=90, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %%
subset = pdframe_sorted.tail(n)
subset
# Out:
#                            Libellé                     Monnaie       Dernier  \
# 139  RépubliquedémocratiqueduCongo          FrancCongolais-CDF  3.016427e+03
# 140                       Tanzanie      ShillingDeTanzanie-TZS  3.089600e+03
# 141                        Burundi          FrancDuBurundi-BIF  3.476183e+03
# 142                       Colombie          PesoDeColombie-COP  3.566265e+03
# 143                       Mongolie                  Tugrik-MNT  4.194940e+03
# 144                        Ouganda  ShillingD&apos;Ouganda-UGX  4.350243e+03
# 145                       Cambodge                    Riel-KHR  4.717271e+03
# 146                     Madagascar                  Ariary-MGA  5.017961e+03
# 147                         Zambie                  Kwacha-ZMK  6.773527e+03
# 148                       Paraguay                 Guarani-PYG  7.004504e+03
# 149                         Guinée           FrancDeGuinée-GNF  1.024089e+04
# 150                    Ouzbékistan                     Sum-UZS  1.374974e+04
# 151                    SierraLeone                   Leone-SLL  1.423708e+04
# 152                      Indonésie  RoupieD&apos;Indonésie-IDR  2.066282e+04
# 153            SaoTomé-et-Principe                   Dobra-STD  2.432817e+04
# 154                           Laos                     Kip-LAK  2.618418e+04
# 155                        ViêtNam                    Dong-VND  3.043897e+04
# 156                          Liban            LivreDuLiban-LBP  1.044300e+05
# 157                      Vénézuela           BolívarFuerté-VEF  2.842994e+05
# 158                           Iran                    Rial-IRR  1.602629e+06
#
#         Var
# 139   0.00%
# 140  -0.03%
# 141  -0.36%
# 142  -0.30%
# 143  -0.03%
# 144  +0.13%
# 145  -0.02%
# 146  -0.56%
# 147   0.00%
# 148  -0.07%
# 149  +0.02%
# 150  -0.28%
# 151   0.00%
# 152  -0.04%
# 153   0.00%
# 154  -0.03%
# 155  -0.29%
# 156   0.00%
# 157   0.00%
# 158  -0.03%

# %%
plt.figure(figsize=(12, 6))
plt.barh(subset['Libellé'], subset['Dernier'], color='steelblue')
plt.xlabel('Dernier')
plt.ylabel('Libellé')
plt.title('Currency Exchange Rates (Sorted)')
plt.tight_layout()
plt.show()
