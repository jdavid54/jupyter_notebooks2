# %% [markdown]
# # Celsius and Fahrenheit conversion
#
# Use the reusable `temperature_conversion` module to convert temperatures.

# %%
#from temperature_conversion import celsius_to_fahrenheit, fahrenheit_to_celsius

# %%
"""Utilities for converting temperatures between Celsius and Fahrenheit."""


def celsius_to_fahrenheit(celsius: float) -> float:
    """Convert a Celsius temperature to Fahrenheit."""
    return (celsius * 9 / 5) + 32


def fahrenheit_to_celsius(fahrenheit: float) -> float:
    """Convert a Fahrenheit temperature to Celsius."""
    return (fahrenheit - 32) * 5 / 9


#print(celsius_to_fahrenheit(32))

# %%
celsius = 25
fahrenheit = celsius_to_fahrenheit(celsius)
print(f"{celsius}°C = {fahrenheit}°F")
# Out:
# 25°C = 77.0°F

# %%
fahrenheit = 77
celsius = fahrenheit_to_celsius(fahrenheit)
print(f"{fahrenheit}°F = {celsius}°C")
# Out:
# 77°F = 25.0°C

# %%
for t in range(-20, 51, 10):
    fahrenheit = celsius_to_fahrenheit(t)
    print(f"{t}°C = {fahrenheit}°F")
# Out:
# -20°C = -4.0°F
# -10°C = 14.0°F
# 0°C = 32.0°F
# 10°C = 50.0°F
# 20°C = 68.0°F
# 30°C = 86.0°F
# 40°C = 104.0°F
# 50°C = 122.0°F

# %%
import matplotlib.pyplot as plt

# %%
# celsius = []
# c=[]
time=[t for t in range(-4, 130, 10)]
celsius = list(map(fahrenheit_to_celsius, time))
c = list(map(lambda t: (t-32)*0.5, time))
'''
for t in time:
    celsius.append(fahrenheit_to_celsius(t))
    c.append((t-32)*0.5)
    #print(f"{t}°F = {celsius[-1]:<6.2f}°C = {c:<6.2f}°C")  
'''
plt.plot(time, celsius, 'ro', label='Celsius')#, label=f"{t}°F = {celsius[-1]:.2f}°C")  
plt.plot(time, c, 'bo', label='Approximate Celsius')#, label=f"{t}°F = {c:.2f}°C") 
plt.legend()
