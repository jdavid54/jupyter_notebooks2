# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Determine the direction and extent of the shadow
    if phase <= 0.5:
        # Waxing crescent to first quarter to waxing gibbous
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
        ax.add_artist(shadow)
        clip_path = plt.Circle((0.5 + 0.4 * (1 - phase * 2), 0.5), 0.4, transform=ax.transData)
    else:
        # Waning gibbous to last quarter to waning crescent
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
        ax.add_artist(shadow)
        clip_path = plt.Circle((0.5 - 0.4 * ((phase - 0.5) * 2), 0.5), 0.4, transform=ax.transData)
    
    shadow.set_clip_path(clip_path)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.25)  # Quarter moon
draw_moon_phase(0.75)  # Three quarters moon

# %%
draw_moon_phase(0.1)

# %%
import matplotlib.pyplot as plt

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Determine the radius of the shadow circle
    if phase <= 0.5:
        # Waxing crescent to first quarter to waxing gibbous
        shadow_radius = 0.4 * (1 - 2 * phase)
    else:
        # Waning gibbous to last quarter to waning crescent
        shadow_radius = 0.4 * (2 * phase - 1)
    
    # Draw the shadow
    if phase != 1:
        if phase <= 0.5:
            shadow = plt.Circle((0.5 + 0.4 * (1 - phase * 2), 0.5), shadow_radius, color='black', ec='black', lw=2)
        else:
            shadow = plt.Circle((0.5 - 0.4 * ((phase - 0.5) * 2), 0.5), shadow_radius, color='black', ec='black', lw=2)
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Determine the radius and position of the shadow circle
    if phase == 0:
        # New moon: Shadow circle overlaps the moon
        shadow_radius = 0.4
        shadow = plt.Circle((0.5, 0.5), shadow_radius, color='black', ec='black', lw=2)
    else:
        if phase <= 0.5:
            # Waxing crescent to first quarter to waxing gibbous
            shadow_radius = 0.4 * (1 - 2 * phase)
            shadow = plt.Circle((0.5, 0.5), shadow_radius, color='black', ec='black', lw=2)
        else:
            # Waning gibbous to last quarter to waning crescent
            shadow_radius = 0.4 * (2 * phase - 1)
            shadow = plt.Circle((0.5, 0.5), shadow_radius, color='black', ec='black', lw=2)
        
    ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)   # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)   # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Determine the direction and extent of the shadow
    if phase <= 0.5:
        # Waxing crescent to first quarter to waxing gibbous
        shadow = plt.Circle((0.5 + 0.4 * (1 - phase * 2), 0.5), 0.4, color='black', ec='black', lw=2)
        ax.add_artist(shadow)
        clip_path = plt.Circle((0.5 + 0.4 * (1 - phase * 2), 0.5), 0.4, transform=ax.transData)
    else:
        # Waning gibbous to last quarter to waning crescent
        shadow = plt.Circle((0.5 - 0.4 * ((phase - 0.5) * 2), 0.5), 0.4, color='black', ec='black', lw=2)
        ax.add_artist(shadow)
        clip_path = plt.Circle((0.5 - 0.4 * ((phase - 0.5) * 2), 0.5), 0.4, transform=ax.transData)
    
    shadow.set_clip_path(clip_path)
    
    # Add overlap during new moon phase
    if phase == 0:
        overlap_shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
        ax.add_artist(overlap_shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Draw the shadow
    if phase == 0:
        # New moon
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
    elif phase == 1:
        # Full moon, no shadow
        shadow = None
    else:
        # For other phases, adjust shadow size and position
        if phase <= 0.5:
            shadow_pos = (0.5 + 0.4 * (1 - 2 * phase), 0.5)
        else:
            shadow_pos = (0.5 - 0.4 * (2 * phase - 1), 0.5)
        
        shadow_radius = 0.4
        shadow = plt.Circle(shadow_pos, shadow_radius, color='black', ec='black', lw=2)
    
    if shadow:
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    if phase == 0:
        # New moon
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
    elif phase == 1:
        # Full moon, no shadow
        shadow = None
    else:
        # For other phases
        if phase <= 0.5:
            # Waxing crescent to first quarter to waxing gibbous
            x_shift = 0.4 * (1 - 2 * phase)
        else:
            # Waning gibbous to last quarter to waning crescent
            x_shift = 0.4 * (2 * phase - 1)
        
        shadow = plt.Circle((0.5 + x_shift, 0.5), 0.4, color='black', ec='black', lw=2)
        clip_circle = plt.Circle((0.5, 0.5), 0.4, transform=ax.transData)
        shadow.set_clip_path(clip_circle)
    
    if shadow:
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Draw the shadow
    if phase == 0:
        # New moon
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
    elif phase == 1:
        # Full moon, no shadow
        shadow = None
    else:
        # For other phases
        if phase <= 0.5:
            # Waxing crescent to first quarter to waxing gibbous
            x_shift = 0.4 * (1 - 2 * phase)
            shadow_radius = 0.4 * (2 * phase)
        else:
            # Waning gibbous to last quarter to waning crescent
            x_shift = 0.4 * (2 * phase - 1)
            shadow_radius = 0.4 * (2 * (1 - phase))
        
        shadow = plt.Circle((0.5 + x_shift, 0.5), shadow_radius, color='black', ec='black', lw=2)
        clip_circle = plt.Circle((0.5, 0.5), 0.4, transform=ax.transData)
        shadow.set_clip_path(clip_circle)
    
    if shadow:
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    # Determine the shadow's position and radius
    if phase == 0:
        # New moon
        shadow_radius = 0.4
        shadow_pos = (0.5, 0.5)
        shadow = plt.Circle(shadow_pos, shadow_radius, color='black', ec='black', lw=2)
    elif phase == 1:
        # Full moon, no shadow
        shadow = None
    else:
        if phase <= 0.5:
            # Waxing crescent to first quarter to waxing gibbous
            x_shift = 0.5 / (2 * (1 - phase))
            shadow_radius = 0.4 / (2 * (1 - phase))
            shadow_pos = (0.5 + x_shift, 0.5)
        else:
            # Waning gibbous to last quarter to waning crescent
            x_shift = 0.5 / (2 * phase)
            shadow_radius = 0.4 / (2 * phase)
            shadow_pos = (0.5 - x_shift, 0.5)
        
        shadow = plt.Circle(shadow_pos, shadow_radius, color='black', ec='black', lw=2)
        clip_circle = plt.Circle((0.5, 0.5), 0.4, transform=ax.transData)
        shadow.set_clip_path(clip_circle)
    
    if shadow:
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)  # New moon
draw_moon_phase(0.25)  # First quarter
draw_moon_phase(0.5)  # Full moon
draw_moon_phase(0.75)  # Last quarter

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_moon_phase(phase):
    """
    Draws the moon phase.
    
    Parameters:
    phase (float): The fraction of the moon that is illuminated (0 = new moon, 1 = full moon).
    """
    
    # Ensure the phase is between 0 and 1
    if phase < 0 or phase > 1:
        raise ValueError("Phase must be between 0 and 1")
    
    fig, ax = plt.subplots()
    
    # Draw the full moon as a circle
    moon = plt.Circle((0.5, 0.5), 0.4, color='white', ec='black', lw=2)
    ax.add_artist(moon)
    
    if phase == 0:
        # New moon
        shadow = plt.Circle((0.5, 0.5), 0.4, color='black', ec='black', lw=2)
    elif phase == 1:
        # Full moon, no shadow
        shadow = None
    else:
        # For other phases
        if phase <= 0.25:
            # Waxing crescent
            r_shadow = 0.4 / (1 - 2 * phase)
            x_offset = 0.5 + r_shadow
        elif phase <= 0.5:
            # First quarter
            r_shadow = 0.4 / (2 * (0.5 - phase))
            x_offset = 0.5 + r_shadow
        elif phase <= 0.75:
            # Last quarter
            r_shadow = 0.4 / (2 * (phase - 0.5))
            x_offset = 0.5 - r_shadow
        else:
            # Waning crescent
            r_shadow = 0.4 / (1 - 2 * (1 - phase))
            x_offset = 0.5 - r_shadow
        
        shadow = plt.Circle((x_offset, 0.5), r_shadow, color='black', ec='black', lw=2)
        clip_circle = plt.Circle((0.5, 0.5), 0.4, transform=ax.transData)
        shadow.set_clip_path(clip_circle)
    
    if shadow:
        ax.add_artist(shadow)

    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_aspect('equal', 'box')
    ax.axis('off')
    
    plt.show()

# Example usage
draw_moon_phase(0.0)   # New moon
draw_moon_phase(0.25)  # First quarter
#draw_moon_phase(0.5)   # Full moon
#draw_moon_phase(0.75)  # Last quarter
#draw_moon_phase(0.1)   # Waxing crescent
#draw_moon_phase(0.9)   # Waning crescent
