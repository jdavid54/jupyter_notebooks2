# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import ipywidgets as widgets
from IPython.display import display, clear_output

# Add at the beginning after imports
# plt.ion()  # Turn on interactive mode

# %%
# Function to convert time string to datetime object for plotting
def time_to_datetime(time_str, base_date="2025-08-25"):
    time_str = str(time_str).strip()
    try:
        hours, minutes = map(int, time_str.split(':'))
        dt = datetime.strptime(base_date, "%Y-%m-%d")
        return dt + timedelta(hours=hours, minutes=minutes)
    except (ValueError, AttributeError):
        return None


def plot_chunk(chunk_index):
    chunk_index -= 1

    """Plot a specific chunk of data"""
    # Create a new figure each time to ensure clean output
    fig, ax = plt.subplots(figsize=(14, 8))
    
    start_idx = chunk_index * chunk_size
    end_idx = min(start_idx + chunk_size, len(valid_indices))
    
    if start_idx >= len(valid_indices):
        return
    
    chunk_indices = valid_indices[start_idx:end_idx]
    x = np.arange(len(chunk_indices))
    
    # Plot both curves
    ax.plot(x, [sunrise_datetimes[i] for i in chunk_indices], 'o-', color='orange', 
             linewidth=3, markersize=8, label='Lever du soleil (Sunrise)', markerfacecolor='white', markeredgewidth=2)

    ax.plot(x, [sunset_datetimes[i] for i in chunk_indices], 'o-', color='purple', 
             linewidth=3, markersize=8, label='Coucher du soleil (Sunset)', markerfacecolor='white', markeredgewidth=2)

    # Customize the plot
    start_day = dates[chunk_indices[0]]
    end_day = dates[chunk_indices[-1]]
    ax.set_title(f'Heures de Lever et Coucher du Soleil\n{start_day} au {end_day}\nChunk {chunk_index + 1}/{total_chunks}', 
              fontsize=14, fontweight='bold', pad=20)
    ax.set_xlabel('Jours', fontsize=12, fontweight='bold')
    ax.set_ylabel('Heure (HH:MM)', fontsize=12, fontweight='bold')

    # Set x-axis labels
    x_labels = [f"{days[i]}\n{dates[i]}" for i in chunk_indices]
    ax.set_xticks(x)
    ax.set_xticklabels(x_labels, rotation=45, ha='right')

    # Format y-axis to show time in HH:MM
    ax.yaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M'))

    # Set appropriate y-axis limits
    chunk_times = [sunrise_datetimes[i] for i in chunk_indices] + [sunset_datetimes[i] for i in chunk_indices]
    min_time = min(chunk_times)
    max_time = max(chunk_times)
    
    # Add some padding to the time range
    ax.set_ylim(min_time - timedelta(minutes=30), max_time + timedelta(minutes=30))

    # Add grid
    ax.grid(True, alpha=0.3, linestyle='--')

    # Add legend
    ax.legend(loc='upper right', fontsize=11, framealpha=0.9)

    # Add value annotations on the points
    for i, idx in enumerate(chunk_indices):
        sunrise_time = sunrise_datetimes[idx].strftime('%H:%M')
        sunset_time = sunset_datetimes[idx].strftime('%H:%M')
        
        # Annotate sunrise points
        ax.annotate(sunrise_time, 
                    (i, sunrise_datetimes[idx]), 
                    xytext=(0, 20),
                    textcoords='offset points',
                    ha='center', va='bottom',
                    fontsize=9, fontweight='bold',
                    color='orange',
                    bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8, edgecolor='orange'))
        
        # Annotate sunset points
        ax.annotate(sunset_time, 
                    (i, sunset_datetimes[idx]), 
                    xytext=(0, -25),
                    textcoords='offset points',
                    ha='center', va='top',
                    fontsize=9, fontweight='bold',
                    color='purple',
                    bbox=dict(boxstyle="round,pad=0.3", facecolor='white', alpha=0.8, edgecolor='purple'))

    plt.tight_layout()
    plt.show()

def on_slider_change(change):
    """Handle slider change with proper output clearing"""
    with output:
        clear_output(wait=True)  # Clear the previous output
        plot_chunk(change['new'])  # Plot the new chunk

# %% [markdown]
# # Read from JSON file or use the provided data

# %%
try:
    file_path = r'C:\Users\jeand\Desktop\ephemerides.json'
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    print(f"Successfully loaded {len(data)} records from JSON file")
except:
    # Use the provided data if file reading fails
    data = [
        {"Jour":"Lundi","Date":" 25 Août 2025","Lever du soleil":"  06:58","Midi":" 13:52","Coucher du soleil":" 20:47","Durée jour":"13:49","Durée nuit":"10:11. "},
        {"Jour":"Mardi","Date":" 26 Août 2025","Lever du soleil":"  06:59","Midi":" 13:52","Coucher du soleil":" 20:45","Durée jour":"13:46","Durée nuit":"10:14. "},
        {"Jour":"Mercredi","Date":" 27 Août 2025","Lever du soleil":"  07:00","Midi":" 13:51","Coucher du soleil":" 20:43","Durée jour":"13:43","Durée nuit":"10:17. "},
        {"Jour":"Jeudi","Date":" 28 Août 2025","Lever du soleil":"  07:02","Midi":" 13:51","Coucher du soleil":" 20:41","Durée jour":"13:39","Durée nuit":"10:21. "},
        {"Jour":"Vendredi","Date":" 29 Août 2025","Lever du soleil":"  07:03","Midi":" 13:50","Coucher du soleil":" 20:38","Durée jour":"13:35","Durée nuit":"10:25. "},
        {"Jour":"Samedi","Date":" 30 Août 2025","Lever du soleil":"  07:05","Midi":" 13:50","Coucher du soleil":" 20:36","Durée jour":"13:31","Durée nuit":"10:29. "},
        {"Jour":"Dimanche","Date":" 31 Août 2025","Lever du soleil":"  07:06","Midi":" 13:50","Coucher du soleil":" 20:34","Durée jour":"13:28","Durée nuit":"10:32. "}
    ]
    print("Using provided data")
# Out:
# Successfully loaded 2 records from JSON file

# %%
data['ephemerides']
# Out:
# [{'Jour': 'Mardi',
#   'Date': '26 Août 2025',
#   'Lever du soleil': '06:59',
#   'Midi astronomique': '13:52',
#   'Coucher du soleil': '20:45',
#   'Durée de la journée': '13:46',
#   'Durée de la nuit': '10:14'},
#  {'Jour': 'Mercredi',
#   'Date': '27 Août 2025',
#   'Lever du soleil': '07:00',
#   'Midi astronomique': '13:51',
#   'Coucher du soleil': '20:43',
#   'Durée de la journée': '13:43',
#   'Durée de la nuit': '10:17'},
#  {'Jour': 'Jeudi',
#   'Date': '28 Août 2025',
#   'Lever du soleil': '07:02',
#   'Midi astronomique': '13:51',
#   'Coucher du soleil': '20:41',
#   'Durée de la journée': '13:39',
#   'Durée de la nuit': '10:21'},
#  {'Jour': 'Vendredi',
#   'Date': '29 Août 2025',
#   'Lever du soleil': '07:03',
#   'Midi astronomique': '13:50',
#   'Coucher du soleil': '20:38',
#   'Durée de la journée': '13:35',
#   'Durée de la nuit': '10:25'},
#  {'Jour': 'Samedi',
#   'Date': '30 Août 2025',
#   'Lever du soleil': '07:05',
#   'Midi astronomique': '13:50',
#   'Coucher du soleil': '20:36',
#   'Durée de la journée': '13:31',
#   'Durée de la nuit': '10:29'},
#  {'Jour': 'Dimanche',
#   'Date': '31 Août 2025',
#   'Lever du soleil': '07:06',
#   'Midi astronomique': '13:50',
#   'Coucher du soleil': '20:34',
#   'Durée de la journée': '13:28',
#   'Durée de la nuit': '10:32'},
#  {'Jour': 'Lundi',
#   'Date': '01 Septembre 2025',
#   'Lever du soleil': '07:08',
#   'Midi astronomique': '13:50',
#   'Coucher du soleil': '20:32',
#   'Durée de la journée': '13:24',
#   'Durée de la nuit': '10:36'},
#  {'Jour': 'Mardi',
#   'Date': '02 Septembre 2025',
#   'Lever du soleil': '07:09',
#   'Midi astronomique': '13:49',
#   'Coucher du soleil': '20:30',
#   'Durée de la journée': '13:21',
#   'Durée de la nuit': '10:39'},
#  {'Jour': 'Mercredi',
#   'Date': '03 Septembre 2025',
#   'Lever du soleil': '07:11',
#   'Midi astronomique': '13:49',
#   'Coucher du soleil': '20:28',
#   'Durée de la journée': '13:17',
#   'Durée de la nuit': '10:43'},
#  {'Jour': 'Jeudi',
#   'Date': '04 Septembre 2025',
#   'Lever du soleil': '07:12',
#   'Midi astronomique': '13:49',
#   'Coucher du soleil': '20:26',
#   'Durée de la journée': '13:14',
#   'Durée de la nuit': '10:46'},
#  {'Jour': 'Vendredi',
#   'Date': '05 Septembre 2025',
#   'Lever du soleil': '07:13',
#   'Midi astronomique': '13:48',
#   'Coucher du soleil': '20:24',
#   'Durée de la journée': '13:11',
#   'Durée de la nuit': '10:49'},
#  {'Jour': 'Samedi',
#   'Date': '06 Septembre 2025',
#   'Lever du soleil': '07:15',
#   'Midi astronomique': '13:48',
#   'Coucher du soleil': '20:22',
#   'Durée de la journée': '13:07',
#   'Durée de la nuit': '10:53'},
#  {'Jour': 'Dimanche',
#   'Date': '07 Septembre 2025',
#   'Lever du soleil': '07:16',
#   'Midi astronomique': '13:48',
#   'Coucher du soleil': '20:20',
#   'Durée de la journée': '13:04',
#   'Durée de la nuit': '10:56'},
#  {'Jour': 'Lundi',
#   'Date': '08 Septembre 2025',
#   'Lever du soleil': '07:18',
#   'Midi astronomique': '13:48',
#   'Coucher du soleil': '20:18',
#   'Durée de la journée': '13:00',
#   'Durée de la nuit': '11:00'},
#  {'Jour': 'Mardi',
#   'Date': '09 Septembre 2025',
#   'Lever du soleil': '07:19',
#   'Midi astronomique': '13:47',
#   'Coucher du soleil': '20:16',
#   'Durée de la journée': '12:57',
#   'Durée de la nuit': '11:03'},
#  {'Jour': 'Mercredi',
#   'Date': '10 Septembre 2025',
#   'Lever du soleil': '07:20',
#   'Midi astronomique': '13:47',
#   'Coucher du soleil': '20:14',
#   'Durée de la journée': '12:54',
#   'Durée de la nuit': '11:06'},
#  {'Jour': 'Jeudi',
#   'Date': '11 Septembre 2025',
#   'Lever du soleil': '07:22',
#   'Midi astronomique': '13:46',
#   'Coucher du soleil': '20:11',
#   'Durée de la journée': '12:49',
#   'Durée de la nuit': '11:11'},
#  {'Jour': 'Vendredi',
#   'Date': '12 Septembre 2025',
#   'Lever du soleil': '07:23',
#   'Midi astronomique': '13:46',
#   'Coucher du soleil': '20:09',
#   'Durée de la journée': '12:46',
#   'Durée de la nuit': '11:14'},
#  {'Jour': 'Samedi',
#   'Date': '13 Septembre 2025',
#   'Lever du soleil': '07:25',
#   'Midi astronomique': '13:46',
#   'Coucher du soleil': '20:07',
#   'Durée de la journée': '12:42',
#   'Durée de la nuit': '11:18'},
#  {'Jour': 'Dimanche',
#   'Date': '14 Septembre 2025',
#   'Lever du soleil': '07:26',
#   'Midi astronomique': '13:45',
#   'Coucher du soleil': '20:05',
#   'Durée de la journée': '12:39',
#   'Durée de la nuit': '11:21'},
#  {'Jour': 'Lundi',
#   'Date': '15 Septembre 2025',
#   'Lever du soleil': '07:28',
#   'Midi astronomique': '13:45',
#   'Coucher du soleil': '20:03',
#   'Durée de la journée': '12:35',
#   'Durée de la nuit': '11:25'},
#  {'Jour': 'Mardi',
#   'Date': '16 Septembre 2025',
#   'Lever du soleil': '07:29',
#   'Midi astronomique': '13:45',
#   'Coucher du soleil': '20:01',
#   'Durée de la journée': '12:32',
#   'Durée de la nuit': '11:28'},
#  {'Jour': 'Mercredi',
#   'Date': '17 Septembre 2025',
#   'Lever du soleil': '07:30',
#   'Midi astronomique': '13:44',
#   'Coucher du soleil': '19:59',
#   'Durée de la journée': '12:29',
#   'Durée de la nuit': '11:31'},
#  {'Jour': 'Jeudi',
#   'Date': '18 Septembre 2025',
#   'Lever du soleil': '07:32',
#   'Midi astronomique': '13:44',
#   'Coucher du soleil': '19:57',
#   'Durée de la journée': '12:25',
#   'Durée de la nuit': '11:35'},
#  {'Jour': 'Vendredi',
#   'Date': '19 Septembre 2025',
#   'Lever du soleil': '07:33',
#   'Midi astronomique': '13:44',
#   'Coucher du soleil': '19:55',
#   'Durée de la journée': '12:22',
#   'Durée de la nuit': '11:38'},
#  {'Jour': 'Samedi',
#   'Date': '20 Septembre 2025',
#   'Lever du soleil': '07:35',
#   'Midi astronomique': '13:44',
#   'Coucher du soleil': '19:53',
#   'Durée de la journée': '12:18',
#   'Durée de la nuit': '11:42'},
#  {'Jour': 'Dimanche',
#   'Date': '21 Septembre 2025',
#   'Lever du soleil': '07:36',
#   'Midi astronomique': '13:43',
#   'Coucher du soleil': '19:51',
#   'Durée de la journée': '12:15',
#   'Durée de la nuit': '11:45'},
#  {'Jour': 'Lundi',
#   'Date': '22 Septembre 2025',
#   'Lever du soleil': '07:38',
#   'Midi astronomique': '13:43',
#   'Coucher du soleil': '19:48',
#   'Durée de la journée': '12:10',
#   'Durée de la nuit': '11:50'},
#  {'Jour': 'Mardi',
#   'Date': '23 Septembre 2025',
#   'Lever du soleil': '07:39',
#   'Midi astronomique': '13:42',
#   'Coucher du soleil': '19:46',
#   'Durée de la journée': '12:07',
#   'Durée de la nuit': '11:53'},
#  {'Jour': 'Mercredi',
#   'Date': '24 Septembre 2025',
#   'Lever du soleil': '07:40',
#   'Midi astronomique': '13:42',
#   'Coucher du soleil': '19:44',
#   'Durée de la journée': '12:04',
#   'Durée de la nuit': '11:56'},
#  {'Jour': 'Jeudi',
#   'Date': '25 Septembre 2025',
#   'Lever du soleil': '07:42',
#   'Midi astronomique': '13:42',
#   'Coucher du soleil': '19:42',
#   'Durée de la journée': '12:00',
#   'Durée de la nuit': '12:00'},
#  {'Jour': 'Vendredi',
#   'Date': '26 Septembre 2025',
#   'Lever du soleil': '07:43',
#   'Midi astronomique': '13:41',
#   'Coucher du soleil': '19:40',
#   'Durée de la journée': '11:57',
#   'Durée de la nuit': '12:03'},
#  {'Jour': 'Samedi',
#   'Date': '27 Septembre 2025',
#   'Lever du soleil': '07:45',
#   'Midi astronomique': '13:41',
#   'Coucher du soleil': '19:38',
#   'Durée de la journée': '11:53',
#   'Durée de la nuit': '12:07'},
#  {'Jour': 'Dimanche',
#   'Date': '28 Septembre 2025',
#   'Lever du soleil': '07:46',
#   'Midi astronomique': '13:41',
#   'Coucher du soleil': '19:36',
#   'Durée de la journée': '11:50',
#   'Durée de la nuit': '12:10'},
#  {'Jour': 'Lundi',
#   'Date': '29 Septembre 2025',
#   'Lever du soleil': '07:48',
#   'Midi astronomique': '13:41',
#   'Coucher du soleil': '19:34',
#   'Durée de la journée': '11:46',
#   'Durée de la nuit': '12:14'},
#  {'Jour': 'Mardi',
#   'Date': '30 Septembre 2025',
#   'Lever du soleil': '07:49',
#   'Midi astronomique': '13:40',
#   'Coucher du soleil': '19:32',
#   'Durée de la journée': '11:43',
#   'Durée de la nuit': '12:17'},
#  {'Jour': 'Mercredi',
#   'Date': '01 Octobre 2025',
#   'Lever du soleil': '07:50',
#   'Midi astronomique': '13:39',
#   'Coucher du soleil': '19:29',
#   'Durée de la journée': '11:39',
#   'Durée de la nuit': '12:21'},
#  {'Jour': 'Jeudi',
#   'Date': '02 Octobre 2025',
#   'Lever du soleil': '07:52',
#   'Midi astronomique': '13:39',
#   'Coucher du soleil': '19:27',
#   'Durée de la journée': '11:35',
#   'Durée de la nuit': '12:25'},
#  {'Jour': 'Vendredi',
#   'Date': '03 Octobre 2025',
#   'Lever du soleil': '07:53',
#   'Midi astronomique': '13:39',
#   'Coucher du soleil': '19:25',
#   'Durée de la journée': '11:32',
#   'Durée de la nuit': '12:28'},
#  {'Jour': 'Samedi',
#   'Date': '04 Octobre 2025',
#   'Lever du soleil': '07:55',
#   'Midi astronomique': '13:39',
#   'Coucher du soleil': '19:23',
#   'Durée de la journée': '11:28',
#   'Durée de la nuit': '12:32'},
#  {'Jour': 'Dimanche',
#   'Date': '05 Octobre 2025',
#   'Lever du soleil': '07:56',
#   'Midi astronomique': '13:38',
#   'Coucher du soleil': '19:21',
#   'Durée de la journée': '11:25',
#   'Durée de la nuit': '12:35'},
#  {'Jour': 'Lundi',
#   'Date': '06 Octobre 2025',
#   'Lever du soleil': '07:58',
#   'Midi astronomique': '13:38',
#   'Coucher du soleil': '19:19',
#   'Durée de la journée': '11:21',
#   'Durée de la nuit': '12:39'},
#  {'Jour': 'Mardi',
#   'Date': '07 Octobre 2025',
#   'Lever du soleil': '07:59',
#   'Midi astronomique': '13:38',
#   'Coucher du soleil': '19:17',
#   'Durée de la journée': '11:18',
#   'Durée de la nuit': '12:42'},
#  {'Jour': 'Mercredi',
#   'Date': '08 Octobre 2025',
#   'Lever du soleil': '08:01',
#   'Midi astronomique': '13:38',
#   'Coucher du soleil': '19:15',
#   'Durée de la journée': '11:14',
#   'Durée de la nuit': '12:46'},
#  {'Jour': 'Jeudi',
#   'Date': '09 Octobre 2025',
#   'Lever du soleil': '08:02',
#   'Midi astronomique': '13:37',
#   'Coucher du soleil': '19:13',
#   'Durée de la journée': '11:11',
#   'Durée de la nuit': '12:49'},
#  {'Jour': 'Vendredi',
#   'Date': '10 Octobre 2025',
#   'Lever du soleil': '08:04',
#   'Midi astronomique': '13:37',
#   'Coucher du soleil': '19:11',
#   'Durée de la journée': '11:07',
#   'Durée de la nuit': '12:53'},
#  {'Jour': 'Samedi',
#   'Date': '11 Octobre 2025',
#   'Lever du soleil': '08:05',
#   'Midi astronomique': '13:37',
#   'Coucher du soleil': '19:09',
#   'Durée de la journée': '11:04',
#   'Durée de la nuit': '12:56'},
#  {'Jour': 'Dimanche',
#   'Date': '12 Octobre 2025',
#   'Lever du soleil': '08:07',
#   'Midi astronomique': '13:37',
#   'Coucher du soleil': '19:07',
#   'Durée de la journée': '11:00',
#   'Durée de la nuit': '13:00'},
#  {'Jour': 'Lundi',
#   'Date': '13 Octobre 2025',
#   'Lever du soleil': '08:08',
#   'Midi astronomique': '13:36',
#   'Coucher du soleil': '19:05',
#   'Durée de la journée': '10:57',
#   'Durée de la nuit': '13:03'},
#  {'Jour': 'Mardi',
#   'Date': '14 Octobre 2025',
#   'Lever du soleil': '08:10',
#   'Midi astronomique': '13:36',
#   'Coucher du soleil': '19:03',
#   'Durée de la journée': '10:53',
#   'Durée de la nuit': '13:07'},
#  {'Jour': 'Mercredi',
#   'Date': '15 Octobre 2025',
#   'Lever du soleil': '08:11',
#   'Midi astronomique': '13:36',
#   'Coucher du soleil': '19:01',
#   'Durée de la journée': '10:50',
#   'Durée de la nuit': '13:10'},
#  {'Jour': 'Jeudi',
#   'Date': '16 Octobre 2025',
#   'Lever du soleil': '08:13',
#   'Midi astronomique': '13:36',
#   'Coucher du soleil': '18:59',
#   'Durée de la journée': '10:46',
#   'Durée de la nuit': '13:14'},
#  {'Jour': 'Vendredi',
#   'Date': '17 Octobre 2025',
#   'Lever du soleil': '08:14',
#   'Midi astronomique': '13:35',
#   'Coucher du soleil': '18:57',
#   'Durée de la journée': '10:43',
#   'Durée de la nuit': '13:17'},
#  {'Jour': 'Samedi',
#   'Date': '18 Octobre 2025',
#   'Lever du soleil': '08:16',
#   'Midi astronomique': '13:35',
#   'Coucher du soleil': '18:55',
#   'Durée de la journée': '10:39',
#   'Durée de la nuit': '13:21'},
#  {'Jour': 'Dimanche',
#   'Date': '19 Octobre 2025',
#   'Lever du soleil': '08:17',
#   'Midi astronomique': '13:35',
#   'Coucher du soleil': '18:53',
#   'Durée de la journée': '10:36',
#   'Durée de la nuit': '13:24'},
#  {'Jour': 'Lundi',
#   'Date': '20 Octobre 2025',
#   'Lever du soleil': '08:19',
#   'Midi astronomique': '13:35',
#   'Coucher du soleil': '18:51',
#   'Durée de la journée': '10:32',
#   'Durée de la nuit': '13:28'},
#  {'Jour': 'Mardi',
#   'Date': '21 Octobre 2025',
#   'Lever du soleil': '08:20',
#   'Midi astronomique': '13:34',
#   'Coucher du soleil': '18:49',
#   'Durée de la journée': '10:29',
#   'Durée de la nuit': '13:31'},
#  {'Jour': 'Mercredi',
#   'Date': '22 Octobre 2025',
#   'Lever du soleil': '08:22',
#   'Midi astronomique': '13:34',
#   'Coucher du soleil': '18:47',
#   'Durée de la journée': '10:25',
#   'Durée de la nuit': '13:35'},
#  {'Jour': 'Jeudi',
#   'Date': '23 Octobre 2025',
#   'Lever du soleil': '08:23',
#   'Midi astronomique': '13:34',
#   'Coucher du soleil': '18:45',
#   'Durée de la journée': '10:22',
#   'Durée de la nuit': '13:38'},
#  {'Jour': 'Vendredi',
#   'Date': '24 Octobre 2025',
#   'Lever du soleil': '08:25',
#   'Midi astronomique': '13:34',
#   'Coucher du soleil': '18:44',
#   'Durée de la journée': '10:19',
#   'Durée de la nuit': '13:41'}]

# %% [markdown]
# ## Proceed data

# %%
# Extract data
days = [entry['Jour'] for entry in data['ephemerides']]
dates = [entry['Date'].strip() for entry in data['ephemerides']]
sunrise_times = [entry['Lever du soleil'].strip() for entry in data['ephemerides']]
sunset_times = [entry['Coucher du soleil'].strip() for entry in data['ephemerides']]

# Convert times to datetime objects for plotting
sunrise_datetimes = [time_to_datetime(time) for time in sunrise_times]
sunset_datetimes = [time_to_datetime(time) for time in sunset_times]

# Filter out any invalid entries
valid_indices = [i for i, (sun, set) in enumerate(zip(sunrise_datetimes, sunset_datetimes)) 
                if sun is not None and set is not None]

if not valid_indices:
    print("No valid time data found")
    #exit()

# %% [markdown]
# # Navigation slider setup

# %%
# Global variables for navigation
chunk_size = 7
total_chunks = (len(valid_indices) + chunk_size - 1) // chunk_size

# Create output area
output = widgets.Output()

# Create slider with better formatting
chunk_slider = widgets.IntSlider(
    value=1,
    min=1,
    max=total_chunks,
    step=1,
    description='Chunk:',
    continuous_update=False,
    readout=True,
    style={'description_width': 'initial'}
)


# Connect the slider change event
chunk_slider.observe(on_slider_change, names='value')

# Create a container for the slider and output
container = widgets.VBox([
    widgets.HBox([widgets.Label('Naviguez avec le slider '), chunk_slider]),
    output
])

# %% [markdown]
# # Display the current chunk

# %%
# Display the container
display(container)

# Plot the initial chunk
with output:
    plot_chunk(1)
# Out:
# VBox(children=(HBox(children=(Label(value='Naviguez avec le slider '), IntSlider(value=1, continuous_update=Fa…
