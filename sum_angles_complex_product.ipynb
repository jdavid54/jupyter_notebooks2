# %%
from cmath import phase, polar
from numpy import degrees, rad2deg

# %%
p = 1
m=[]
for i in range(1,172):
    p *= (i+1j)
    m.append(p)

# %%
for p in m:
    print('%-48s\t%-45s\t%s' % (p,polar(p),degrees(phase(p))))
# Out:
# (1+1j)                                          	(1.4142135623730951, 0.7853981633974483)     	45.0
# (1+3j)                                          	(3.1622776601683795, 1.2490457723982544)     	71.56505117707799
# 10j                                             	(10.0, 1.5707963267948966)                   	90.0
# (-10+40j)                                       	(41.23105625617661, 1.8157749899217608)      	104.03624346792648
# (-90+190j)                                      	(210.23796041628637, 2.0131705497716417)     	115.3461759419467
# (-730+1050j)                                    	(1278.8275880665071, 2.1783192271862686)     	124.80849814997232
# (-6160+6620j)                                   	(9042.67659490264, 2.320216281790432)        	132.9386005041283
# (-55900+46800j)                                 	(72904.38944261175, 2.444571276337194)       	140.06361685303008
# ...
