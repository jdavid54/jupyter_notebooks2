# %%
import numpy
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas
#https://www.geeksforgeeks.org/matplotlib-dates-dateformatter-class-in-python/

# %%
total_bars = 25
numpy.random.seed(total_bars)

dates = pandas.date_range('3/4/2020',
						periods=total_bars,
						freq='m')
dates
# Out:
# DatetimeIndex(['2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#                '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31',
#                '2020-11-30', '2020-12-31', '2021-01-31', '2021-02-28',
#                '2021-03-31', '2021-04-30', '2021-05-31', '2021-06-30',
#                '2021-07-31', '2021-08-31', '2021-09-30', '2021-10-31',
#                '2021-11-30', '2021-12-31', '2022-01-31', '2022-02-28',
#                '2022-03-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
diff = pandas.DataFrame(
	data=numpy.random.randn(total_bars),
	index=dates,
	columns=['A']
)
diff
# Out:
#                    A
# 2020-03-31  0.228273
# 2020-04-30  1.026890
# 2020-05-31 -0.839585
# 2020-06-30 -0.591182
# 2020-07-31 -0.956888
# 2020-08-31 -0.222326
# 2020-09-30 -0.619915
# 2020-10-31  1.837905
# 2020-11-30 -2.053231
# 2020-12-31  0.868583
# 2021-01-31 -0.920734
# 2021-02-28 -0.232312
# 2021-03-31  2.152957
# 2021-04-30 -1.334661
# 2021-05-31  0.076380
# 2021-06-30 -1.246089
# 2021-07-31  1.202272
# 2021-08-31 -1.049942
# 2021-09-30  1.056610
# 2021-10-31 -0.419678
# 2021-11-30  2.294842
# 2021-12-31 -2.594487
# 2022-01-31  2.822756
# 2022-02-28  0.680889
# 2022-03-31 -1.577693

# %%
figure, axes = plt.subplots(figsize=(10, 6))

axes.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

axes.bar(diff.index,
		diff['A'],
		width=25,
		align='center')
# Out:
# <BarContainer object of 25 artists>

# %%
help(mdates.HourLocator(range(0, 24, 1)))
mdates.HourLocator(range(0,24,1)).hms0d
#mdates.HourLocator(range(0,24,1)).datalim_to_dt()  
#mdates.HourLocator(range(0,24,1)).__call__()
mdates.HourLocator(range(0,24,1)).__dict__#['rule']
# Out:
# Help on HourLocator in module matplotlib.dates object:
#
# class HourLocator(RRuleLocator)
#  |  HourLocator(byhour=None, interval=1, tz=None)
#  |
#  |  Make ticks on occurrences of each hour.
#  |
#  |  Method resolution order:
#  |      HourLocator
#  |      RRuleLocator
#  |      DateLocator
#  |      matplotlib.ticker.Locator
#  |      matplotlib.ticker.TickHelper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, byhour=None, interval=1, tz=None)
#  |      Mark every hour in *byhour*; *byhour* can be an int or sequence.
#  |      Default is to tick every hour: ``byhour=range(24)``
#  |
#  |      *interval* is the interval between each iteration.  For
#  |      example, if ``interval=2``, mark every second occurrence.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from RRuleLocator:
#  |
#  |  __call__(self)
#  |      Return the locations of the ticks.
#  |
# ...

# %%
help(mdates.rrulewrapper)#.__dict__
# Out:
# Help on class rrulewrapper in module matplotlib.dates:
#
# class rrulewrapper(builtins.object)
#  |  rrulewrapper(freq, tzinfo=None, **kwargs)
#  |
#  |  Methods defined here:
#  |
#  |  __getattr__(self, name)
#  |
#  |  __init__(self, freq, tzinfo=None, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __setstate__(self, state)
#  |
#  |  set(self, **kwargs)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
