# %%
import wikipedia
#https://pypi.org/project/Wikipedia-API/

# %%
result = wikipedia.page('freeCodeCamp')

# %%
print(result.summary)
# Out:
# freeCodeCamp (also referred to as “Free Code Camp”) is a non-profit organization that consists of an interactive learning web platform, an online community forum, chat rooms, Medium publications and local organizations that intend to make learning web development accessible to anyone. Beginning with tutorials that introduce students to HTML, CSS and JavaScript, students progress to project assignments that they must complete either alone or in pairs. Upon completion of all project tasks, students are partnered with other nonprofits to build web applications, giving the students practical development experience.

# %%
for link in result.links:
    print(link)
# Out:
# ALISON (company)
# APIs and Microservices
# Academic Earth
# Alexa Internet
# Anant Agarwal
# Andrew Ng
# AngularJS
# Bootstrap (front-end framework)
# Brady Haran
# CGP Grey
# Canvas Network
# Cascading Style Sheets
# China Open Resources for Education
# ClassDojo
# CodeCombat
# Code School
# Codecademy
# Connectivism
# Coursera
# Crash Course (YouTube)
# D3.js
# Daphne Koller
# Data visualization
# Derek Muller
# Duolingo
# EdX
# EduKart
# Edulanka
# Eliademy
# Express.js
# France Université Numérique
# Front End Libraries
# FutureLearn
# Gamification
# George Siemens
# Git
# Green brothers
# HTML5
# Hank Green
# Hello English
# IONISx
# Impostor syndrome
# Information Security and Quality Assurance
# Iversity
# JQuery
# JavaScript
# JavaScript Algorithms and Data Structures
# John Green (author)
# KSL-TV
# Kadenze
# Khan Academy
# Kopernik (organization)
# LinkedIn Learning
# Lynda Weinman
# MIT OpenCourseWare
# MailChimp
# Massive open online course
# Medium (website)
# Mike Feerick
# Mindvalley
# MongoDB
# Node.js
# Nonprofit organization
# Oklahoma City
# Open-source
# Open2Study
# OpenCourseWare
# OpenHPI
# OpenLearn
# OpenLearning
# Open data
# Open education
# Open educational resources
# Pair programming
# Peer to Peer University
# Peter Norvig
# Pluralsight
# Quipper (company)
# React (JavaScript library)
# Responsive Web Design
# Ribbon Hero
# SWAYAM
# Salman Khan (educator)
# San Francisco, California
# Sass (stylesheet language)
# Sebastian Thrun
# Shaw Academy
# Skillshare
# Stanford
# Stephen Downes
# Topica Edtech Group
# Udacity
# Udemy
# Unacademy
# Unbundling
# Web development
# Woz U

# %%
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')
page_py = wiki_wiki.page('Python_(programming_language)')

# %%
print(wiki_wiki)
# Out:
# <wikipediaapi.Wikipedia object at 0xb1711fec>

# %%
print(page_py)
# Out:
# Python_(programming_language) (id: ??, ns: 0)

# %%
page_py = wiki_wiki.page('Python_(programming_language)')
print("Page - Exists: %s" % page_py.exists())
# Page - Exists: True

page_missing = wiki_wiki.page('NonExistingPageWithStrangeName')
print("Page - Exists: %s" %     page_missing.exists())
# Page - Exists: False
# Out:
# Page - Exists: True
# Page - Exists: False

# %%
wiki_wiki = wikipediaapi.Wikipedia('en')

print("Page - Title: %s" % page_py.title)
# Page - Title: Python (programming language)

print("Page - Summary: %s" % page_py.summary[0:60])
# Page - Summary: Python is a widely used high-level programming language for
# Out:
# Page - Title: Python (programming language)
# Page - Summary: Python is an interpreted, high-level, general-purpose progra

# %%
print(page_py.fullurl)
# https://en.wikipedia.org/wiki/Python_(programming_language)

print(page_py.canonicalurl)
# https://en.wikipedia.org/wiki/Python_(programming_language)
# Out:
# https://en.wikipedia.org/wiki/Python_(programming_language)
# https://en.wikipedia.org/wiki/Python_(programming_language)

# %%
wiki_wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI
)

p_wiki = wiki_wiki.page("freeCodeCamp")
print(p_wiki.text)
# Summary
# Section 1
# Text of section 1
# Section 1.1
# Text of section 1.1
# ...
# Out:
# freeCodeCamp (also referred to as “Free Code Camp”) is a non-profit organization that consists of an interactive learning web platform, an online community forum, chat rooms, Medium publications and local organizations that intend to make learning web development accessible to anyone. Beginning with tutorials that introduce students to HTML, CSS and JavaScript, students progress to project assignments that they must complete either alone or in pairs. Upon completion of all project tasks, students are partnered with other nonprofits to build web applications, giving the students practical development experience.
#
# History
# freeCodeCamp was launched in October 2014 and incorporated as Free Code Camp, Inc. The founder, Quincy Larson, is a software developer who took up programming after graduate school and created freeCodeCamp as a way to streamline a student's progress from beginner to being job-ready.
# In a 2015 podcast interview, he summarized his motivation for creating freeCodeCamp as follows: “freeCodeCamp is my effort to correct the extremely inefficient and circuitous way I learned to code. I’m committing my career and the rest of my life towards making this process as efficient and painless as possible. […] All those things that made learning to code a nightmare to me are things that we are trying to fix with freeCodeCamp.”The original curriculum focused on MongoDB, Express.js, AngularJS, and Node.js and was estimated to take 800 hours to complete. Many of the lessons were links to free material on other platforms, such as Codecademy, Stanford, or Code School. The course was broken up into “Waypoints” (quick, interactive tutorials), “Bonfires” (algorithm challenges), “Ziplines” (front-end projects), and “Basejumps” (full-stack projects). Completing the front-end and full-stack projects awarded the student with respective certificates.
# The curriculum was updated in January 2016 to rely less on outside material, remove the unconventional section names, and switch focus from AngularJS to React.js as the front-end library of choice. There were a number of additions to the coursework, including D3.js and Sass, which brought the total time estimate to 2,080 hours and two more certificates, data visualization and back-end.
#
# Quincy Larson
# After returning from a trip to China, Larson was inspired to launch freeCodeCamp by seeing a young boy's interest towards coding. And he decided to give people the opportunity to learn programming. After six years living in San Francisco, Larson now lives in Oklahoma City, Oklahoma.
#
# Curriculum
# The self-paced curriculum involves 1,400 hours of interactive coding challenges and web development projects, plus 800 hours of contributing to open-source  projects for nonprofits and is constantly expanded by more challenges and projects. This translates into about one year of full-time coding. The curriculum is divided into Responsive Web Design, JavaScript Algorithms and Data Structures, Front End Libraries, data visualization, APIs and Microservices, and Information Security and Quality Assurance. Participants receive a certificate after completing each section.The curriculum emphasizes pair programming, intended to foster a culture of collaboration and shared learning, which can overcome a student's doubts about the adequacy of their skills (popularly referred to as “impostor syndrome”).The languages and technologies currently taught by freeCodeCamp include HTML5, CSS 3, JavaScript, jQuery, Bootstrap, Sass, React.js, Node.js, Express.js, MongoDB, and Git.
#
# Nonprofit work
# As students of freeCodeCamp finish all certificates of the curriculum, they get the opportunity, and are encouraged, to work with nonprofit organizations. Examples have been Indonesia-based nonprofit Kopernik and People Saving Animals.In 2016, freeCodeCamp announced their "Open Source for Good" initiative, which extends and open sources their nonprofit work to all nonprofits and organizations to use. Within ten months of launching, the initiative has created seven open-source tools. Mail for Good is one of the projects, which helps organizations send bulk email messages at a low cost, which serves as a cheaper alternative to services such as MailChimp.
#
# Reception
# freeCodeCamp's platform is used by about 350,000 unique visitors per month, with students from over 160 countries. According to Alexa, freeCodeCamp is ranked around 2,150 globally and around 1,290 in the United States in terms of monthly traffic.freeCodeCamp has international, community-run groups where students can interact in person. Some groups have been featured in local news, citing freeCodeCamp as an introduction to programming in order to fill the estimated vacancy in programming-related jobs in the next decade.
#
# References
# External links
# Official website

# %%
wiki_html = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.HTML
)
p_html = wiki_html.page("freeCodeCamp")
print(p_html.text)
# <p>Summary</p>
# <h2>Section 1</h2>
# <p>Text of section 1</p>
# <h3>Section 1.1</h3>
# <p>Text of section 1.1</p>
# ...
# Out:
# <p><span></span>
# </p>
# <p><b>freeCodeCamp</b> (also referred to as “<b>Free Code Camp</b>”) is a non-profit organization that consists of an interactive learning web platform, an online community forum, chat rooms, Medium publications and local organizations that intend to make learning web development accessible to anyone. Beginning with tutorials that introduce students to HTML, CSS and JavaScript, students progress to project assignments that they must complete either alone or in pairs. Upon completion of all project tasks, students are partnered with other nonprofits to build web applications, giving the students practical development experience.</p>
#
# <h2>History</h2>
# <p>freeCodeCamp was launched in October 2014 and incorporated as Free Code Camp, Inc. The founder, Quincy Larson, is a software developer who took up programming after graduate school and created freeCodeCamp as a way to streamline a student's progress from beginner to being job-ready.
# In a 2015 podcast interview, he summarized his motivation for creating freeCodeCamp as follows: “freeCodeCamp is my effort to correct the extremely inefficient and circuitous way I learned to code. I’m committing my career and the rest of my life towards making this process as efficient and painless as possible. […] All those things that made learning to code a nightmare to me are things that we are trying to fix with freeCodeCamp.”</p><p>The original curriculum focused on MongoDB, Express.js, AngularJS, and Node.js and was estimated to take 800 hours to complete. Many of the lessons were links to free material on other platforms, such as Codecademy, Stanford, or Code School. The course was broken up into “Waypoints” (quick, interactive tutorials), “Bonfires” (algorithm challenges), “Ziplines” (front-end projects), and “Basejumps” (full-stack projects). Completing the front-end and full-stack projects awarded the student with respective certificates.
# </p><p>The curriculum was updated in January 2016 to rely less on outside material, remove the unconventional section names, and switch focus from AngularJS to React.js as the front-end library of choice. There were a number of additions to the coursework, including D3.js and Sass, which brought the total time estimate to 2,080 hours and two more certificates, data visualization and back-end.
# </p>
#
# <h3>Quincy Larson</h3>
# <p>After returning from a trip to China, Larson was inspired to launch freeCodeCamp by seeing a young boy's interest towards coding. And he decided to give people the opportunity to learn programming. After six years living in San Francisco, Larson now lives in Oklahoma City, Oklahoma.</p>
#
# <h2>Curriculum</h2>
# <p>The self-paced curriculum involves 1,400 hours of interactive coding challenges and web development projects, plus 800 hours of contributing to open-source  projects for nonprofits and is constantly expanded by more challenges and projects. This translates into about one year of full-time coding. The curriculum is divided into Responsive Web Design, JavaScript Algorithms and Data Structures, Front End Libraries, data visualization, APIs and Microservices, and Information Security and Quality Assurance. Participants receive a certificate after completing each section.</p><p>The curriculum emphasizes pair programming, intended to foster a culture of collaboration and shared learning, which can overcome a student's doubts about the adequacy of their skills (popularly referred to as “impostor syndrome”).</p><p>The languages and technologies currently taught by freeCodeCamp include HTML5, CSS 3, JavaScript, jQuery, Bootstrap, Sass, React.js, Node.js, Express.js, MongoDB, and Git.</p>
#
# <h2>Nonprofit work</h2>
# <p>As students of freeCodeCamp finish all certificates of the curriculum, they get the opportunity, and are encouraged, to work with nonprofit organizations. Examples have been Indonesia-based nonprofit Kopernik and People Saving Animals.</p><p>In 2016, freeCodeCamp announced their "Open Source for Good" initiative, which extends and open sources their nonprofit work to all nonprofits and organizations to use. Within ten months of launching, the initiative has created seven open-source tools. Mail for Good is one of the projects, which helps organizations send bulk email messages at a low cost, which serves as a cheaper alternative to services such as MailChimp.
# </p>
#
# <h2>Reception</h2>
# <p>freeCodeCamp's platform is used by about 350,000 unique visitors per month, with students from over 160 countries. According to Alexa, freeCodeCamp is ranked around 2,150 globally and around 1,290 in the United States in terms of monthly traffic.</p><p>freeCodeCamp has international, community-run groups where students can interact in person. Some groups have been featured in local news, citing freeCodeCamp as an introduction to programming in order to fill the estimated vacancy in programming-related jobs in the next decade.</p>
#
# <h2>References</h2>
# <h2>External links</h2>
# <ul><li><span><span>Official website</span></span></li></ul>

# %%
def print_sections(sections, level=0):
        for s in sections:
                print("%s: %s - %s" % ("*" * (level + 1), s.title, s.text[0:40]))
                print_sections(s.sections, level + 1)


print_sections(page_py.sections)
# *: History - Python was conceived in the late 1980s,
# *: Features and philosophy - Python is a multi-paradigm programming l
# *: Syntax and semantics - Python is meant to be an easily readable
# **: Indentation - Python uses whitespace indentation, rath
# **: Statements and control flow - Python's statements include (among other
# **: Expressions - Some Python expressions are similar to l
# Out:
# *: History - Python was conceived in the late 1980s b
# *: Features and philosophy - Python is a multi-paradigm programming l
# *: Syntax and semantics - Python is meant to be an easily readable
# **: Indentation - Python uses whitespace indentation, rath
# **: Statements and control flow - Python's statements include (among other
# **: Expressions - Some Python expressions are similar to l
# **: Methods - Methods on objects are functions attache
# **: Typing - Python uses duck typing and has typed ob
# **: Mathematics - Python has the usual C language arithmet
# *: Libraries - Python's large standard library, commonl
# *: Development environments - Most Python implementations (including C
# *: Implementations -
# **: Reference implementation - CPython is the reference implementation
# **: Other implementations - PyPy is a fast, compliant interpreter of
# **: Unsupported implementations - Other just-in-time Python compilers have
# **: Cross-compilers to other languages - There are several compilers to high-leve
# **: Performance - A performance comparison of various Pyth
# *: Development - Python's development is conducted largel
# *: Naming - Python's name is derived from the Britis
# *: API documentation generators - Python API documentation generators incl
# *: Uses - Since 2003, Python has consistently rank
# *: Languages influenced by Python - Python's design and philosophy have infl
# *: See also - Comparison of programming languages
# List
# *: References -
# **: Sources - "Python for Artificial Intelligence". Wi
# *: Further reading - Downey, Allen B. (May 2012). Think Pytho
# *: External links -
# Official website
# Python at Curlie

# %%
def print_langlinks(page):
        langlinks = page.langlinks
        for k in sorted(langlinks.keys()):
            v = langlinks[k]
            print("%s: %s - %s: %s" % (k, v.language, v.title, v.fullurl))

print_langlinks(page_py)
# af: af - Python (programmeertaal): https://af.wikipedia.org/wiki/Python_(programmeertaal)
# als: als - Python (Programmiersprache): https://als.wikipedia.org/wiki/Python_(Programmiersprache)
# an: an - Python: https://an.wikipedia.org/wiki/Python
# ar: ar - بايثون: https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86
# as: as - পাইথন: https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8

page_py_cs = page_py.langlinks['cs']
print("Page - Summary: %s" % page_py_cs.summary[0:60])
# Page - Summary: Python (anglická výslovnost [ˈpaiθtən]) je vysokoúrovňový sk
# Out:
# af: af - Python (programmeertaal): https://af.wikipedia.org/wiki/Python_(programmeertaal)
# als: als - Python (Programmiersprache): https://als.wikipedia.org/wiki/Python_(Programmiersprache)
# an: an - Python: https://an.wikipedia.org/wiki/Python
# ar: ar - بايثون: https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86
# as: as - পাইথন: https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8
# ast: ast - Python: https://ast.wikipedia.org/wiki/Python
# az: az - Python (proqramlaşdırma dili): https://az.wikipedia.org/wiki/Python_(proqramla%C5%9Fd%C4%B1rma_dili)
# azb: azb - پایتون: https://azb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86
# be: be - Python (мова праграмавання): https://be.wikipedia.org/wiki/Python_(%D0%BC%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F)
# bg: bg - Python: https://bg.wikipedia.org/wiki/Python
# bn: bn - পাইথন (প্রোগ্রামিং ভাষা): https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE)
# bs: bs - Python (programski jezik): https://bs.wikipedia.org/wiki/Python_(programski_jezik)
# bug: bug - Python: https://bug.wikipedia.org/wiki/Python
# ca: ca - Python: https://ca.wikipedia.org/wiki/Python
# ceb: ceb - Python (programming language): https://ceb.wikipedia.org/wiki/Python_(programming_language)
# ckb: ckb - پایتن (زمانی پرۆگرامسازی): https://ckb.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%86_(%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D9%BE%D8%B1%DB%86%DA%AF%D8%B1%D8%A7%D9%85%D8%B3%D8%A7%D8%B2%DB%8C)
# cs: cs - Python: https://cs.wikipedia.org/wiki/Python
# cy: cy - Python (iaith raglennu): https://cy.wikipedia.org/wiki/Python_(iaith_raglennu)
# da: da - Python (programmeringssprog): https://da.wikipedia.org/wiki/Python_(programmeringssprog)
# de: de - Python (Programmiersprache): https://de.wikipedia.org/wiki/Python_(Programmiersprache)
# el: el - Python: https://el.wikipedia.org/wiki/Python
# eo: eo - Python (programlingvo): https://eo.wikipedia.org/wiki/Python_(programlingvo)
# es: es - Python: https://es.wikipedia.org/wiki/Python
# et: et - Python (programmeerimiskeel): https://et.wikipedia.org/wiki/Python_(programmeerimiskeel)
# eu: eu - Python (informatika): https://eu.wikipedia.org/wiki/Python_(informatika)
# fa: fa - پایتون (زبان برنامه‌نویسی): https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86_(%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C)
# fi: fi - Python (ohjelmointikieli): https://fi.wikipedia.org/wiki/Python_(ohjelmointikieli)
# fr: fr - Python (langage): https://fr.wikipedia.org/wiki/Python_(langage)
# gl: gl - Python: https://gl.wikipedia.org/wiki/Python
# gu: gu - પાયથોન(પ્રોગ્રામિંગ ભાષા): https://gu.wikipedia.org/wiki/%E0%AA%AA%E0%AA%BE%E0%AA%AF%E0%AA%A5%E0%AB%8B%E0%AA%A8(%E0%AA%AA%E0%AB%8D%E0%AA%B0%E0%AB%8B%E0%AA%97%E0%AB%8D%E0%AA%B0%E0%AA%BE%E0%AA%AE%E0%AA%BF%E0%AA%82%E0%AA%97_%E0%AA%AD%E0%AA%BE%E0%AA%B7%E0%AA%BE)
# he: he - פייתון: https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%99%D7%AA%D7%95%D7%9F
# hi: hi - पाइथन: https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8
# hr: hr - Python (programski jezik): https://hr.wikipedia.org/wiki/Python_(programski_jezik)
# hu: hu - Python (programozási nyelv): https://hu.wikipedia.org/wiki/Python_(programoz%C3%A1si_nyelv)
# hy: hy - Python: https://hy.wikipedia.org/wiki/Python
# ia: ia - Python (linguage de programmation): https://ia.wikipedia.org/wiki/Python_(linguage_de_programmation)
# id: id - Python (bahasa pemrograman): https://id.wikipedia.org/wiki/Python_(bahasa_pemrograman)
# is: is - Python (forritunarmál): https://is.wikipedia.org/wiki/Python_(forritunarm%C3%A1l)
# it: it - Python: https://it.wikipedia.org/wiki/Python
# ja: ja - Python: https://ja.wikipedia.org/wiki/Python
# jbo: jbo - paiton: https://jbo.wikipedia.org/wiki/paiton
# ka: ka - პითონი (პროგრამირების ენა): https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90)
# kk: kk - Python: https://kk.wikipedia.org/wiki/Python
# km: km - ផាយថុន: https://km.wikipedia.org/wiki/%E1%9E%95%E1%9E%B6%E1%9E%99%E1%9E%90%E1%9E%BB%E1%9E%93
# ko: ko - 파이썬: https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC
# ky: ky - Python: https://ky.wikipedia.org/wiki/Python
# la: la - Python (lingua programmandi): https://la.wikipedia.org/wiki/Python_(lingua_programmandi)
# lmo: lmo - Python: https://lmo.wikipedia.org/wiki/Python
# lt: lt - Python: https://lt.wikipedia.org/wiki/Python
# lv: lv - Python: https://lv.wikipedia.org/wiki/Python
# mk: mk - Пајтон (програмски јазик): https://mk.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA)
# ml: ml - പൈത്തൺ (പ്രോഗ്രാമിങ്ങ് ഭാഷ): https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%88%E0%B4%A4%E0%B5%8D%E0%B4%A4%E0%B5%BA_(%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%99%E0%B5%8D%E0%B4%99%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7)
# mn: mn - Python: https://mn.wikipedia.org/wiki/Python
# mr: mr - पायथॉन: https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8
# ms: ms - Python: https://ms.wikipedia.org/wiki/Python
# my: my - Python (programming language): https://my.wikipedia.org/wiki/Python_(programming_language)
# nds: nds - Python (Programmeerspraak): https://nds.wikipedia.org/wiki/Python_(Programmeerspraak)
# ne: ne - पाइथन प्रोग्रामिङ्ग भाषा: https://ne.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%87%E0%A4%A5%E0%A4%A8_%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%99%E0%A5%8D%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE
# nl: nl - Python (programmeertaal): https://nl.wikipedia.org/wiki/Python_(programmeertaal)
# nn: nn - Python: https://nn.wikipedia.org/wiki/Python
# no: no - Python: https://no.wikipedia.org/wiki/Python
# or: or - ପାଇଥନ୍ (ପ୍ରୋଗ୍ରାମିଂ ଭାଷା): https://or.wikipedia.org/wiki/%E0%AC%AA%E0%AC%BE%E0%AC%87%E0%AC%A5%E0%AC%A8%E0%AD%8D_(%E0%AC%AA%E0%AD%8D%E0%AC%B0%E0%AD%8B%E0%AC%97%E0%AD%8D%E0%AC%B0%E0%AC%BE%E0%AC%AE%E0%AC%BF%E0%AC%82_%E0%AC%AD%E0%AC%BE%E0%AC%B7%E0%AC%BE)
# pl: pl - Python: https://pl.wikipedia.org/wiki/Python
# pnb: pnb - پائیتھن (کمپیوٹر بولی): https://pnb.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%DA%A9%D9%85%D9%BE%DB%8C%D9%88%D9%B9%D8%B1_%D8%A8%D9%88%D9%84%DB%8C)
# pt: pt - Python: https://pt.wikipedia.org/wiki/Python
# ro: ro - Python: https://ro.wikipedia.org/wiki/Python
# ru: ru - Python: https://ru.wikipedia.org/wiki/Python
# sco: sco - Python (programmin leid): https://sco.wikipedia.org/wiki/Python_(programmin_leid)
# sh: sh - Python programski jezik: https://sh.wikipedia.org/wiki/Python_programski_jezik
# shn: shn - Python (programming language): https://shn.wikipedia.org/wiki/Python_(programming_language)
# si: si - පයිතන්: https://si.wikipedia.org/wiki/%E0%B6%B4%E0%B6%BA%E0%B7%92%E0%B6%AD%E0%B6%B1%E0%B7%8A
# simple: simple - Python (programming language): https://simple.wikipedia.org/wiki/Python_(programming_language)
# sk: sk - Python (programovací jazyk): https://sk.wikipedia.org/wiki/Python_(programovac%C3%AD_jazyk)
# sl: sl - Python (programski jezik): https://sl.wikipedia.org/wiki/Python_(programski_jezik)
# sq: sq - Python: https://sq.wikipedia.org/wiki/Python
# sr: sr - Пајтон (програмски језик): https://sr.wikipedia.org/wiki/%D0%9F%D0%B0%D1%98%D1%82%D0%BE%D0%BD_(%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA)
# sv: sv - Python (programspråk): https://sv.wikipedia.org/wiki/Python_(programspr%C3%A5k)
# ta: ta - பைத்தான்: https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AF%88%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AE%BE%E0%AE%A9%E0%AF%8D
# te: te - పైథాన్ (కంప్యూటర్ భాష): https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%88%E0%B0%A5%E0%B0%BE%E0%B0%A8%E0%B1%8D_(%E0%B0%95%E0%B0%82%E0%B0%AA%E0%B1%8D%E0%B0%AF%E0%B1%82%E0%B0%9F%E0%B0%B0%E0%B1%8D_%E0%B0%AD%E0%B0%BE%E0%B0%B7)
# tg: tg - Python: https://tg.wikipedia.org/wiki/Python
# th: th - ภาษาไพทอน: https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99
# tl: tl - Python (wikang pamprograma): https://tl.wikipedia.org/wiki/Python_(wikang_pamprograma)
# tr: tr - Python (programlama dili): https://tr.wikipedia.org/wiki/Python_(programlama_dili)
# tt: tt - Python: https://tt.wikipedia.org/wiki/Python
# uk: uk - Python: https://uk.wikipedia.org/wiki/Python
# ur: ur - پائیتھن (پروگرامنگ زبان): https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%86_(%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%86%DA%AF_%D8%B2%D8%A8%D8%A7%D9%86)
# uz: uz - Python: https://uz.wikipedia.org/wiki/Python
# vi: vi - Python (ngôn ngữ lập trình): https://vi.wikipedia.org/wiki/Python_(ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh)
# war: war - Python (programming language): https://war.wikipedia.org/wiki/Python_(programming_language)
# wuu: wuu - Python: https://wuu.wikipedia.org/wiki/Python
# zh: zh - Python: https://zh.wikipedia.org/wiki/Python
# zh-min-nan: zh-min-nan - Python: https://zh-min-nan.wikipedia.org/wiki/Python
# zh-yue: zh-yue - Python: https://zh-yue.wikipedia.org/wiki/Python
# Page - Summary: Python (anglická výslovnost [ˈpaiθən]) je vysokoúrovňový skr

# %%
def print_links(page):
        links = page.links
        for title in sorted(links.keys()):
            print("%s: %s" % (title, links[title]))

print_links(page_py)
# 3ds Max: 3ds Max (id: ??, ns: 0)
# ?:: ?: (id: ??, ns: 0)
# ABC (programming language): ABC (programming language) (id: ??, ns: 0)
# ALGOL 68: ALGOL 68 (id: ??, ns: 0)
# Abaqus: Abaqus (id: ??, ns: 0)
# ...
# Out:
# 3ds Max: 3ds Max (id: ??, ns: 0)
# ?:: ?: (id: ??, ns: 0)
# ABC (programming language): ABC (programming language) (id: ??, ns: 0)
# ALGOL 68: ALGOL 68 (id: ??, ns: 0)
# APL (programming language): APL (programming language) (id: ??, ns: 0)
# Abaqus: Abaqus (id: ??, ns: 0)
# Academic Free License: Academic Free License (id: ??, ns: 0)
# Academic conference: Academic conference (id: ??, ns: 0)
# Alex Martelli: Alex Martelli (id: ??, ns: 0)
# Algebra: Algebra (id: ??, ns: 0)
# Alternative terms for free software: Alternative terms for free software (id: ??, ns: 0)
# Amazon (company): Amazon (company) (id: ??, ns: 0)
# AmigaOS 4: AmigaOS 4 (id: ??, ns: 0)
# Amoeba (operating system): Amoeba (operating system) (id: ??, ns: 0)
# Anaconda (installer): Anaconda (installer) (id: ??, ns: 0)
# Anonymous function: Anonymous function (id: ??, ns: 0)
# Apache Groovy: Apache Groovy (id: ??, ns: 0)
# Apache License: Apache License (id: ??, ns: 0)
# Apache web server: Apache web server (id: ??, ns: 0)
# Aphorism: Aphorism (id: ??, ns: 0)
# Apple Public Source License: Apple Public Source License (id: ??, ns: 0)
# ArXiv: ArXiv (id: ??, ns: 0)
# Arbitrary precision arithmetic: Arbitrary precision arithmetic (id: ??, ns: 0)
# ArcGIS: ArcGIS (id: ??, ns: 0)
# Array index: Array index (id: ??, ns: 0)
# Array slicing: Array slicing (id: ??, ns: 0)
# Artificial intelligence: Artificial intelligence (id: ??, ns: 0)
# Artistic License: Artistic License (id: ??, ns: 0)
# Aspect-oriented programming: Aspect-oriented programming (id: ??, ns: 0)
# Assembly language: Assembly language (id: ??, ns: 0)
# Assertion (programming): Assertion (programming) (id: ??, ns: 0)
# Associative array: Associative array (id: ??, ns: 0)
# Astropy: Astropy (id: ??, ns: 0)
# Autodesk Softimage: Autodesk Softimage (id: ??, ns: 0)
# BASIC: BASIC (id: ??, ns: 0)
# BSD licenses: BSD licenses (id: ??, ns: 0)
# Backporting: Backporting (id: ??, ns: 0)
# Backward compatibility: Backward compatibility (id: ??, ns: 0)
# Bazel (software): Bazel (software) (id: ??, ns: 0)
# Beerware: Beerware (id: ??, ns: 0)
# Benevolent Dictator For Life: Benevolent Dictator For Life (id: ??, ns: 0)
# Beta release: Beta release (id: ??, ns: 0)
# Bibcode: Bibcode (id: ??, ns: 0)
# Bibliothèque nationale de France: Bibliothèque nationale de France (id: ??, ns: 0)
# Biopython: Biopython (id: ??, ns: 0)
# Blender (software): Blender (software) (id: ??, ns: 0)
# Block (programming): Block (programming) (id: ??, ns: 0)
# Boo (programming language): Boo (programming language) (id: ??, ns: 0)
# Book:Free and Open Source Software: Book:Free and Open Source Software (id: ??, ns: 108)
# Boolean value: Boolean value (id: ??, ns: 0)
# Boost Software License: Boost Software License (id: ??, ns: 0)
# Bottle (web framework): Bottle (web framework) (id: ??, ns: 0)
# Bug tracker: Bug tracker (id: ??, ns: 0)
# BuildBot: BuildBot (id: ??, ns: 0)
# Byte: Byte (id: ??, ns: 0)
# Bytecode: Bytecode (id: ??, ns: 0)
# C (programming language): C (programming language) (id: ??, ns: 0)
# C Sharp (programming language): C Sharp (programming language) (id: ??, ns: 0)
# C++: C++ (id: ??, ns: 0)
# C89 (C version): C89 (C version) (id: ??, ns: 0)
# C99: C99 (id: ??, ns: 0)
# CCP Games: CCP Games (id: ??, ns: 0)
# CERN: CERN (id: ??, ns: 0)
# CLPython: CLPython (id: ??, ns: 0)
# CLU (programming language): CLU (programming language) (id: ??, ns: 0)
# COBOL: COBOL (id: ??, ns: 0)
# CPython: CPython (id: ??, ns: 0)
# Calculus: Calculus (id: ??, ns: 0)
# Capella (notation program): Capella (notation program) (id: ??, ns: 0)
# Category:Articles containing potentially dated statements from August 2016: Category:Articles containing potentially dated statements from August 2016 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from December 2018: Category:Articles containing potentially dated statements from December 2018 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from March 2018: Category:Articles containing potentially dated statements from March 2018 (id: ??, ns: 14)
# Category:Free software: Category:Free software (id: ??, ns: 14)
# Category:Programming languages: Category:Programming languages (id: ??, ns: 14)
# Category:Python web frameworks: Category:Python web frameworks (id: ??, ns: 14)
# Category:Use dmy dates from August 2015: Category:Use dmy dates from August 2015 (id: ??, ns: 14)
# Category:Wikipedia articles with BNF identifiers: Category:Wikipedia articles with BNF identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with GND identifiers: Category:Wikipedia articles with GND identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with LCCN identifiers: Category:Wikipedia articles with LCCN identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with SUDOC identifiers: Category:Wikipedia articles with SUDOC identifiers (id: ??, ns: 14)
# Centrum Wiskunde & Informatica: Centrum Wiskunde & Informatica (id: ??, ns: 0)
# Character string: Character string (id: ??, ns: 0)
# CherryPy: CherryPy (id: ??, ns: 0)
# Chris Lattner: Chris Lattner (id: ??, ns: 0)
# Cinema 4D: Cinema 4D (id: ??, ns: 0)
# CircuitPython: CircuitPython (id: ??, ns: 0)
# CiteSeerX: CiteSeerX (id: ??, ns: 0)
# Class (computer science): Class (computer science) (id: ??, ns: 0)
# Cobra (programming language): Cobra (programming language) (id: ??, ns: 0)
# Code readability: Code readability (id: ??, ns: 0)
# CoffeeScript: CoffeeScript (id: ??, ns: 0)
# Combinatorics: Combinatorics (id: ??, ns: 0)
# Command line interpreter: Command line interpreter (id: ??, ns: 0)
# Common Development and Distribution License: Common Development and Distribution License (id: ??, ns: 0)
# Common Intermediate Language: Common Intermediate Language (id: ??, ns: 0)
# Common Language Runtime: Common Language Runtime (id: ??, ns: 0)
# Common Lisp: Common Lisp (id: ??, ns: 0)
# Community of practice: Community of practice (id: ??, ns: 0)
# Comparison of free and open-source software licenses: Comparison of free and open-source software licenses (id: ??, ns: 0)
# Comparison of free geophysics software: Comparison of free geophysics software (id: ??, ns: 0)
# Comparison of free software for audio: Comparison of free software for audio (id: ??, ns: 0)
# Comparison of integrated development environments: Comparison of integrated development environments (id: ??, ns: 0)
# Comparison of open-source and closed-source software: Comparison of open-source and closed-source software (id: ??, ns: 0)
# Comparison of open-source configuration management software: Comparison of open-source configuration management software (id: ??, ns: 0)
# Comparison of open-source operating systems: Comparison of open-source operating systems (id: ??, ns: 0)
# Comparison of open-source programming language licensing: Comparison of open-source programming language licensing (id: ??, ns: 0)
# Comparison of open-source wireless drivers: Comparison of open-source wireless drivers (id: ??, ns: 0)
# Comparison of programming languages: Comparison of programming languages (id: ??, ns: 0)
# Comparison of shopping cart software: Comparison of shopping cart software (id: ??, ns: 0)
# Comparison of source-code-hosting facilities: Comparison of source-code-hosting facilities (id: ??, ns: 0)
# Compile time: Compile time (id: ??, ns: 0)
# Complex number: Complex number (id: ??, ns: 0)
# Computer file: Computer file (id: ??, ns: 0)
# Conditional (programming): Conditional (programming) (id: ??, ns: 0)
# Continuous integration: Continuous integration (id: ??, ns: 0)
# Contributor License Agreement: Contributor License Agreement (id: ??, ns: 0)
# Copyleft: Copyleft (id: ??, ns: 0)
# Coroutine: Coroutine (id: ??, ns: 0)
# Creative Commons license: Creative Commons license (id: ??, ns: 0)
# Curlie: Curlie (id: ??, ns: 0)
# Curly bracket programming language: Curly bracket programming language (id: ??, ns: 0)
# Cycle detection: Cycle detection (id: ??, ns: 0)
# Cython: Cython (id: ??, ns: 0)
# D (programming language): D (programming language) (id: ??, ns: 0)
# Data mapper pattern: Data mapper pattern (id: ??, ns: 0)
# Data type: Data type (id: ??, ns: 0)
# Debian Free Software Guidelines: Debian Free Software Guidelines (id: ??, ns: 0)
# Definition of Free Cultural Works: Definition of Free Cultural Works (id: ??, ns: 0)
# Design by contract: Design by contract (id: ??, ns: 0)
# Device driver: Device driver (id: ??, ns: 0)
# Digital object identifier: Digital object identifier (id: ??, ns: 0)
# Digital rights management: Digital rights management (id: ??, ns: 0)
# Django (web framework): Django (web framework) (id: ??, ns: 0)
# Dragon (programming language): Dragon (programming language) (id: ??, ns: 0)
# Dropbox (service): Dropbox (service) (id: ??, ns: 0)
# Duck typing: Duck typing (id: ??, ns: 0)
# Dylan (programming language): Dylan (programming language) (id: ??, ns: 0)
# Dynamic programming language: Dynamic programming language (id: ??, ns: 0)
# Dynamic type: Dynamic type (id: ??, ns: 0)
# Dynamic typing: Dynamic typing (id: ??, ns: 0)
# ECMAScript: ECMAScript (id: ??, ns: 0)
# Eclipse Public License: Eclipse Public License (id: ??, ns: 0)
# Elixir (programming language): Elixir (programming language) (id: ??, ns: 0)
# Ellipsis (programming operator): Ellipsis (programming operator) (id: ??, ns: 0)
# End-of-life (product): End-of-life (product) (id: ??, ns: 0)
# Epydoc: Epydoc (id: ??, ns: 0)
# Eric Python IDE: Eric Python IDE (id: ??, ns: 0)
# Erlang (programming language): Erlang (programming language) (id: ??, ns: 0)
# Escape character: Escape character (id: ??, ns: 0)
# Esri: Esri (id: ??, ns: 0)
# Exception handling: Exception handling (id: ??, ns: 0)
# Exception handling syntax: Exception handling syntax (id: ??, ns: 0)
# Expression (computer science): Expression (computer science) (id: ??, ns: 0)
# Extensibility: Extensibility (id: ??, ns: 0)
# F Sharp (programming language): F Sharp (programming language) (id: ??, ns: 0)
# Facebook: Facebook (id: ??, ns: 0)
# Fedora (operating system): Fedora (operating system) (id: ??, ns: 0)
# Filename extension: Filename extension (id: ??, ns: 0)
# Finite element method: Finite element method (id: ??, ns: 0)
# Firaxis Games: Firaxis Games (id: ??, ns: 0)
# Firmware: Firmware (id: ??, ns: 0)
# First-class continuations: First-class continuations (id: ??, ns: 0)
# Flask (web framework): Flask (web framework) (id: ??, ns: 0)
# Floating point: Floating point (id: ??, ns: 0)
# Foobar: Foobar (id: ??, ns: 0)
# Foreach: Foreach (id: ??, ns: 0)
# Fork (software development): Fork (software development) (id: ??, ns: 0)
# Fortran: Fortran (id: ??, ns: 0)
# Free Software Foundation: Free Software Foundation (id: ??, ns: 0)
# Free and open-source graphics device driver: Free and open-source graphics device driver (id: ??, ns: 0)
# Free and open-source software: Free and open-source software (id: ??, ns: 0)
# Free license: Free license (id: ??, ns: 0)
# Free software: Free software (id: ??, ns: 0)
# Free software license: Free software license (id: ??, ns: 0)
# Free software movement: Free software movement (id: ??, ns: 0)
# FreeBSD: FreeBSD (id: ??, ns: 0)
# FreeCAD: FreeCAD (id: ??, ns: 0)
# Function (computing): Function (computing) (id: ??, ns: 0)
# Function (programming): Function (programming) (id: ??, ns: 0)
# Functional programming: Functional programming (id: ??, ns: 0)
# GIMP: GIMP (id: ??, ns: 0)
# GNU Debugger: GNU Debugger (id: ??, ns: 0)
# GNU General Public License: GNU General Public License (id: ??, ns: 0)
# GNU Lesser General Public License: GNU Lesser General Public License (id: ??, ns: 0)
# GNU Manifesto: GNU Manifesto (id: ??, ns: 0)
# GTK: GTK (id: ??, ns: 0)
# Garbage collection (computer science): Garbage collection (computer science) (id: ??, ns: 0)
# Gdscript: Gdscript (id: ??, ns: 0)
# General-purpose programming language: General-purpose programming language (id: ??, ns: 0)
# Generational list of programming languages: Generational list of programming languages (id: ??, ns: 0)
# Generator (computer programming): Generator (computer programming) (id: ??, ns: 0)
# Generator (computer science): Generator (computer science) (id: ??, ns: 0)
# Genie (programming language): Genie (programming language) (id: ??, ns: 0)
# Gentoo Linux: Gentoo Linux (id: ??, ns: 0)
# GitHub: GitHub (id: ??, ns: 0)
# Go (programming language): Go (programming language) (id: ??, ns: 0)
# Google: Google (id: ??, ns: 0)
# Google App Engine: Google App Engine (id: ??, ns: 0)
# Gradual typing: Gradual typing (id: ??, ns: 0)
# Graphical user interface: Graphical user interface (id: ??, ns: 0)
# Gratis versus libre: Gratis versus libre (id: ??, ns: 0)
# Grok (web framework): Grok (web framework) (id: ??, ns: 0)
# Groovy (programming language): Groovy (programming language) (id: ??, ns: 0)
# Guido van Rossum: Guido van Rossum (id: ??, ns: 0)
# Half-open interval: Half-open interval (id: ??, ns: 0)
# Hardware restriction: Hardware restriction (id: ??, ns: 0)
# Haskell (programming language): Haskell (programming language) (id: ??, ns: 0)
# HeaderDoc: HeaderDoc (id: ??, ns: 0)
# Help:Authority control: Help:Authority control (id: ??, ns: 12)
# Here document: Here document (id: ??, ns: 0)
# High-level programming language: High-level programming language (id: ??, ns: 0)
# History of Python: History of Python (id: ??, ns: 0)
# History of free and open-source software: History of free and open-source software (id: ??, ns: 0)
# History of programming languages: History of programming languages (id: ??, ns: 0)
# Houdini (software): Houdini (software) (id: ??, ns: 0)
# Hygienic macro: Hygienic macro (id: ??, ns: 0)
# Hypertext Transfer Protocol: Hypertext Transfer Protocol (id: ??, ns: 0)
# IDLE (Python): IDLE (Python) (id: ??, ns: 0)
# IPython: IPython (id: ??, ns: 0)
# ISC license: ISC license (id: ??, ns: 0)
# ITA Software: ITA Software (id: ??, ns: 0)
# Icon (programming language): Icon (programming language) (id: ??, ns: 0)
# If-then-else: If-then-else (id: ??, ns: 0)
# Immutable: Immutable (id: ??, ns: 0)
# Immutable object: Immutable object (id: ??, ns: 0)
# Imperative programming: Imperative programming (id: ??, ns: 0)
# Industrial Light & Magic: Industrial Light & Magic (id: ??, ns: 0)
# Information security: Information security (id: ??, ns: 0)
# Inkscape: Inkscape (id: ??, ns: 0)
# Instagram: Instagram (id: ??, ns: 0)
# Instance data: Instance data (id: ??, ns: 0)
# Integer (computer science): Integer (computer science) (id: ??, ns: 0)
# Integrated Authority File: Integrated Authority File (id: ??, ns: 0)
# Integrated development environment: Integrated development environment (id: ??, ns: 0)
# International Standard Book Number: International Standard Book Number (id: ??, ns: 0)
# Interpreted language: Interpreted language (id: ??, ns: 0)
# Interpreter (computing): Interpreter (computing) (id: ??, ns: 0)
# IronPython: IronPython (id: ??, ns: 0)
# Iterator: Iterator (id: ??, ns: 0)
# Java (programming language): Java (programming language) (id: ??, ns: 0)
# Java (software platform): Java (software platform) (id: ??, ns: 0)
# Java bytecode: Java bytecode (id: ??, ns: 0)
# Java virtual machine: Java virtual machine (id: ??, ns: 0)
# JavaScript: JavaScript (id: ??, ns: 0)
# Jeff Dean (computer scientist): Jeff Dean (computer scientist) (id: ??, ns: 0)
# Julia (programming language): Julia (programming language) (id: ??, ns: 0)
# Just-in-time compilation: Just-in-time compilation (id: ??, ns: 0)
# Jython: Jython (id: ??, ns: 0)
# Keras: Keras (id: ??, ns: 0)
# Kotlin (programming language): Kotlin (programming language) (id: ??, ns: 0)
# LLVM: LLVM (id: ??, ns: 0)
# Lambda (programming): Lambda (programming) (id: ??, ns: 0)
# Language binding: Language binding (id: ??, ns: 0)
# Late binding: Late binding (id: ??, ns: 0)
# Lazy evaluation: Lazy evaluation (id: ??, ns: 0)
# Lego Mindstorms EV3: Lego Mindstorms EV3 (id: ??, ns: 0)
# Library of Congress Control Number: Library of Congress Control Number (id: ??, ns: 0)
# LibreOffice: LibreOffice (id: ??, ns: 0)
# License proliferation: License proliferation (id: ??, ns: 0)
# Lightwave: Lightwave (id: ??, ns: 0)
# Linux distribution: Linux distribution (id: ??, ns: 0)
# Lisp (programming language): Lisp (programming language) (id: ??, ns: 0)
# List (computer science): List (computer science) (id: ??, ns: 0)
# List comprehension: List comprehension (id: ??, ns: 0)
# List comprehensions: List comprehensions (id: ??, ns: 0)
# List of Python software: List of Python software (id: ??, ns: 0)
# List of collaborative software: List of collaborative software (id: ??, ns: 0)
# List of commercial open-source applications and services: List of commercial open-source applications and services (id: ??, ns: 0)
# List of content management systems: List of content management systems (id: ??, ns: 0)
# List of formerly proprietary software: List of formerly proprietary software (id: ??, ns: 0)
# List of free and open-source Android applications: List of free and open-source Android applications (id: ??, ns: 0)
# List of free and open-source iOS applications: List of free and open-source iOS applications (id: ??, ns: 0)
# List of free and open-source software organizations: List of free and open-source software organizations (id: ??, ns: 0)
# List of free and open-source software packages: List of free and open-source software packages (id: ??, ns: 0)
# List of free and open-source web applications: List of free and open-source web applications (id: ??, ns: 0)
# List of free software project directories: List of free software project directories (id: ??, ns: 0)
# List of free television software: List of free television software (id: ??, ns: 0)
# List of free-software events: List of free-software events (id: ??, ns: 0)
# List of integrated development environments for Python: List of integrated development environments for Python (id: ??, ns: 0)
# List of open-source bioinformatics software: List of open-source bioinformatics software (id: ??, ns: 0)
# List of open-source codecs: List of open-source codecs (id: ??, ns: 0)
# List of open-source health software: List of open-source health software (id: ??, ns: 0)
# List of open-source routing platforms: List of open-source routing platforms (id: ??, ns: 0)
# List of open-source software for mathematics: List of open-source software for mathematics (id: ??, ns: 0)
# List of open-source video games: List of open-source video games (id: ??, ns: 0)
# List of programming languages: List of programming languages (id: ??, ns: 0)
# List of programming languages by type: List of programming languages by type (id: ??, ns: 0)
# List of statistical packages: List of statistical packages (id: ??, ns: 0)
# List of trademarked open-source software: List of trademarked open-source software (id: ??, ns: 0)
# List of word processors: List of word processors (id: ??, ns: 0)
# Lock (computer science): Lock (computer science) (id: ??, ns: 0)
# Logic programming: Logic programming (id: ??, ns: 0)
# Long-term support: Long-term support (id: ??, ns: 0)
# Lua (programming language): Lua (programming language) (id: ??, ns: 0)
# MATLAB: MATLAB (id: ??, ns: 0)
# MIME: MIME (id: ??, ns: 0)
# MIT License: MIT License (id: ??, ns: 0)
# MacOS: MacOS (id: ??, ns: 0)
# Mathematical software: Mathematical software (id: ??, ns: 0)
# Mathematics: Mathematics (id: ??, ns: 0)
# Matplotlib: Matplotlib (id: ??, ns: 0)
# Matrix multiplication: Matrix multiplication (id: ??, ns: 0)
# Maya (software): Maya (software) (id: ??, ns: 0)
# Memory allocation: Memory allocation (id: ??, ns: 0)
# Memory management: Memory management (id: ??, ns: 0)
# Mercurial: Mercurial (id: ??, ns: 0)
# Metaclass: Metaclass (id: ??, ns: 0)
# Metaobject: Metaobject (id: ??, ns: 0)
# Metaprogramming: Metaprogramming (id: ??, ns: 0)
# Metasyntactic variable: Metasyntactic variable (id: ??, ns: 0)
# Method (computing): Method (computing) (id: ??, ns: 0)
# Method (programming): Method (programming) (id: ??, ns: 0)
# MicroPython: MicroPython (id: ??, ns: 0)
# Microcontroller: Microcontroller (id: ??, ns: 0)
# Microsoft Open Specification Promise: Microsoft Open Specification Promise (id: ??, ns: 0)
# Microsoft Windows: Microsoft Windows (id: ??, ns: 0)
# Microthread: Microthread (id: ??, ns: 0)
# Mod wsgi: Mod wsgi (id: ??, ns: 0)
# Modo (software): Modo (software) (id: ??, ns: 0)
# Modula-3: Modula-3 (id: ??, ns: 0)
# Modular programming: Modular programming (id: ??, ns: 0)
# Monty Python: Monty Python (id: ??, ns: 0)
# MotionBuilder: MotionBuilder (id: ??, ns: 0)
# Mozilla Public License: Mozilla Public License (id: ??, ns: 0)
# Mozilla software rebranded by Debian: Mozilla software rebranded by Debian (id: ??, ns: 0)
# Multi-paradigm programming language: Multi-paradigm programming language (id: ??, ns: 0)
# Musical notation: Musical notation (id: ??, ns: 0)
# MyHDL: MyHDL (id: ??, ns: 0)
# N900: N900 (id: ??, ns: 0)
# NASA: NASA (id: ??, ns: 0)
# NOP (code): NOP (code) (id: ??, ns: 0)
# Nagare (web framework): Nagare (web framework) (id: ??, ns: 0)
# Name resolution (programming languages): Name resolution (programming languages) (id: ??, ns: 0)
# Natural language processing: Natural language processing (id: ??, ns: 0)
# Neologism: Neologism (id: ??, ns: 0)
# NetBSD: NetBSD (id: ??, ns: 0)
# Netherlands: Netherlands (id: ??, ns: 0)
# Nevow: Nevow (id: ??, ns: 0)
# Nim (programming language): Nim (programming language) (id: ??, ns: 0)
# Ninja-IDE: Ninja-IDE (id: ??, ns: 0)
# Nokia: Nokia (id: ??, ns: 0)
# Non-English-based programming languages: Non-English-based programming languages (id: ??, ns: 0)
# Nonprofit organization: Nonprofit organization (id: ??, ns: 0)
# Notebook interface: Notebook interface (id: ??, ns: 0)
# Nuitka: Nuitka (id: ??, ns: 0)
# Nuke (software): Nuke (software) (id: ??, ns: 0)
# NumPy: NumPy (id: ??, ns: 0)
# Numba: Numba (id: ??, ns: 0)
# Number theory: Number theory (id: ??, ns: 0)
# Numerical mathematics: Numerical mathematics (id: ??, ns: 0)
# O'Reilly Media: O'Reilly Media (id: ??, ns: 0)
# OCaml: OCaml (id: ??, ns: 0)
# Object (computer science): Object (computer science) (id: ??, ns: 0)
# Object language: Object language (id: ??, ns: 0)
# Object-oriented programming: Object-oriented programming (id: ??, ns: 0)
# Objective-C: Objective-C (id: ??, ns: 0)
# Off-side rule: Off-side rule (id: ??, ns: 0)
# One Laptop per Child: One Laptop per Child (id: ??, ns: 0)
# Open-core model: Open-core model (id: ??, ns: 0)
# Open-source hardware: Open-source hardware (id: ??, ns: 0)
# Open-source license: Open-source license (id: ??, ns: 0)
# Open-source software: Open-source software (id: ??, ns: 0)
# Open-source software development: Open-source software development (id: ??, ns: 0)
# Open-source software security: Open-source software security (id: ??, ns: 0)
# Open-source-software movement: Open-source-software movement (id: ??, ns: 0)
# OpenBSD: OpenBSD (id: ??, ns: 0)
# Operating system: Operating system (id: ??, ns: 0)
# Operator overloading: Operator overloading (id: ??, ns: 0)
# Oracle Corporation: Oracle Corporation (id: ??, ns: 0)
# Outline of free software: Outline of free software (id: ??, ns: 0)
# PHP: PHP (id: ??, ns: 0)
# Package management system: Package management system (id: ??, ns: 0)
# Paint Shop Pro: Paint Shop Pro (id: ??, ns: 0)
# Pascal (programming language): Pascal (programming language) (id: ??, ns: 0)
# Perl: Perl (id: ??, ns: 0)
# Permissive software license: Permissive software license (id: ??, ns: 0)
# Peter Norvig: Peter Norvig (id: ??, ns: 0)
# Pip (package manager): Pip (package manager) (id: ??, ns: 0)
# Pointer (computer programming): Pointer (computer programming) (id: ??, ns: 0)
# Portage (software): Portage (software) (id: ??, ns: 0)
# Portal:Computer programming: Portal:Computer programming (id: ??, ns: 100)
# Portal:Free and open-source software: Portal:Free and open-source software (id: ??, ns: 100)
# Portal:Python: Portal:Python (id: ??, ns: 100)
# Ported: Ported (id: ??, ns: 0)
# Premature optimization: Premature optimization (id: ??, ns: 0)
# Prettyprint: Prettyprint (id: ??, ns: 0)
# Printf: Printf (id: ??, ns: 0)
# Procedural programming: Procedural programming (id: ??, ns: 0)
# Programming language: Programming language (id: ??, ns: 0)
# Programming language implementation: Programming language implementation (id: ??, ns: 0)
# Programming paradigm: Programming paradigm (id: ??, ns: 0)
# Proprietary device driver: Proprietary device driver (id: ??, ns: 0)
# Proprietary firmware: Proprietary firmware (id: ??, ns: 0)
# Proprietary software: Proprietary software (id: ??, ns: 0)
# Pseudorandom number generator: Pseudorandom number generator (id: ??, ns: 0)
# Psyco: Psyco (id: ??, ns: 0)
# Public domain: Public domain (id: ??, ns: 0)
# PyCharm: PyCharm (id: ??, ns: 0)
# PyCon: PyCon (id: ??, ns: 0)
# PyDev: PyDev (id: ??, ns: 0)
# PyGTK: PyGTK (id: ??, ns: 0)
# PyPy: PyPy (id: ??, ns: 0)
# PyQt: PyQt (id: ??, ns: 0)
# PyS60: PyS60 (id: ??, ns: 0)
# Pydoc: Pydoc (id: ??, ns: 0)
# Pygame: Pygame (id: ??, ns: 0)
# Pyjs: Pyjs (id: ??, ns: 0)
# Pyladies: Pyladies (id: ??, ns: 0)
# Pylons (web framework): Pylons (web framework) (id: ??, ns: 0)
# Pylons project: Pylons project (id: ??, ns: 0)
# Pyramid (web framework): Pyramid (web framework) (id: ??, ns: 0)
# Pyrex (programming language): Pyrex (programming language) (id: ??, ns: 0)
# Python: Python (id: ??, ns: 0)
# Python Conference: Python Conference (id: ??, ns: 0)
# Python License: Python License (id: ??, ns: 0)
# Python Package Index: Python Package Index (id: ??, ns: 0)
# Python Software Foundation: Python Software Foundation (id: ??, ns: 0)
# Python Software Foundation License: Python Software Foundation License (id: ??, ns: 0)
# Python for S60: Python for S60 (id: ??, ns: 0)
# Python syntax and semantics: Python syntax and semantics (id: ??, ns: 0)
# PythonAnywhere: PythonAnywhere (id: ??, ns: 0)
# Qt (software): Qt (software) (id: ??, ns: 0)
# Quixote (web framework): Quixote (web framework) (id: ??, ns: 0)
# R (programming language): R (programming language) (id: ??, ns: 0)
# RPython: RPython (id: ??, ns: 0)
# Raspberry Pi: Raspberry Pi (id: ??, ns: 0)
# Raw string: Raw string (id: ??, ns: 0)
# Read–eval–print loop: Read–eval–print loop (id: ??, ns: 0)
# Red Hat Linux: Red Hat Linux (id: ??, ns: 0)
# Reddit: Reddit (id: ??, ns: 0)
# Reference counting: Reference counting (id: ??, ns: 0)
# Reference cycle: Reference cycle (id: ??, ns: 0)
# Reference implementation: Reference implementation (id: ??, ns: 0)
# Reflection (computer science): Reflection (computer science) (id: ??, ns: 0)
# Reflective programming: Reflective programming (id: ??, ns: 0)
# Regular expression: Regular expression (id: ??, ns: 0)
# Relational database: Relational database (id: ??, ns: 0)
# Resource Acquisition Is Initialization: Resource Acquisition Is Initialization (id: ??, ns: 0)
# Revolution OS: Revolution OS (id: ??, ns: 0)
# Ring (programming language): Ring (programming language) (id: ??, ns: 0)
# Ring-lang: Ring-lang (id: ??, ns: 0)
# Round to even: Round to even (id: ??, ns: 0)
# Rounding: Rounding (id: ??, ns: 0)
# Roundup (issue tracker): Roundup (issue tracker) (id: ??, ns: 0)
# Ruby (programming language): Ruby (programming language) (id: ??, ns: 0)
# Run-time algorithm specialisation: Run-time algorithm specialisation (id: ??, ns: 0)
# Rust (programming language): Rust (programming language) (id: ??, ns: 0)
# SCO–Linux disputes: SCO–Linux disputes (id: ??, ns: 0)
# SETL: SETL (id: ??, ns: 0)
# SQLAlchemy: SQLAlchemy (id: ??, ns: 0)
# SageMath: SageMath (id: ??, ns: 0)
# Scala (programming language): Scala (programming language) (id: ??, ns: 0)
# Scheme (programming language): Scheme (programming language) (id: ??, ns: 0)
# SciPy: SciPy (id: ??, ns: 0)
# Scientific computing: Scientific computing (id: ??, ns: 0)
# Scikit-learn: Scikit-learn (id: ??, ns: 0)
# Scorewriter: Scorewriter (id: ??, ns: 0)
# Scribus: Scribus (id: ??, ns: 0)
# Scripting language: Scripting language (id: ??, ns: 0)
# Self-hosting (web services): Self-hosting (web services) (id: ??, ns: 0)
# Series 60: Series 60 (id: ??, ns: 0)
# Set (computer science): Set (computer science) (id: ??, ns: 0)
# Shallow copy: Shallow copy (id: ??, ns: 0)
# Shared Source Initiative: Shared Source Initiative (id: ??, ns: 0)
# Shed Skin: Shed Skin (id: ??, ns: 0)
# Shell script: Shell script (id: ??, ns: 0)
# Simple DirectMedia Layer: Simple DirectMedia Layer (id: ??, ns: 0)
# Single-board computer: Single-board computer (id: ??, ns: 0)
# Sleepycat License: Sleepycat License (id: ??, ns: 0)
# Smalltalk: Smalltalk (id: ??, ns: 0)
# Software design: Software design (id: ??, ns: 0)
# Software developer: Software developer (id: ??, ns: 0)
# Software license: Software license (id: ??, ns: 0)
# Software patents and free software: Software patents and free software (id: ??, ns: 0)
# Software release life cycle: Software release life cycle (id: ??, ns: 0)
# Source-available software: Source-available software (id: ??, ns: 0)
# Spam (Monty Python): Spam (Monty Python) (id: ??, ns: 0)
# Sphinx (documentation generator): Sphinx (documentation generator) (id: ??, ns: 0)
# Spotify: Spotify (id: ??, ns: 0)
# Spyce (software): Spyce (software) (id: ??, ns: 0)
# Stack Overflow: Stack Overflow (id: ??, ns: 0)
# Stackless Python: Stackless Python (id: ??, ns: 0)
# Standard ML: Standard ML (id: ??, ns: 0)
# Standard library: Standard library (id: ??, ns: 0)
# Stani's Python Editor: Stani's Python Editor (id: ??, ns: 0)
# Statement (computer science): Statement (computer science) (id: ??, ns: 0)
# Static typing: Static typing (id: ??, ns: 0)
# String interpolation: String interpolation (id: ??, ns: 0)
# String literal: String literal (id: ??, ns: 0)
# Strongly typed programming language: Strongly typed programming language (id: ??, ns: 0)
# Structured programming: Structured programming (id: ??, ns: 0)
# Stuart J. Russell: Stuart J. Russell (id: ??, ns: 0)
# Sugar (software): Sugar (software) (id: ??, ns: 0)
# Sugar Labs: Sugar Labs (id: ??, ns: 0)
# Swift (programming language): Swift (programming language) (id: ??, ns: 0)
# Symbian: Symbian (id: ??, ns: 0)
# Syntactic sugar: Syntactic sugar (id: ??, ns: 0)
# Syntax highlighting: Syntax highlighting (id: ??, ns: 0)
# Système universitaire de documentation: Système universitaire de documentation (id: ??, ns: 0)
# TACTIC (web framework): TACTIC (web framework) (id: ??, ns: 0)
# TIOBE Programming Community Index: TIOBE Programming Community Index (id: ??, ns: 0)
# TIOBE index: TIOBE index (id: ??, ns: 0)
# Tail call: Tail call (id: ??, ns: 0)
# Tcl: Tcl (id: ??, ns: 0)
# Template talk:FOSS: Template talk:FOSS (id: ??, ns: 11)
# Template talk:Programming languages: Template talk:Programming languages (id: ??, ns: 11)
# Template talk:Python (programming language): Template talk:Python (programming language) (id: ??, ns: 11)
# Template talk:Python web frameworks: Template talk:Python web frameworks (id: ??, ns: 11)
# Template:FOSS: Template:FOSS (id: ??, ns: 10)
# Template:Latest preview software release/Python: Template:Latest preview software release/Python (id: ??, ns: 10)
# Template:Latest stable software release/Python: Template:Latest stable software release/Python (id: ??, ns: 10)
# Template:Programming languages: Template:Programming languages (id: ??, ns: 10)
# Template:Python (programming language): Template:Python (programming language) (id: ??, ns: 10)
# Template:Python web frameworks: Template:Python web frameworks (id: ??, ns: 10)
# TensorFlow: TensorFlow (id: ??, ns: 0)
# The C Programming Language: The C Programming Language (id: ??, ns: 0)
# The Cathedral and the Bazaar: The Cathedral and the Bazaar (id: ??, ns: 0)
# The Document Foundation: The Document Foundation (id: ??, ns: 0)
# The Free Software Definition: The Free Software Definition (id: ??, ns: 0)
# The Inquirer: The Inquirer (id: ??, ns: 0)
# The Open Source Definition: The Open Source Definition (id: ??, ns: 0)
# There is more than one way to do it: There is more than one way to do it (id: ??, ns: 0)
# This (computer programming): This (computer programming) (id: ??, ns: 0)
# Timeline of programming languages: Timeline of programming languages (id: ??, ns: 0)
# Tornado (web server): Tornado (web server) (id: ??, ns: 0)
# Transcompiler: Transcompiler (id: ??, ns: 0)
# Trusted Computing: Trusted Computing (id: ??, ns: 0)
# Tuple: Tuple (id: ??, ns: 0)
# TurboGears: TurboGears (id: ??, ns: 0)
# Twisted (software): Twisted (software) (id: ??, ns: 0)
# Type system: Type system (id: ??, ns: 0)
# TypeScript: TypeScript (id: ??, ns: 0)
# Ubiquity (software): Ubiquity (software) (id: ??, ns: 0)
# Ubuntu (operating system): Ubuntu (operating system) (id: ??, ns: 0)
# Unicode: Unicode (id: ??, ns: 0)
# Unified Extensible Firmware Interface: Unified Extensible Firmware Interface (id: ??, ns: 0)
# Unit test: Unit test (id: ??, ns: 0)
# Unit testing: Unit testing (id: ??, ns: 0)
# Unix shell: Unix shell (id: ??, ns: 0)
# Unix-like: Unix-like (id: ??, ns: 0)
# Unladen Swallow: Unladen Swallow (id: ??, ns: 0)
# Unlicense: Unlicense (id: ??, ns: 0)
# VHDL: VHDL (id: ??, ns: 0)
# Variable (computer science): Variable (computer science) (id: ??, ns: 0)
# Viral license: Viral license (id: ??, ns: 0)
# Virtual machine: Virtual machine (id: ??, ns: 0)
# Visual Basic .NET: Visual Basic .NET (id: ??, ns: 0)
# WTFPL: WTFPL (id: ??, ns: 0)
# Web Server Gateway Interface: Web Server Gateway Interface (id: ??, ns: 0)
# Web application: Web application (id: ??, ns: 0)
# Web browser: Web browser (id: ??, ns: 0)
# Web framework: Web framework (id: ??, ns: 0)
# Web2py: Web2py (id: ??, ns: 0)
# Webware for Python: Webware for Python (id: ??, ns: 0)
# While loop: While loop (id: ??, ns: 0)
# Whitespace character: Whitespace character (id: ??, ns: 0)
# Wikipedia: Wikipedia (id: ??, ns: 0)
# Wikipedia:Good articles: Wikipedia:Good articles (id: ??, ns: 4)
# Wikipedia:WikiProject Software/Free and open-source software task force: Wikipedia:WikiProject Software/Free and open-source software task force (id: ??, ns: 4)
# Wikipedia:Wikimedia sister projects: Wikipedia:Wikimedia sister projects (id: ??, ns: 4)
# Yahoo!: Yahoo! (id: ??, ns: 0)
# Yukihiro Matsumoto: Yukihiro Matsumoto (id: ??, ns: 0)
# Zen of Python: Zen of Python (id: ??, ns: 0)
# Zero-based: Zero-based (id: ??, ns: 0)
# Zlib License: Zlib License (id: ??, ns: 0)
# Zope: Zope (id: ??, ns: 0)

# %%
def print_categories(page):
        categories = page.categories
        for title in sorted(categories.keys()):
            print("%s: %s" % (title, categories[title]))


print("Categories")
print_categories(page_py)
# Category:All articles containing potentially dated statements: ...
# Category:All articles with unsourced statements: ...
# Category:Articles containing potentially dated statements from August 2016: ...
# Category:Articles containing potentially dated statements from March 2017: ...
# Category:Articles containing potentially dated statements from September 2017: ...
# Out:
# Categories
# Category:All articles containing potentially dated statements: Category:All articles containing potentially dated statements (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from August 2016: Category:Articles containing potentially dated statements from August 2016 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from December 2018: Category:Articles containing potentially dated statements from December 2018 (id: ??, ns: 14)
# Category:Articles containing potentially dated statements from March 2018: Category:Articles containing potentially dated statements from March 2018 (id: ??, ns: 14)
# Category:Articles with Curlie links: Category:Articles with Curlie links (id: ??, ns: 14)
# Category:Articles with short description: Category:Articles with short description (id: ??, ns: 14)
# Category:Class-based programming languages: Category:Class-based programming languages (id: ??, ns: 14)
# Category:Computational notebook: Category:Computational notebook (id: ??, ns: 14)
# Category:Computer science in the Netherlands: Category:Computer science in the Netherlands (id: ??, ns: 14)
# Category:Cross-platform free software: Category:Cross-platform free software (id: ??, ns: 14)
# Category:Cross-platform software: Category:Cross-platform software (id: ??, ns: 14)
# Category:Dutch inventions: Category:Dutch inventions (id: ??, ns: 14)
# Category:Dynamically typed programming languages: Category:Dynamically typed programming languages (id: ??, ns: 14)
# Category:Educational programming languages: Category:Educational programming languages (id: ??, ns: 14)
# Category:Good articles: Category:Good articles (id: ??, ns: 14)
# Category:High-level programming languages: Category:High-level programming languages (id: ??, ns: 14)
# Category:Information technology in the Netherlands: Category:Information technology in the Netherlands (id: ??, ns: 14)
# Category:Object-oriented programming languages: Category:Object-oriented programming languages (id: ??, ns: 14)
# Category:Programming languages: Category:Programming languages (id: ??, ns: 14)
# Category:Programming languages created in 1991: Category:Programming languages created in 1991 (id: ??, ns: 14)
# Category:Python (programming language): Category:Python (programming language) (id: ??, ns: 14)
# Category:Scripting languages: Category:Scripting languages (id: ??, ns: 14)
# Category:Text-oriented programming languages: Category:Text-oriented programming languages (id: ??, ns: 14)
# Category:Use dmy dates from August 2015: Category:Use dmy dates from August 2015 (id: ??, ns: 14)
# Category:Wikipedia articles with BNF identifiers: Category:Wikipedia articles with BNF identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with GND identifiers: Category:Wikipedia articles with GND identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with LCCN identifiers: Category:Wikipedia articles with LCCN identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with SUDOC identifiers: Category:Wikipedia articles with SUDOC identifiers (id: ??, ns: 14)

# %%
def print_categorymembers(categorymembers, level=0, max_level=1):
        for c in categorymembers.values():
            print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
            if c.ns == wikipediaapi.Namespace.CATEGORY and level < max_level:
                print_categorymembers(c.categorymembers, level=level + 1, max_level=max_level)


cat = wiki_wiki.page("Category:Physics")
print("Category members: Category:Physics")
print_categorymembers(cat.categorymembers)

# Category members: Category:Physics
# * Statistical mechanics (ns: 0)
# * Category:Physical quantities (ns: 14)
# ** Refractive index (ns: 0)
# ** Vapor quality (ns: 0)
# ** Electric susceptibility (ns: 0)
# ** Specific weight (ns: 0)
# ** Category:Viscosity (ns: 14)
# *** Brookfield Engineering (ns: 0)
# Out:
# Category members: Category:Physics
# *: Physics (ns: 0)
# *: Outline of physics (ns: 0)
# *: Glossary of classical physics (ns: 0)
# *: Portal:Physics (ns: 100)
# *: Action-angle coordinates (ns: 0)
# *: Aerometer (ns: 0)
# *: Bayesian model of computational anatomy (ns: 0)
# *: Group actions in computational anatomy (ns: 0)
# *: Cabbeling (ns: 0)
# *: Camelback potential (ns: 0)
# *: Center of percussion (ns: 0)
# *: Computational anatomy (ns: 0)
# *: Conformon (ns: 0)
# *: Diffeomorphometry (ns: 0)
# *: Diffraction-limited storage ring (ns: 0)
# *: Diffuse field acoustic testing (ns: 0)
# *: Dirac membrane (ns: 0)
# *: Dispersive medium (ns: 0)
# *: Droplet vaporization (ns: 0)
# *: Electron heat capacity (ns: 0)
# *: Elitzur–Vaidman bomb tester (ns: 0)
# *: Energy well (ns: 0)
# *: Farris effect (rheology) (ns: 0)
# *: Front (physics) (ns: 0)
# *: Gapped Hamiltonian (ns: 0)
# *: Gravitationally-interacting massive particles (ns: 0)
# *: Harmonic (ns: 0)
# *: Homeokinetics (ns: 0)
# *: Hopkinson effect (ns: 0)
# *: Infinite derivative gravity (ns: 0)
# *: Interface (matter) (ns: 0)
# *: Jahn–Teller effect (ns: 0)
# *: Large deformation diffeomorphic metric mapping (ns: 0)
# *: Scientific law (ns: 0)
# *: Many-body theory (ns: 0)
# *: Microfluidic cell culture (ns: 0)
# *: Nonlinear frictiophoresis (ns: 0)
# *: Normal contact stiffness (ns: 0)
# *: Northwest Nuclear Consortium (ns: 0)
# *: Parallel force system (ns: 0)
# *: Perpendicular paramagnetic bond (ns: 0)
# *: Phase stretch transform (ns: 0)
# *: Plexciton (ns: 0)
# *: Pseudo Jahn–Teller effect (ns: 0)
# *: Radial basis function interpolation (ns: 0)
# *: Random cluster model (ns: 0)
# *: RAON (ns: 0)
# *: Resistive plate chamber (ns: 0)
# *: Riemannian metric and Lie bracket in computational anatomy (ns: 0)
# *: Rogue wave (ns: 0)
# *: Self-propulsion (ns: 0)
# *: Silicon nanowire (ns: 0)
# *: Solid light (ns: 0)
# *: Solid-state physics (ns: 0)
# *: Spectroscopy of multiply ionized atoms (ns: 0)
# *: Statistical mechanics (ns: 0)
# *: Stochastic thermodynamics (ns: 0)
# *: Straw tracker (ns: 0)
# *: Surface growth (ns: 0)
# *: Total position spread (ns: 0)
# *: Category:Concepts in physics (ns: 14)
# **: 4D vector (ns: 0)
# **: Active and passive transformation (ns: 0)
# **: Ansatz (ns: 0)
# **: Araki–Sucher correction (ns: 0)
# **: Arrow of time (ns: 0)
# **: Asymptotic safety in quantum gravity (ns: 0)
# **: Bell's theorem (ns: 0)
# **: Boltzmann's entropy formula (ns: 0)
# **: Born reciprocity (ns: 0)
# **: Bose–Einstein statistics (ns: 0)
# **: Brownian ratchet (ns: 0)
# **: Canonical transformation (ns: 0)
# **: Capacitance (ns: 0)
# **: Capstan equation (ns: 0)
# **: Cauchy momentum equation (ns: 0)
# **: Causality (ns: 0)
# **: Causality (physics) (ns: 0)
# **: Cherenkov radiation (ns: 0)
# **: Classical fluid (ns: 0)
# **: Classical limit (ns: 0)
# **: Classical mechanics (ns: 0)
# **: Clausius–Mossotti relation (ns: 0)
# **: Clockwise (ns: 0)
# **: Closed system (ns: 0)
# **: Coherence (physics) (ns: 0)
# **: Coherent turbulent structure (ns: 0)
# **: Commutative property (ns: 0)
# **: Composite Higgs models (ns: 0)
# **: Time crystal (ns: 0)
# **: Conservation law (ns: 0)
# **: Contracted Bianchi identities (ns: 0)
# **: Convection (ns: 0)
# **: Cooper pair (ns: 0)
# **: Copenhagen interpretation (ns: 0)
# **: Coulomb gap (ns: 0)
# **: Covariance group (ns: 0)
# **: Covariance principle (ns: 0)
# **: Covariant formulation of classical electromagnetism (ns: 0)
# **: Cross section (physics) (ns: 0)
# **: Current density (ns: 0)
# **: Darwin Lagrangian (ns: 0)
# **: Degenerate semiconductor (ns: 0)
# **: Degrees of freedom (physics and chemistry) (ns: 0)
# **: Density of states (ns: 0)
# **: Diffraction (ns: 0)
# **: Diffraction formalism (ns: 0)
# **: Dimension (ns: 0)
# **: Discrete spectrum (ns: 0)
# **: Dispersion relation (ns: 0)
# **: Einstein's thought experiments (ns: 0)
# **: Elastance (ns: 0)
# **: Electromagnet (ns: 0)
# **: Electromagnetic induction (ns: 0)
# **: Electron equivalent (ns: 0)
# **: Electronic entropy (ns: 0)
# **: Electrostatics (ns: 0)
# **: Elementary particle (ns: 0)
# **: Emission spectrum (ns: 0)
# **: Empty lattice approximation (ns: 0)
# **: Enthalpy (ns: 0)
# **: Entropy (ns: 0)
# **: Configuration entropy (ns: 0)
# **: EPR paradox (ns: 0)
# **: Equation of state (ns: 0)
# **: Equipartition theorem (ns: 0)
# **: Equivalence principle (ns: 0)
# **: Equivalence principle (geometric) (ns: 0)
# **: Ergodic hypothesis (ns: 0)
# **: Euclidean vector (ns: 0)
# **: Euler equations (fluid dynamics) (ns: 0)
# **: Euler's laws of motion (ns: 0)
# **: Ewald–Oseen extinction theorem (ns: 0)
# **: Fermi gas (ns: 0)
# **: Fermi's golden rule (ns: 0)
# **: Fermion (ns: 0)
# **: Feynman diagram (ns: 0)
# **: Field (physics) (ns: 0)
# **: Field effect (semiconductor) (ns: 0)
# **: Fine-structure constant (ns: 0)
# **: First law of thermodynamics (ns: 0)
# **: First observation of gravitational waves (ns: 0)
# **: Flavour (particle physics) (ns: 0)
# **: Flotation of flexible objects (ns: 0)
# **: Four-vector (ns: 0)
# **: Fractional quantum mechanics (ns: 0)
# **: Fractional Schrödinger equation (ns: 0)
# **: Frame-dragging (ns: 0)
# **: Free electron model (ns: 0)
# **: Free neutron decay (ns: 0)
# **: Free particle (ns: 0)
# **: Frustrated triangular lattice (ns: 0)
# **: Introduction to gauge theory (ns: 0)
# **: Generalized Lagrangian mean (ns: 0)
# **: Gibbs free energy (ns: 0)
# **: Ginzburg criterion (ns: 0)
# **: Global mode (ns: 0)
# **: Gravitational singularity (ns: 0)
# **: Green's function (ns: 0)
# **: Green's function number (ns: 0)
# **: Group velocity dispersion (ns: 0)
# **: H-theorem (ns: 0)
# **: Heat (ns: 0)
# **: Heat engine (ns: 0)
# **: Heisenberg cut (ns: 0)
# **: Helmholtz free energy (ns: 0)
# **: Entropic uncertainty (ns: 0)
# **: Homogeneity (physics) (ns: 0)
# **: Hydrodynamic quantum analogs (ns: 0)
# **: Hydrogen atom (ns: 0)
# **: Impulse (physics) (ns: 0)
# **: Instability (ns: 0)
# **: Integral length scale (ns: 0)
# **: Internal energy (ns: 0)
# **: Intrinsic parity (ns: 0)
# **: Invariant (physics) (ns: 0)
# **: Invariant mass (ns: 0)
# **: Ionic conductivity (solid state) (ns: 0)
# **: Kinetic scheme (ns: 0)
# **: Kinetic theory of gases (ns: 0)
# **: Komar superpotential (ns: 0)
# **: Koopman–von Neumann classical mechanics (ns: 0)
# **: Lagrangian mechanics (ns: 0)
# **: Lamb shift (ns: 0)
# **: Legendre transformation (ns: 0)
# **: Leggett inequality (ns: 0)
# **: Length measurement (ns: 0)
# **: Lepton (ns: 0)
# **: Linear response function (ns: 0)
# **: Linear system (ns: 0)
# **: Linearity (ns: 0)
# **: Long-slit spectroscopy (ns: 0)
# **: Lorentz force (ns: 0)
# **: Lorentz scalar (ns: 0)
# **: Lorenz gauge condition (ns: 0)
# **: Macroscopic scale (ns: 0)
# **: Magnetic braking (ns: 0)
# **: Majorana fermion (ns: 0)
# **: Mass versus weight (ns: 0)
# **: Mass-to-charge ratio (ns: 0)
# **: Master equation (ns: 0)
# **: Introduction to the mathematics of general relativity (ns: 0)
# **: Maxwell–Boltzmann statistics (ns: 0)
# **: Maxwell's demon (ns: 0)
# **: List of textbooks in electromagnetism (ns: 0)
# **: Matrix representation of Maxwell's equations (ns: 0)
# **: Maxwell's equations in curved spacetime (ns: 0)
# **: Mean field theory (ns: 0)
# **: Mean inter-particle distance (ns: 0)
# **: Measure (physics) (ns: 0)
# **: Mechanics (ns: 0)
# **: Melting point (ns: 0)
# **: Meter water equivalent (ns: 0)
# **: Metric tensor (ns: 0)
# **: Microscopic scale (ns: 0)
# **: Minkowski space (ns: 0)
# **: Motion (ns: 0)
# **: Navier–Stokes equations (ns: 0)
# **: Negative frequency (ns: 0)
# **: Negative refraction (ns: 0)
# **: Newton's law of cooling (ns: 0)
# **: Newton's laws of motion (ns: 0)
# **: Newton's theorem of revolving orbits (ns: 0)
# **: Newtonian dynamics (ns: 0)
# **: Newtonian motivations for general relativity (ns: 0)
# **: Node (physics) (ns: 0)
# **: Noether's theorem (ns: 0)
# **: Non-contact force (ns: 0)
# **: Non-equilibrium thermodynamics (ns: 0)
# **: Nonlinear system (ns: 0)
# **: Nuclear fusion (ns: 0)
# **: Nuclear physics (ns: 0)
# **: Nuclear reaction (ns: 0)
# **: Observer (physics) (ns: 0)
# **: Observer (quantum physics) (ns: 0)
# **: Observer effect (physics) (ns: 0)
# **: One-electron universe (ns: 0)
# **: Onsager reciprocal relations (ns: 0)
# **: Optogalvanic effect (ns: 0)
# **: Palatini identity (ns: 0)
# **: Paramagnetism (ns: 0)
# **: Parity (physics) (ns: 0)
# **: Partial differential equation (ns: 0)
# **: Partition function (statistical mechanics) (ns: 0)
# **: Path integral formulation (ns: 0)
# **: Pauli exclusion principle (ns: 0)
# **: Permittivity (ns: 0)
# **: Perturbation theory (ns: 0)
# **: Phase (matter) (ns: 0)
# **: Phase space (ns: 0)
# **: Phase transition (ns: 0)
# **: Photon polarization (ns: 0)
# **: Physical information (ns: 0)
# **: Physical object (ns: 0)
# **: Physical theories modified by general relativity (ns: 0)
# **: Physics applications of asymptotically safe gravity (ns: 0)
# **: Plasma (physics) (ns: 0)
# **: Point particle (ns: 0)
# **: Poisson bracket (ns: 0)
# **: Polynomial Wigner–Ville distribution (ns: 0)
# **: Potential gradient (ns: 0)
# **: Potentiometric surface (ns: 0)
# **: Power (physics) (ns: 0)
# **: Pressure (ns: 0)
# **: Principle of covariance (ns: 0)
# **: Principle of least action (ns: 0)
# **: Probability amplitude (ns: 0)
# **: Probability density function (ns: 0)
# **: Probability of occupation (ns: 0)
# **: Pulse (physics) (ns: 0)
# **: QED vacuum (ns: 0)
# **: Quantization (physics) (ns: 0)
# **: Quantum chromodynamics (ns: 0)
# **: Quantum chromodynamics binding energy (ns: 0)
# **: Quantum electrodynamics (ns: 0)
# **: Quantum field theory (ns: 0)
# **: Quantum hadrodynamics (ns: 0)
# **: Quantum mechanics (ns: 0)
# **: Quantum non-equilibrium (ns: 0)
# **: Quantum number (ns: 0)
# **: Quantum potential (ns: 0)
# **: Quantum pseudo-telepathy (ns: 0)
# **: Quantum triviality (ns: 0)
# **: The Quantum Vacuum: An Introduction to Quantum Electrodynamics (ns: 0)
# **: Quasiparticle (ns: 0)
# **: Radiation (ns: 0)
# **: Reflection (physics) (ns: 0)
# **: Refraction (ns: 0)
# **: Regenerative capacitor memory (ns: 0)
# **: Regularization (physics) (ns: 0)
# **: Relation between Schrödinger's equation and the path integral formulation of quantum mechanics (ns: 0)
# **: Relational approach to quantum physics (ns: 0)
# **: Relationship between string theory and quantum field theory (ns: 0)
# **: Relative density (ns: 0)
# **: Relative locality (ns: 0)
# **: Relativistic heat conduction (ns: 0)
# **: Relativistic Lagrangian mechanics (ns: 0)
# **: Renormalization (ns: 0)
# **: Rest (physics) (ns: 0)
# **: Rotational partition function (ns: 0)
# **: Saturation velocity (ns: 0)
# **: Scalar (physics) (ns: 0)
# **: Scale of temperature (ns: 0)
# **: Scattering (ns: 0)
# **: Schrödinger's cat (ns: 0)
# **: Second law of thermodynamics (ns: 0)
# **: Self-organization (ns: 0)
# **: Self-oscillation (ns: 0)
# **: Shear stress (ns: 0)
# **: Sommerfeld expansion (ns: 0)
# **: Spacetime (ns: 0)
# **: Spatial dispersion (ns: 0)
# **: Spatial scale (ns: 0)
# **: Special relativity (ns: 0)
# **: Specific gravity (ns: 0)
# **: Specific properties (ns: 0)
# **: Spectral gap (physics) (ns: 0)
# **: Spectrum (ns: 0)
# **: Speed of light (ns: 0)
# **: Spontaneous emission (ns: 0)
# **: Standard gravity (ns: 0)
# **: Standard Model (ns: 0)
# **: State space (physics) (ns: 0)
# **: Statistical ensemble (mathematical physics) (ns: 0)
# **: Statistical mechanics (ns: 0)
# **: Stimulated emission (ns: 0)
# **: Stochastic thermodynamics (ns: 0)
# **: Strangeness (ns: 0)
# **: String theory (ns: 0)
# **: Strong interaction (ns: 0)
# **: Super Bloch oscillations (ns: 0)
# **: Superconductivity (ns: 0)
# **: Supercooling (ns: 0)
# **: Superfluid helium-4 (ns: 0)
# **: Superfluidity (ns: 0)
# **: Superposition principle (ns: 0)
# **: Supersymmetric theory of stochastic dynamics (ns: 0)
# **: Supersymmetry (ns: 0)
# **: Surface stress (ns: 0)
# **: Symmetry (physics) (ns: 0)
# **: Physical system (ns: 0)
# **: System size expansion (ns: 0)
# **: Sznajd model (ns: 0)
# **: Temperature (ns: 0)
# **: Tensor (ns: 0)
# **: Ternary fission (ns: 0)
# **: Theoretical motivation for general relativity (ns: 0)
# **: Thermal conduction (ns: 0)
# **: Thermal conductivity (ns: 0)
# **: Thermal equilibrium (ns: 0)
# **: Thermodynamic limit (ns: 0)
# **: Thermodynamics (ns: 0)
# **: Thermomass theory (ns: 0)
# **: Thought experiment (ns: 0)
# **: Three-body problem (ns: 0)
# **: Time (ns: 0)
# **: Time dilation (ns: 0)
# **: Time translation symmetry (ns: 0)
# **: Tipping point (physics) (ns: 0)
# **: Transactional interpretation (ns: 0)
# **: Turbulence (ns: 0)
# **: Two-body problem (ns: 0)
# **: Vacuum (ns: 0)
# **: Variable structure system (ns: 0)
# **: Vasiliev equations (ns: 0)
# **: Vector potential (ns: 0)
# **: Vector space (ns: 0)
# **: Virial theorem (ns: 0)
# **: Virtual particle (ns: 0)
# **: Viscous stress tensor (ns: 0)
# **: Volume (thermodynamics) (ns: 0)
# **: Wave equation (ns: 0)
# **: Wave function collapse (ns: 0)
# **: Wavenumber (ns: 0)
# **: Weak interaction (ns: 0)
# **: Wheelbase (ns: 0)
# **: Wigner quasiprobability distribution (ns: 0)
# **: Wigner–Weyl transform (ns: 0)
# **: Work function (ns: 0)
# **: World tube (ns: 0)
# **: Yang–Mills theory (ns: 0)
# **: Zero-point energy (ns: 0)
# **: Category:Entropy (ns: 14)
# **: Category:Physical hypotheses (ns: 14)
# **: Category:Mechanics (ns: 14)
# **: Category:Motion (physics) (ns: 14)
# **: Category:Physical bodies (ns: 14)
# **: Category:Vacuum (ns: 14)
# *: Category:Physics templates (ns: 14)
# **: Template:Conjugate variables (thermodynamics) (ns: 10)
# **: Template:Early science terminology warning (ns: 10)
# **: Template:Einstein summation convention (ns: 10)
# **: Template:Subfields of physics (ns: 10)
# **: Category:Physics infobox templates (ns: 14)
# **: Category:Physics navbox templates (ns: 14)
# **: Category:Physics sidebar templates (ns: 14)
# **: Category:Mechanics templates (ns: 14)
# **: Category:Nuclide templates (ns: 14)
# **: Category:Physical quantities and unit templates (ns: 14)
# **: Category:Physics citation templates (ns: 14)
# **: Category:Physics formatting templates (ns: 14)
# **: Category:Subatomic particle symbol templates (ns: 14)
# **: Category:WikiProject Physics templates (ns: 14)
# **: Category:Physics stub templates (ns: 14)
# *: Category:Subfields of physics (ns: 14)
# **: Branches of physics (ns: 0)
# **: Applied physics (ns: 0)
# **: Atmospheric physics (ns: 0)
# **: Atomic, molecular, and optical physics (ns: 0)
# **: Classical physics (ns: 0)
# **: Computational physics (ns: 0)
# **: Condensed matter physics (ns: 0)
# **: Physics education (ns: 0)
# **: Electromagnetism (ns: 0)
# **: Experimental physics (ns: 0)
# **: Mechanics (ns: 0)
# **: Microphysics (ns: 0)
# **: Modern physics (ns: 0)
# **: Nuclear physics (ns: 0)
# **: Particle physics (ns: 0)
# **: Philosophy of physics (ns: 0)
# **: Physical cosmology (ns: 0)
# **: Physics of financial markets (ns: 0)
# **: Plasma (physics) (ns: 0)
# **: Pseudophysics (ns: 0)
# **: Surface science (ns: 0)
# **: Thermodynamics (ns: 0)
# **: Category:Applied and interdisciplinary physics (ns: 14)
# **: Category:Atomic, molecular, and optical physics (ns: 14)
# **: Category:Cloud and fog physics (ns: 14)
# **: Category:Computational physics (ns: 14)
# **: Category:Condensed matter physics (ns: 14)
# **: Category:Physics education (ns: 14)
# **: Category:Electromagnetism (ns: 14)
# **: Category:Experimental physics (ns: 14)
# **: Category:Mechanics (ns: 14)
# **: Category:Nuclear physics (ns: 14)
# **: Category:Particle physics (ns: 14)
# **: Category:Philosophy of physics (ns: 14)
# **: Category:Physical cosmology (ns: 14)
# **: Category:Plasma physics (ns: 14)
# **: Category:Pseudophysics (ns: 14)
# **: Category:Psychophysics (ns: 14)
# **: Category:Surface science (ns: 14)
# **: Category:Theoretical physics (ns: 14)
# **: Category:Thermodynamics (ns: 14)
# *: Category:Physicists (ns: 14)
# **: Physicist (ns: 0)
# **: Academic genealogy of theoretical physicists (ns: 0)
# **: List of physicists (ns: 0)
# **: Medical physicist (ns: 0)
# **: Klaus Kern (ns: 0)
# **: Category:Physicists by century (ns: 14)
# **: Category:Physicists by field of research (ns: 14)
# **: Category:Physicists by nationality (ns: 14)
# **: Category:Women physicists (ns: 14)
# **: Category:African physicists (ns: 14)
# **: Category:Ancient physicists (ns: 14)
# **: Category:Cultural depictions of physicists (ns: 14)
# **: Category:Physics educators (ns: 14)
# **: Category:Fictional physicists (ns: 14)
# **: Category:Jewish physicists (ns: 14)
# **: Category:Magneticians (ns: 14)
# **: Category:Medical physicists (ns: 14)
# **: Category:Medieval physicists (ns: 14)
# **: Category:Opticians (ns: 14)
# **: Category:Physics award winners (ns: 14)
# **: Category:Physicists who committed suicide (ns: 14)
# **: Category:Tamil physicists (ns: 14)
# **: Category:Wikipedia books on physicists (ns: 14)
# **: Category:Physicist stubs (ns: 14)
# *: Category:Physics awards (ns: 14)
# **: Albert Einstein World Award of Science (ns: 0)
# **: Alexander Hollaender Award in Biophysics (ns: 0)
# **: Alfredo di Braccio Award (ns: 0)
# **: Gregori Aminoff Prize (ns: 0)
# **: Arctowski Medal (ns: 0)
# **: Aryabhata Award (ns: 0)
# **: Batchelor Prize (ns: 0)
# **: Blaise Pascal Chair (ns: 0)
# **: Bogolyubov Prize (ns: 0)
# **: Bogolyubov Prize (NASU) (ns: 0)
# **: Bogolyubov Prize for young scientists (ns: 0)
# **: Niels Bohr International Gold Medal (ns: 0)
# **: Boltzmann Medal (ns: 0)
# **: Ludwig Boltzmann Prize (ns: 0)
# **: Breakthrough Prize in Fundamental Physics (ns: 0)
# **: Harold Brown Award (ns: 0)
# **: CAP-CRM Prize in Theoretical and Mathematical Physics (ns: 0)
# **: Comstock Prize in Physics (ns: 0)
# **: Copley Medal (ns: 0)
# **: Demidov Prize (ns: 0)
# **: Dirac Medal (ns: 0)
# **: Eddington Medal (ns: 0)
# **: Edison Volta Prize (ns: 0)
# **: Einstein Prize for Laser Science (ns: 0)
# **: Albert Einstein Award (ns: 0)
# **: Albert Einstein Medal (ns: 0)
# **: Enrico Fermi Award (ns: 0)
# **: Enrico Fermi Prize (ns: 0)
# **: First Step to Nobel Prize in Physics (ns: 0)
# **: Friedmann Prize (ns: 0)
# **: List of Fritz London Memorial Prizes (ns: 0)
# **: Günther Laukien Prize (ns: 0)
# **: H. C. Ørsted Medal (ns: 0)
# **: Haitinger Prize (ns: 0)
# **: Hector Memorial Medal (ns: 0)
# **: IEEE Heinrich Hertz Medal (ns: 0)
# **: Henri Poincaré Prize (ns: 0)
# **: Hughes Medal (ns: 0)
# **: I. I. Rabi Award (ns: 0)
# **: Infosys Prize (ns: 0)
# **: International Dennis Gabor Award (ns: 0)
# **: J. Robert Oppenheimer Memorial Prize (ns: 0)
# **: Jacques Herbrand Prize (ns: 0)
# **: John Price Wetherill Medal (ns: 0)
# **: John Stewart Bell Prize (ns: 0)
# **: Oskar Klein Memorial Lecture (ns: 0)
# **: Klopsteg Memorial Award (ns: 0)
# **: Klung Wilhelmy Science Award (ns: 0)
# **: Kotcherlakota Rangadhama Rao Memorial Lecture Award (ns: 0)
# **: Kurchatov Medal (ns: 0)
# **: Landau Gold Medal (ns: 0)
# **: Leconte Prize (ns: 0)
# **: Heinz Maier-Leibnitz-Preis (ns: 0)
# **: Lieben Prize (ns: 0)
# **: Lise Meitner Distinguished Lecture (ns: 0)
# **: Lorentz Medal (ns: 0)
# **: Thomas Ranken Lyle Medal (ns: 0)
# **: Matteucci Medal (ns: 0)
# **: Medard W. Welch Award (ns: 0)
# **: Luigi G. Napolitano Award (ns: 0)
# **: National Prize for Exact Sciences (Chile) (ns: 0)
# **: Louis Néel Medal (ns: 0)
# **: Niels Bohr Institute (ns: 0)
# **: Nishina Memorial Prize (ns: 0)
# **: Nobel Prize in Physics (ns: 0)
# **: Giuseppe Occhialini Medal and Prize (ns: 0)
# **: Oersted Medal (ns: 0)
# **: Om Prakash Bhasin Award (ns: 0)
# **: Pawsey Medal (ns: 0)
# **: Peter Mark Memorial award (ns: 0)
# **: Pomeranchuk Prize (ns: 0)
# **: Bruno Pontecorvo Prize (ns: 0)
# **: Ampère Prize (ns: 0)
# **: Rayleigh Medal (ns: 0)
# **: Richtmyer Memorial Award (ns: 0)
# **: Robert A. Millikan award (ns: 0)
# **: Rumford Prize (ns: 0)
# **: Russell Varian Prize (ns: 0)
# **: Rutherford Medal (Royal Society of New Zealand) (ns: 0)
# **: Sackler Prize (ns: 0)
# **: Abdus Salam Award (ns: 0)
# **: Karl Scheel Prize (ns: 0)
# **: Shaw Prize (ns: 0)
# **: Sloan Research Fellowship (ns: 0)
# **: R W B Stephens Medal (ns: 0)
# **: Stern–Gerlach Medal (ns: 0)
# **: Three Physicists Prize (ns: 0)
# **: Tomassoni awards (ns: 0)
# **: Tyndall Medal (ns: 0)
# **: UNESCO Niels Bohr Medal (ns: 0)
# **: VASVIK Industrial Research Award (ns: 0)
# **: Volta Prize (ns: 0)
# **: Walter Boas Medal (ns: 0)
# **: Wigner Medal (ns: 0)
# **: Wolf Prize in Physics (ns: 0)
# **: A B Wood Medal (ns: 0)
# **: Category:Physics awards templates (ns: 14)
# **: Category:Awards of the Acoustical Society of America (ns: 14)
# **: Category:Awards of the American Institute of Physics (ns: 14)
# **: Category:Awards of the American Physical Society (ns: 14)
# **: Category:Awards of the Optical Society (ns: 14)
# **: Category:Awards of the European Physical Society (ns: 14)
# **: Category:Awards of the German Physical Society (ns: 14)
# **: Category:Awards of the Institute of Physics (ns: 14)
# **: Category:Laser awards and associations (ns: 14)
# **: Category:Nobel Prize in Physics (ns: 14)
# **: Category:Physics award winners (ns: 14)
# *: Category:Equations of physics (ns: 14)
# **: Bethe–Salpeter equation (ns: 0)
# **: Boltzmann equation (ns: 0)
# **: Breit equation (ns: 0)
# **: Chandrasekhar's white dwarf equation (ns: 0)
# **: Chrystal's equation (ns: 0)
# **: Constitutive equation (ns: 0)
# **: Convection–diffusion equation (ns: 0)
# **: D'Alembert's equation (ns: 0)
# **: Defining equation (physics) (ns: 0)
# **: Dirac equation in the algebra of physical space (ns: 0)
# **: Einstein field equations (ns: 0)
# **: Einstein–Rosen metric (ns: 0)
# **: Electromagnetic wave equation (ns: 0)
# **: Elliott formula (ns: 0)
# **: Emden–Chandrasekhar equation (ns: 0)
# **: Equations of motion (ns: 0)
# **: Euler's differential equation (ns: 0)
# **: Fresnel equations (ns: 0)
# **: Froissart–Stora equation (ns: 0)
# **: Gordon decomposition (ns: 0)
# **: Klein–Gordon equation (ns: 0)
# **: Landau–Lifshitz–Gilbert equation (ns: 0)
# **: Liouville–Bratu–Gelfand equation (ns: 0)
# **: List of electromagnetism equations (ns: 0)
# **: List of equations in classical mechanics (ns: 0)
# **: List of equations in fluid mechanics (ns: 0)
# **: List of equations in gravitation (ns: 0)
# **: List of equations in nuclear and particle physics (ns: 0)
# **: List of equations in quantum mechanics (ns: 0)
# **: List of equations in wave theory (ns: 0)
# **: List of photonics equations (ns: 0)
# **: List of relativistic equations (ns: 0)
# **: List of textbooks in electromagnetism (ns: 0)
# **: Maxwell's equations (ns: 0)
# **: Microplane model for constitutive laws of materials (ns: 0)
# **: Nahm equations (ns: 0)
# **: Numerical solution of the convection–diffusion equation (ns: 0)
# **: Poisson's equation (ns: 0)
# **: Quadrupole formula (ns: 0)
# **: Quantum KZ equations (ns: 0)
# **: Rarita–Schwinger equation (ns: 0)
# **: Relativistic wave equations (ns: 0)
# **: Semiconductor Bloch equations (ns: 0)
# **: Sine-Gordon equation (ns: 0)
# **: Strange–Rahman–Smith equation (ns: 0)
# **: Thomas–Fermi equation (ns: 0)
# **: Two-body Dirac equations (ns: 0)
# **: Von Foerster equation (ns: 0)
# **: Williams spray equation (ns: 0)
# **: Yang–Baxter equation (ns: 0)
# **: Category:Acoustic equations (ns: 14)
# **: Category:Dirac equation (ns: 14)
# **: Category:Equations of fluid dynamics (ns: 14)
# **: Category:Equations of state (ns: 14)
# **: Category:Maxwell's equations (ns: 14)
# **: Category:Schrödinger equation (ns: 14)
# *: Category:Physics events (ns: 14)
# **: Asian Physics Olympiad (ns: 0)
# **: International Conference of Physics Students (ns: 0)
# **: International Physics Olympiad (ns: 0)
# **: IYPT 2011 (ns: 0)
# **: Poincaré Seminars (ns: 0)
# **: POISK Centre (ns: 0)
# **: Romanian Master of Mathematics and Sciences (ns: 0)
# **: Ukrainian Physicists' Tournament for University Students (ns: 0)
# **: World Year of Physics 2005 (ns: 0)
# **: Category:Physics conferences (ns: 14)
# *: Category:Physics in fiction (ns: 14)
# **: Apergy (ns: 0)
# **: The Big Bang Theory (ns: 0)
# **: Blackhole (video game) (ns: 0)
# **: Calabi-Yau (play) (ns: 0)
# **: Copenhagen (play) (ns: 0)
# **: Dark matter in fiction (ns: 0)
# **: Electrolaser (ns: 0)
# **: Faster-than-light (ns: 0)
# **: Faster-than-light communication (ns: 0)
# **: Force field (fiction) (ns: 0)
# **: Half-Life (video game) (ns: 0)
# **: Holtzman effect (ns: 0)
# **: Hypertime (ns: 0)
# **: Orthogonal (series) (ns: 0)
# **: Os (Fringe) (ns: 0)
# **: Physics and Star Wars (ns: 0)
# **: Portal (video game) (ns: 0)
# **: Portal 2 (ns: 0)
# **: Production and Decay of Strange Particles (ns: 0)
# **: Quantum aesthetics (ns: 0)
# **: Quantum singularity (ns: 0)
# **: Rubber science (ns: 0)
# **: Schrödinger's cat in popular culture (ns: 0)
# **: Schrödinger's Kitten (ns: 0)
# **: Tachyons in fiction (ns: 0)
# **: Technology in Star Trek (ns: 0)
# **: Teleportation in fiction (ns: 0)
# **: Timestream (ns: 0)
# **: Tipler cylinder (ns: 0)
# **: Ultrawave (ns: 0)
# **: Young Sheldon (ns: 0)
# **: Category:Antimatter (ns: 14)
# **: Category:Cartoon physics (ns: 14)
# **: Category:Cultural depictions of physicists (ns: 14)
# **: Category:Fictional dimensions (ns: 14)
# **: Category:Faster-than-light travel in fiction (ns: 14)
# **: Category:Fictional characters by physics or reality manipulation (ns: 14)
# **: Category:Fictional power sources (ns: 14)
# **: Category:Films about physics (ns: 14)
# **: Category:Quantum mechanics in fiction (ns: 14)
# **: Category:Teleportation in fiction (ns: 14)
# **: Category:Time in fiction (ns: 14)
# *: Category:Fringe physics (ns: 14)
# **: Allais effect (ns: 0)
# **: Anti-gravity (ns: 0)
# **: Brilliant Light Power (ns: 0)
# **: Cold fusion (ns: 0)
# **: Constructor theory (ns: 0)
# **: Criticism of the theory of relativity (ns: 0)
# **: Dean drive (ns: 0)
# **: Death ray (ns: 0)
# **: Einstein–Cartan–Evans theory (ns: 0)
# **: Electrogravitics (ns: 0)
# **: Energy Catalyzer (ns: 0)
# **: Gravitational shielding (ns: 0)
# **: Hafnium controversy (ns: 0)
# **: Heim theory (ns: 0)
# **: Burkhard Heim (ns: 0)
# **: Corentin Louis Kervran (ns: 0)
# **: Antonio Longoria (ns: 0)
# **: Magnetospheric eternally collapsing object (ns: 0)
# **: Mass formula (ns: 0)
# **: Matter wave clock (ns: 0)
# **: Harry Grindell Matthews (ns: 0)
# **: Newman's energy machine (ns: 0)
# **: Non-standard cosmology (ns: 0)
# **: Patterson power cell (ns: 0)
# **: Plasma cosmology (ns: 0)
# **: Polarizable vacuum (ns: 0)
# **: Harold E. Puthoff (ns: 0)
# **: Quantized inertia (ns: 0)
# **: Quantum vacuum thruster (ns: 0)
# **: Reactionless drive (ns: 0)
# **: RF resonant cavity thruster (ns: 0)
# **: Jack Sarfatti (ns: 0)
# **: Shaft passer (ns: 0)
# **: Stochastic electrodynamics (ns: 0)
# **: Tired light (ns: 0)
# **: Tractor beam (ns: 0)
# **: U-bit (ns: 0)
# **: United States gravity control propulsion research (ns: 0)
# **: Tom Van Flandern (ns: 0)
# **: Voodoo Science (ns: 0)
# **: George Woodward Warder (ns: 0)
# **: Category:Anti-gravity (ns: 14)
# **: Category:Cold fusion (ns: 14)
# **: Category:Faster-than-light travel (ns: 14)
# **: Category:Perpetual motion (ns: 14)
# **: Category:Pseudophysics (ns: 14)
# **: Category:Teleportation (ns: 14)
# *: Category:Gravity (ns: 14)
# **: Gravity (ns: 0)
# **: Allais effect (ns: 0)
# **: Artificial gravity (ns: 0)
# **: Artificial gravity in fiction (ns: 0)
# **: Barnes–Hut simulation (ns: 0)
# **: Bentley's paradox (ns: 0)
# **: Gravitational binding energy (ns: 0)
# **: Blackett effect (ns: 0)
# **: Cavendish experiment (ns: 0)
# **: Coriolis field (ns: 0)
# **: Timir Datta (ns: 0)
# **: Dropping In Microgravity Environment (ns: 0)
# **: Dynamical dimensional reduction (ns: 0)
# **: Gravity of Earth (ns: 0)
# **: Einstein–Hilbert action (ns: 0)
# **: Electrogravitics (ns: 0)
# **: Equations for a falling body (ns: 0)
# **: Equivalence principle (geometric) (ns: 0)
# **: European Low Gravity Research Association (ns: 0)
# **: Exotic matter (ns: 0)
# **: James E. Faller (ns: 0)
# **: Flyby anomaly (ns: 0)
# **: Free fall (ns: 0)
# **: Gauss's law for gravity (ns: 0)
# **: General covariant transformations (ns: 0)
# **: Introduction to general relativity (ns: 0)
# **: Geomorphology (ns: 0)
# **: Geopotential model (ns: 0)
# **: Graviquake (ns: 0)
# **: Gravitational acceleration (ns: 0)
# **: Gravitational biology (ns: 0)
# **: Gravitational constant (ns: 0)
# **: Gravitational coupling constant (ns: 0)
# **: Gravitational energy (ns: 0)
# **: Gravitational field (ns: 0)
# **: Gravitational instability (ns: 0)
# **: Gravitational interaction of antimatter (ns: 0)
# **: Gravitational potential (ns: 0)
# **: Gravitational-wave astronomy (ns: 0)
# **: Gravitationally-interacting massive particles (ns: 0)
# **: Gravity feed (ns: 0)
# **: Gravity of Mars (ns: 0)
# **: Gravity well (ns: 0)
# **: Gregory–Laflamme instability (ns: 0)
# **: Hypergravity (ns: 0)
# **: Hypotheses non fingo (ns: 0)
# **: Innermost stable circular orbit (ns: 0)
# **: Inspiral (ns: 0)
# **: Intelligent falling (ns: 0)
# **: Laser accelerometer (ns: 0)
# **: Lemaître coordinates (ns: 0)
# **: Lemaître–Tolman metric (ns: 0)
# **: Levitation (ns: 0)
# **: List of equations in gravitation (ns: 0)
# **: Low-g condition (ns: 0)
# **: Lunar theory (ns: 0)
# **: Mach's principle (ns: 0)
# **: Micro-g environment (ns: 0)
# **: Microgravity University (ns: 0)
# **: Gravitation of the Moon (ns: 0)
# **: N-body choreography (ns: 0)
# **: N-body problem (ns: 0)
# **: N-body simulation (ns: 0)
# **: Negative mass (ns: 0)
# **: Painlevé conjecture (ns: 0)
# **: Peres metric (ns: 0)
# **: Physical geodesy (ns: 0)
# **: Potential energy (ns: 0)
# **: Pressuron (ns: 0)
# **: Quadrupole (ns: 0)
# **: Roche limit (ns: 0)
# **: Roche lobe (ns: 0)
# **: Route dependence (ns: 0)
# **: Schiehallion experiment (ns: 0)
# **: Schrödinger–Newton equation (ns: 0)
# **: Self-gravitation (ns: 0)
# **: Shell theorem (ns: 0)
# **: Standard gravity (ns: 0)
# **: Stellar dynamics (ns: 0)
# **: Strong gravity (ns: 0)
# **: Surface gravity (ns: 0)
# **: Tidal force (ns: 0)
# **: Tidal tensor (ns: 0)
# **: Timeline of gravitational physics and relativity (ns: 0)
# **: Gravity train (ns: 0)
# **: Tug of war (astronomy) (ns: 0)
# **: Vertical deflection (ns: 0)
# **: Weightlessness (ns: 0)
# **: Weyl−Lewis−Papapetrou coordinates (ns: 0)
# **: Woodward effect (ns: 0)
# **: World manifold (ns: 0)
# **: Wormhole (ns: 0)
# **: Zero-velocity surface (ns: 0)
# **: Category:Anti-gravity (ns: 14)
# **: Category:Effects of gravitation (ns: 14)
# **: Category:Falling (ns: 14)
# **: Category:Fictional characters with gravity abilities (ns: 14)
# **: Category:Gravimetry (ns: 14)
# **: Category:Gravitational waves (ns: 14)
# **: Category:Gravitational-wave astronomy (ns: 14)
# **: Category:Great Attractor (ns: 14)
# **: Category:Levitation (ns: 14)
# **: Category:Orbits (ns: 14)
# **: Category:Theories of gravitation (ns: 14)
# **: Category:Weightlessness (ns: 14)
# *: Category:History of physics (ns: 14)
# **: History of physics (ns: 0)
# **: Academic genealogy of theoretical physicists (ns: 0)
# **: Aether drag hypothesis (ns: 0)
# **: Annus mirabilis (ns: 0)
# **: Annus Mirabilis papers (ns: 0)
# **: Anti-gravity (ns: 0)
# **: Arago spot (ns: 0)
# **: Archimedean point (ns: 0)
# **: Aristotelian physics (ns: 0)
# **: Atom (Asimov book) (ns: 0)
# **: B Reactor (ns: 0)
# **: Balmer series (ns: 0)
# **: History of the battery (ns: 0)
# **: Beverly Clock (ns: 0)
# **: History of the Big Bang theory (ns: 0)
# **: Bohr–Einstein debates (ns: 0)
# **: Caloric theory (ns: 0)
# **: Charles de Loys (ns: 0)
# **: History of classical mechanics (ns: 0)
# **: Classical unified field theories (ns: 0)
# **: Clockwork universe (ns: 0)
# **: Codex on the Flight of Birds (ns: 0)
# **: Conservation of energy (ns: 0)
# **: Contact electrification (ns: 0)
# **: The Copernican Question (ns: 0)
# **: The Copernican Revolution (book) (ns: 0)
# **: Corpuscular theory of light (ns: 0)
# **: Dark star (Newtonian mechanics) (ns: 0)
# **: De motu corporum in gyrum (ns: 0)
# **: Deutsche Physik (ns: 0)
# **: Dioptrique (ns: 0)
# **: Albert Einstein Archives (ns: 0)
# **: Einstein Papers Project (ns: 0)
# **: Einstein's Blackboard (ns: 0)
# **: Einstein's thought experiments (ns: 0)
# **: History of electromagnetic theory (ns: 0)
# **: Timeline of electromagnetism and classical optics (ns: 0)
# **: Emission theory (ns: 0)
# **: Equation of State Calculations by Fast Computing Machines (ns: 0)
# **: Euler's laws of motion (ns: 0)
# **: European Synchrotron Radiation Facility (ns: 0)
# **: An Experimental Enquiry Concerning the Source of the Heat which is Excited by Friction (ns: 0)
# **: Fermi–Pasta–Ulam–Tsingou problem (ns: 0)
# **: Fresnel equations (ns: 0)
# **: Fresnel rhomb (ns: 0)
# **: Augustin-Jean Fresnel (ns: 0)
# **: History of general relativity (ns: 0)
# **: Golden age of cosmology (ns: 0)
# **: Golden age of physics (ns: 0)
# **: Heisenberg's entryway to matrix mechanics (ns: 0)
# **: History of fluid mechanics (ns: 0)
# **: History of gravitational theory (ns: 0)
# **: History of spectroscopy (ns: 0)
# **: History of string theory (ns: 0)
# **: History of the philosophy of field theory (ns: 0)
# **: Hole argument (ns: 0)
# **: Horologium Oscillatorium (ns: 0)
# **: Horror vacui (physics) (ns: 0)
# **: Hyperradiant Fresnel lens (ns: 0)
# **: Hypotheses non fingo (ns: 0)
# **: The Internet Pilot to Physics (ns: 0)
# **: Kite experiment (ns: 0)
# **: Koenig's manometric flame apparatus (ns: 0)
# **: Le Sage's theory of gravitation (ns: 0)
# **: Leibniz–Clarke correspondence (ns: 0)
# **: Length contraction (ns: 0)
# **: List of important publications in physics (ns: 0)
# **: History of loop quantum gravity (ns: 0)
# **: Lorentz ether theory (ns: 0)
# **: History of Lorentz transformations (ns: 0)
# **: Luminiferous aether (ns: 0)
# **: Raffaello Magiotti (ns: 0)
# **: History of materials science (ns: 0)
# **: Mathematical formulation of quantum mechanics (ns: 0)
# **: History of Maxwell's equations (ns: 0)
# **: Mean speed theorem (ns: 0)
# **: Mechanical equivalent of heat (ns: 0)
# **: Mechanical explanations of gravitation (ns: 0)
# **: Moseley's law (ns: 0)
# **: N ray (ns: 0)
# **: Newton's law of cooling (ns: 0)
# **: Newton's laws of motion (ns: 0)
# **: Newtonian dynamics (ns: 0)
# **: Night Thoughts of a Classical Physicist (ns: 0)
# **: Nordström's theory of gravitation (ns: 0)
# **: Old quantum theory (ns: 0)
# **: On Physical Lines of Force (ns: 0)
# **: Andrew Pritchard (ns: 0)
# **: History of optics (ns: 0)
# **: Oxford Calculators (ns: 0)
# **: Oxford Electric Bell (ns: 0)
# **: History of the periodic table (ns: 0)
# **: The Physical Principles of the Quantum Theory (ns: 0)
# **: Physical Society of London (ns: 0)
# **: Physics in the medieval Islamic world (ns: 0)
# **: Physics outreach (ns: 0)
# **: Pitch drop experiment (ns: 0)
# **: Plane of polarization (ns: 0)
# **: Plum pudding model (ns: 0)
# **: Pound–Rebka experiment (ns: 0)
# **: Principle of least action (ns: 0)
# **: Quaestiones quaedam philosophicae (ns: 0)
# **: History of quantum field theory (ns: 0)
# **: History of quantum mechanics (ns: 0)
# **: Relationship between mathematics and physics (ns: 0)
# **: Criticism of the theory of relativity (ns: 0)
# **: Relativity of simultaneity (ns: 0)
# **: Ritz ballistic theory (ns: 0)
# **: Rubens' tube (ns: 0)
# **: Rutherford model (ns: 0)
# **: Rydberg formula (ns: 0)
# **: History of Solar System formation and evolution hypotheses (ns: 0)
# **: Electromagnetic mass (ns: 0)
# **: History of special relativity (ns: 0)
# **: Speed of gravity (ns: 0)
# **: Spherical wave transformation (ns: 0)
# **: Sticky bead argument (ns: 0)
# **: Stoic physics (ns: 0)
# **: History of subatomic physics (ns: 0)
# **: History of superconductivity (ns: 0)
# **: Teleparallelism (ns: 0)
# **: Teylers Instrument Room (ns: 0)
# **: Theoretical physics (ns: 0)
# **: Timaeus (dialogue) (ns: 0)
# **: Timeline of chemical element discoveries (ns: 0)
# **: Timeline of quantum mechanics (ns: 0)
# **: Total internal reflection (ns: 0)
# **: Transfermium Wars (ns: 0)
# **: Treatise on Light (ns: 0)
# **: Treatise on Radioactivity (ns: 0)
# **: Über quantentheoretische Umdeutung kinematischer und mechanischer Beziehungen (ns: 0)
# **: United States gravity control propulsion research (ns: 0)
# **: Vaiśeṣika Sūtra (ns: 0)
# **: History of variational principles in physics (ns: 0)
# **: The World (Descartes) (ns: 0)
# **: Thomas Young (scientist) (ns: 0)
# **: Young's interference experiment (ns: 0)
# **: Category:Aether theories (ns: 14)
# **: Category:Atomism (ns: 14)
# **: Category:Classical elements (ns: 14)
# **: Category:History of electrical engineering (ns: 14)
# **: Category:Physics experiments (ns: 14)
# **: Category:Foundational quantum physics (ns: 14)
# **: Category:History of thermodynamics (ns: 14)
# **: Category:Physics societies (ns: 14)
# **: Category:Physics timelines (ns: 14)
# *: Category:Interaction (ns: 14)
# **: Interaction (ns: 0)
# **: Action at a distance (ns: 0)
# **: Coupling (physics) (ns: 0)
# **: Coupling constant (ns: 0)
# **: Fifth force (ns: 0)
# **: Fundamental interaction (ns: 0)
# **: Gravitational binding energy (ns: 0)
# **: Interaction energy (ns: 0)
# **: Category:Chemical bonding (ns: 14)
# *: Category:Limits of computation (ns: 14)
# **: Limits of computation (ns: 0)
# **: Bekenstein bound (ns: 0)
# **: Bremermann's limit (ns: 0)
# **: Classical capacity (ns: 0)
# **: Entanglement-assisted classical capacity (ns: 0)
# **: Holevo's theorem (ns: 0)
# **: Landauer's principle (ns: 0)
# **: Lieb-Robinson bounds (ns: 0)
# **: Margolus–Levitin theorem (ns: 0)
# **: No-teleportation theorem (ns: 0)
# **: Quantum capacity (ns: 0)
# **: Transcomputational problem (ns: 0)
# *: Category:Physics-related lists (ns: 14)
# **: Index of physics articles (ns: 0)
# **: Outline of physics (ns: 0)
# **: Academic genealogy of theoretical physicists (ns: 0)
# **: List of accelerators in particle physics (ns: 0)
# **: List of second moments of area (ns: 0)
# **: List of baryons (ns: 0)
# **: List of centroids (ns: 0)
# **: List of common physics notations (ns: 0)
# **: Constant-resistance network (ns: 0)
# **: List of contributors to general relativity (ns: 0)
# **: Contributors to the mathematical background for general relativity (ns: 0)
# **: List of dualities (ns: 0)
# **: List of Foucault pendulums (ns: 0)
# **: List of gravitational wave observations (ns: 0)
# **: List of heliophysics missions (ns: 0)
# **: List of letters used in mathematics and science (ns: 0)
# **: Lists of physics equations (ns: 0)
# **: List of physics journals (ns: 0)
# **: List of mathematical physics journals (ns: 0)
# **: List of mesons (ns: 0)
# **: List of minerals by optical properties (ns: 0)
# **: List of physics mnemonics (ns: 0)
# **: List of moments of inertia (ns: 0)
# **: Optical properties of water and ice (ns: 0)
# **: Index of optics articles (ns: 0)
# **: List of particles (ns: 0)
# **: List of physical quantities (ns: 0)
# **: List of physicists (ns: 0)
# **: List of Slovenian physicists (ns: 0)
# **: List of plasma physicists (ns: 0)
# **: List of plasma physics articles (ns: 0)
# **: List of physics concepts in primary and secondary education curricula (ns: 0)
# **: List of Proton Synchrotron experiments (ns: 0)
# **: List of important publications in physics (ns: 0)
# **: List of quantum-mechanical systems with analytical solutions (ns: 0)
# **: List of quasiparticles (ns: 0)
# **: Index of radiation articles (ns: 0)
# **: List of refractive indices (ns: 0)
# **: List of relativistic equations (ns: 0)
# **: List of scattering experiments (ns: 0)
# **: List of scientific publications by Albert Einstein (ns: 0)
# **: List of scientists whose names are used in physical constants (ns: 0)
# **: Timeline of discovery of Solar System planets and their moons (ns: 0)
# **: List of states of matter (ns: 0)
# **: State of matter (ns: 0)
# **: List of string theory topics (ns: 0)
# **: List of synchrotron radiation facilities (ns: 0)
# **: List of theoretical physicists (ns: 0)
# **: List of thermodynamic properties (ns: 0)
# **: List of unsolved problems in physics (ns: 0)
# **: List of unusual units of measurement (ns: 0)
# **: Category:Indexes of physics articles (ns: 14)
# **: Category:Lists of Solar System objects (ns: 14)
# **: Category:Lists of things named after physicists (ns: 14)
# **: Category:Physics timelines (ns: 14)
# *: Category:Physics literature (ns: 14)
# **: AIP Conference Proceedings (ns: 0)
# **: Bibliography of popular physics concepts (ns: 0)
# **: De Motu Antiquiora (ns: 0)
# **: Einstein's Blackboard (ns: 0)
# **: Landolt–Börnstein (ns: 0)
# **: The Principles of Quantum Mechanics (ns: 0)
# **: Sponsoring Consortium for Open Access Publishing in Particle Physics (ns: 0)
# **: There's Plenty of Room at the Bottom (ns: 0)
# **: Vaiśeṣika Sūtra (ns: 0)
# **: Category:Physics books (ns: 14)
# **: Category:Physics journals (ns: 14)
# **: Category:Physics papers (ns: 14)
# **: Category:Physics magazines (ns: 14)
# **: Category:Physics pamphlets (ns: 14)
# *: Category:Modern physics (ns: 14)
# **: Category:Chaos theory (ns: 14)
# **: Category:Quantum mechanics (ns: 14)
# **: Category:Theory of relativity (ns: 14)
# *: Category:Physics organizations (ns: 14)
# **: American Association of Physics Teachers (ns: 0)
# **: American Institute of Physics (ns: 0)
# **: American Vacuum Society (ns: 0)
# **: Aspera European Astroparticle network (ns: 0)
# **: Breakthrough Prize in Fundamental Physics (ns: 0)
# **: CESRA (ns: 0)
# **: European Solar Physics Division (ns: 0)
# **: Fazia (ns: 0)
# **: Foundational Questions Institute (ns: 0)
# **: Gravitational Wave International Committee (ns: 0)
# **: Health Physics Society (ns: 0)
# **: High Energy Physics Advisory Panel (ns: 0)
# **: HITRAP (ns: 0)
# **: Indian Physical Society (ns: 0)
# **: International Association of Mathematical Physics (ns: 0)
# **: International Association of Physics Students (ns: 0)
# **: International Centre for Theoretical Physics (ns: 0)
# **: International Union of Pure and Applied Physics (ns: 0)
# **: International Young Physicists' Tournament (ns: 0)
# **: Italian Physical Society (ns: 0)
# **: IUPAC/IUPAP Joint Working Party (ns: 0)
# **: Japan Society of Applied Physics (ns: 0)
# **: Malaysian Physics Institute (ns: 0)
# **: Mediterranean Institute of Fundamental Physics (ns: 0)
# **: Midwestern Universities Research Association (ns: 0)
# **: Moore Center for Theoretical Cosmology and Physics (ns: 0)
# **: National Society of Black Physicists (ns: 0)
# **: National Society of Hispanic Physicists (ns: 0)
# **: Particle Physics Project Prioritization Panel (ns: 0)
# **: Physical Society of Japan (ns: 0)
# **: Physics Instructional Resource Association (ns: 0)
# **: POISK Centre (ns: 0)
# **: Potsdam Denkschrift (ns: 0)
# **: Solar Physics Division (ns: 0)
# **: Sponsoring Consortium for Open Access Publishing in Particle Physics (ns: 0)
# **: Swiss Physical Society (ns: 0)
# **: Ukrainian Physicists' Tournament for University Students (ns: 0)
# **: United States Invitational Young Physicists Tournament (ns: 0)
# **: Zhejiang Institute of Modern Physics (ns: 0)
# **: Category:American Association of Physics Teachers (ns: 14)
# **: Category:American Institute of Physics (ns: 14)
# **: Category:Crystallography organizations (ns: 14)
# **: Category:Geophysics organizations (ns: 14)
# **: Category:Health Physics Society (ns: 14)
# **: Category:Physics institutes (ns: 14)
# **: Category:International Young Physicists' Tournament (ns: 14)
# **: Category:Physics laboratories (ns: 14)
# **: Category:Medical physics organizations (ns: 14)
# **: Category:Physics conferences (ns: 14)
# **: Category:Physics departments (ns: 14)
# **: Category:Physics societies (ns: 14)
# **: Category:Physics organization stubs (ns: 14)
# *: Category:Physical phenomena (ns: 14)
# **: Aharonov–Bohm effect (ns: 0)
# **: Aharonov–Casher effect (ns: 0)
# **: Andreev reflection (ns: 0)
# **: Askaryan radiation (ns: 0)
# **: Biefeld–Brown effect (ns: 0)
# **: Breath-figure self-assembly (ns: 0)
# **: Bubble fusion (ns: 0)
# **: Buttered toast phenomenon (ns: 0)
# **: Butterfly effect (ns: 0)
# **: Casimir effect (ns: 0)
# **: Casimir pressure (ns: 0)
# **: Cavitation (ns: 0)
# **: Coandă effect (ns: 0)
# **: Coffee ring effect (ns: 0)
# **: Condensation cloud (ns: 0)
# **: Coriolis force (ns: 0)
# **: Doppler broadening (ns: 0)
# **: Droplet cluster (ns: 0)
# **: Dynamic scaling (ns: 0)
# **: Hanle effect (ns: 0)
# **: Kondo effect (ns: 0)
# **: Latent heat (ns: 0)
# **: Leidenfrost effect (ns: 0)
# **: Liquid slugging (ns: 0)
# **: Marangoni effect (ns: 0)
# **: Mössbauer effect (ns: 0)
# **: Mpemba effect (ns: 0)
# **: Photophoresis (ns: 0)
# **: Physical change (ns: 0)
# **: Piston effect (ns: 0)
# **: Pouillet effect (ns: 0)
# **: Prandtl–Glauert singularity (ns: 0)
# **: Radiation trapping (ns: 0)
# **: Ramsauer–Townsend effect (ns: 0)
# **: Revolving rivers (ns: 0)
# **: Shock diamond (ns: 0)
# **: Shower-curtain effect (ns: 0)
# **: Singing sand (ns: 0)
# **: Singing Sand Dunes (Dunhuang) (ns: 0)
# **: Sonochemical synthesis (ns: 0)
# **: Sonochemistry (ns: 0)
# **: Sonoluminescence (ns: 0)
# **: Stark effect (ns: 0)
# **: Thermo-dielectric effect (ns: 0)
# **: Thermoelectric effect (ns: 0)
# **: Total internal reflection (ns: 0)
# **: Ultraviolet catastrophe (ns: 0)
# **: Upstream contamination (ns: 0)
# **: Water hammer (ns: 0)
# **: Wigner effect (ns: 0)
# **: Zeeman energy (ns: 0)
# **: Category:Doppler effects (ns: 14)
# **: Category:Earth phenomena (ns: 14)
# **: Category:Electrical phenomena (ns: 14)
# **: Category:Hysteresis (ns: 14)
# **: Category:Ionization (ns: 14)
# **: Category:Motion (physics) (ns: 14)
# **: Category:Optical phenomena (ns: 14)
# **: Category:Radiation (ns: 14)
# **: Category:Stellar phenomena (ns: 14)
# **: Category:Transport phenomena (ns: 14)
# **: Category:Waves (ns: 14)
# **: Category:Weather (ns: 14)
# *: Category:Physical properties (ns: 14)
# **: Durability (ns: 0)
# **: Physical change (ns: 0)
# **: Power density (ns: 0)
# **: Residual stress (ns: 0)
# **: Rot-proof (ns: 0)
# **: Rustproofing (ns: 0)
# **: Toughness (ns: 0)
# **: Category:Thermodynamic properties (ns: 14)
# *: Category:Physical quantities (ns: 14)
# **: ANSI/ASA S1.1-2013 (ns: 0)
# **: International System of Quantities (ns: 0)
# **: ISO 31 (ns: 0)
# **: ISO/IEC 80000 (ns: 0)
# **: List of physical quantities (ns: 0)
# **: Physical quantity (ns: 0)
# **: Quantity calculus (ns: 0)
# **: Absorbed dose (ns: 0)
# **: Absorptance (ns: 0)
# **: Acceleration (ns: 0)
# **: Acoustic impedance (ns: 0)
# **: Admittance (ns: 0)
# **: Aggregate modulus (ns: 0)
# **: Amplitude (ns: 0)
# **: Angular acceleration (ns: 0)
# **: Angular diameter distance (ns: 0)
# **: Angular frequency (ns: 0)
# **: Angular momentum (ns: 0)
# **: Angular velocity (ns: 0)
# **: API gravity (ns: 0)
# **: Areal velocity (ns: 0)
# **: Attenuation coefficient (ns: 0)
# **: Audio frequency (ns: 0)
# **: Bollard pull (ns: 0)
# **: Bulk modulus (ns: 0)
# **: Capacitance (ns: 0)
# **: Carcel (ns: 0)
# **: Characteristic admittance (ns: 0)
# **: Characteristic property (ns: 0)
# **: Charge (physics) (ns: 0)
# **: Circular dichroism (ns: 0)
# **: Coercivity (ns: 0)
# **: Cohesion (chemistry) (ns: 0)
# **: Colorimetry (ns: 0)
# **: Comoving and proper distances (ns: 0)
# **: Conductance quantum (ns: 0)
# **: Couple (mechanics) (ns: 0)
# **: Crystallinity (ns: 0)
# **: Cusec (ns: 0)
# **: Defining equation (physics) (ns: 0)
# **: Delta-v (physics) (ns: 0)
# **: Density (ns: 0)
# **: Displacement (fluid) (ns: 0)
# **: Distance measures (cosmology) (ns: 0)
# **: Distance modulus (ns: 0)
# **: Dust resistant (ns: 0)
# **: Dynamic modulus (ns: 0)
# **: Effective dose (radiation) (ns: 0)
# **: Effective radius (ns: 0)
# **: Elastance (ns: 0)
# **: Electric charge (ns: 0)
# **: Electric field (ns: 0)
# **: Electric flux (ns: 0)
# **: Electric potential (ns: 0)
# **: Electric susceptibility (ns: 0)
# **: Electrical measurements (ns: 0)
# **: Electrical mobility (ns: 0)
# **: Electrical resistance (ns: 0)
# **: Electrical resistance and conductance (ns: 0)
# **: Electrical resistivity and conductivity (ns: 0)
# **: Electrochemical gradient (ns: 0)
# **: Electron mobility (ns: 0)
# **: Emissivity (ns: 0)
# **: Energy flux (ns: 0)
# **: Enthalpy (ns: 0)
# **: Equivalent dose (ns: 0)
# **: Etherington's reciprocity theorem (ns: 0)
# **: Excess property (ns: 0)
# **: Fermi acceleration (ns: 0)
# **: Field strength (ns: 0)
# **: Film speed (ns: 0)
# **: Fluence response (ns: 0)
# **: Flux (ns: 0)
# **: Force (ns: 0)
# **: Frequency (ns: 0)
# **: Fuel efficiency (ns: 0)
# **: Ground pressure (ns: 0)
# **: Group velocity (ns: 0)
# **: Heat capacity (ns: 0)
# **: Heat capacity rate (ns: 0)
# **: Heat capacity ratio (ns: 0)
# **: Huber's equation (ns: 0)
# **: Humidity (ns: 0)
# **: Critical relative humidity (ns: 0)
# **: Relative humidity (ns: 0)
# **: Hypervelocity (ns: 0)
# **: Illuminance (ns: 0)
# **: Immittance (ns: 0)
# **: Electrical impedance (ns: 0)
# **: Characteristic impedance (ns: 0)
# **: Impulse (physics) (ns: 0)
# **: Inductance (ns: 0)
# **: Infinitesimal strain theory (ns: 0)
# **: Intensity (physics) (ns: 0)
# **: Intensive and extensive properties (ns: 0)
# **: Ion transport number (ns: 0)
# **: Ionic strength (ns: 0)
# **: Irradiance (ns: 0)
# **: Jerk (physics) (ns: 0)
# **: Jounce (ns: 0)
# **: Length (ns: 0)
# **: List of electromagnetism equations (ns: 0)
# **: List of equations in fluid mechanics (ns: 0)
# **: List of equations in gravitation (ns: 0)
# **: List of equations in nuclear and particle physics (ns: 0)
# **: List of equations in quantum mechanics (ns: 0)
# **: List of equations in wave theory (ns: 0)
# **: List of materials properties (ns: 0)
# **: List of moments of inertia (ns: 0)
# **: List of photonics equations (ns: 0)
# **: Luminance (ns: 0)
# **: Luminosity (ns: 0)
# **: Luminosity distance (ns: 0)
# **: Luminosity function (ns: 0)
# **: Luminous efficacy (ns: 0)
# **: Luminous energy (ns: 0)
# **: Luminous flux (ns: 0)
# **: Luminous intensity (ns: 0)
# **: Magnetic braking (ns: 0)
# ...
# **: Hořava–Lifshitz gravity (ns: 0)
# **: Hořava–Witten domain wall (ns: 0)
# **: Fred Hoyle Medal and Prize (ns: 0)
# **: Hyperchromicity (ns: 0)
# **: HyperPhysics (ns: 0)
# **: Hypertriton (ns: 0)
# **: Hypsochromic shift (ns: 0)
# **: Ideally hard superconductor (ns: 0)
# **: Identity channel (ns: 0)
# **: Impact parameter (ns: 0)
# **: Impedance pump (ns: 0)
# **: Independent electron approximation (ns: 0)
# **: Inertia damper (ns: 0)
# **: Inherent viscosity (ns: 0)
# **: Interface (matter) (ns: 0)
# **: International Congress on Mathematical Physics (ns: 0)
# **: Intracule (ns: 0)
# **: Intrinsic parity (ns: 0)
# **: Inverse scattering problem (ns: 0)
# **: Ion drift meter (ns: 0)
# **: Ionometer (ns: 0)
# **: Ionospheric storm (ns: 0)
# **: Isenthalpic process (ns: 0)
# **: Ishimori equation (ns: 0)
# **: ISO 31-2 (ns: 0)
# **: ISO 31-3 (ns: 0)
# **: ISO 31-4 (ns: 0)
# **: ISO 31-5 (ns: 0)
# **: ISO 31-6 (ns: 0)
# **: ISO 31-7 (ns: 0)
# **: ISO 31-9 (ns: 0)
# **: ISO 31-13 (ns: 0)
# **: Isoenthalpic–isobaric ensemble (ns: 0)
# **: Isopotential map (ns: 0)
# **: Isoscalar (ns: 0)
# **: Isothermal–isobaric ensemble (ns: 0)
# **: Isotropic radiation (ns: 0)
# **: Isovector (ns: 0)
# **: Jeans's theorem (ns: 0)
# **: Jet (fluid) (ns: 0)
# **: Johnsen–Rahbek effect (ns: 0)
# **: Jolly balance (ns: 0)
# **: K-Poincaré algebra (ns: 0)
# **: K-Poincaré group (ns: 0)
# **: Kadowaki–Woods ratio (ns: 0)
# **: Kantowski–Sachs metric (ns: 0)
# **: Kaonium (ns: 0)
# **: Kaplan–Yorke map (ns: 0)
# **: Karatmeter (ns: 0)
# **: KASCADE (ns: 0)
# **: Kelvin–Planck statement (ns: 0)
# **: Kilocalorie per mole (ns: 0)
# **: Kinetic term (ns: 0)
# **: Kirchhoff–Helmholtz integral (ns: 0)
# **: Kleemenko cycle (ns: 0)
# **: Knight shift (ns: 0)
# **: Knudsen force (ns: 0)
# **: Knudsen gas (ns: 0)
# **: Kodama state (ns: 0)
# **: Kohn effect (ns: 0)
# **: König's theorem (kinetics) (ns: 0)
# **: Konishi anomaly (ns: 0)
# **: Kopp's law (ns: 0)
# **: Kramers–Heisenberg formula (ns: 0)
# **: Kramers' law (ns: 0)
# **: Kratos MS 50 (ns: 0)
# **: Laboratory frame of reference (ns: 0)
# **: Lamb–Mössbauer factor (ns: 0)
# **: Land speed (ns: 0)
# **: Landau–Pomeranchuk–Migdal effect (ns: 0)
# **: Langworthy Professor (ns: 0)
# **: Laplace limit (ns: 0)
# **: Large Volume Detector (ns: 0)
# **: LARMOR neutron microscope (ns: 0)
# **: Laser integration line (ns: 0)
# **: Laser printing of single nanoparticles (ns: 0)
# **: Laser-induced incandescence (ns: 0)
# **: Lasing without inversion (ns: 0)
# **: Ledinegg instability (ns: 0)
# **: Leontovich boundary condition (ns: 0)
# **: Les Houches Accords (ns: 0)
# **: Level-spacing distribution (ns: 0)
# **: Light cone gauge (ns: 0)
# **: Light valve (ns: 0)
# **: Lilienfeld radiation (ns: 0)
# **: Liouville–Arnold theorem (ns: 0)
# **: Lippmann electrometer (ns: 0)
# **: Liquid marbles (ns: 0)
# **: Liquid slugging (ns: 0)
# **: Liquid whistle (ns: 0)
# **: Little hierarchy problem (ns: 0)
# **: Localized surface plasmon (ns: 0)
# **: Lyman Laboratory of Physics (ns: 0)
# **: Lyman limit (ns: 0)
# **: Lyman–Werner photons (ns: 0)
# **: M2-brane (ns: 0)
# **: M5-brane (ns: 0)
# **: Macron (physics) (ns: 0)
# **: Macrosonics (ns: 0)
# **: Magnetic dipole transition (ns: 0)
# **: Magnetic energy (ns: 0)
# **: Magnetic field viewing film (ns: 0)
# **: Magnetic form factor (ns: 0)
# **: Magnetic isotope effect (ns: 0)
# **: Magnetic mirror point (ns: 0)
# **: Magnetogastrography (ns: 0)
# **: Magnetogram (ns: 0)
# **: Magnetorheological finishing (ns: 0)
# **: Malter effect (ns: 0)
# **: Manipulation of atoms by optical field (ns: 0)
# **: Many-body theory (ns: 0)
# **: Margolus–Levitin theorem (ns: 0)
# **: MARIACHI (ns: 0)
# **: Mass formula (ns: 0)
# **: Materials testing reactor (ns: 0)
# **: Matrix string theory (ns: 0)
# **: Matthiessen's ratio (ns: 0)
# **: MAX IV Laboratory (ns: 0)
# **: Maximon (particle) (ns: 0)
# **: McLeod gauge (ns: 0)
# **: Mean free time (ns: 0)
# **: Mécanique analytique (ns: 0)
# **: Mechanical impedance (ns: 0)
# **: Lise Meitner Medal and Prize (ns: 0)
# **: Membrane theory of shells (ns: 0)
# **: Meta-operator (ns: 0)
# **: Metallicity distribution function (ns: 0)
# **: Metallizing (ns: 0)
# **: Microbarometer (ns: 0)
# **: Microstate continuum (ns: 0)
# **: Microviscosity (ns: 0)
# **: Microwave spectroscopy (ns: 0)
# **: Middle World (ns: 0)
# **: MinutePhysics (ns: 0)
# **: MIRACL (ns: 0)
# **: Mirror furnace (ns: 0)
# **: Misalignment mechanism (ns: 0)
# **: Mixed dark matter (ns: 0)
# **: Mobile Anisotropy Telescope (ns: 0)
# **: Model building (particle physics) (ns: 0)
# **: Model C stellarator (ns: 0)
# **: Modified pressure (ns: 0)
# **: Modular invariance (ns: 0)
# **: Modulation sphere (ns: 0)
# **: Moisture expansion (ns: 0)
# **: Molecular biophysics (ns: 0)
# **: Molecular Spectra and Molecular Structure IV. Constants of Diatomic Molecules (ns: 0)
# **: The Monkey and the Hunter (ns: 0)
# **: Monopole (mathematics) (ns: 0)
# **: Monster (physics) (ns: 0)
# **: Motion-triggered contact insufficiency (ns: 0)
# **: Mott criterion (ns: 0)
# **: Mott–Bethe formula (ns: 0)
# **: Mu problem (ns: 0)
# **: Multichannel analyzer (ns: 0)
# **: Multiple-emitter transistor (ns: 0)
# **: Multiplet (ns: 0)
# **: Mutual coherence (physics) (ns: 0)
# **: N-body choreography (ns: 0)
# **: N-vector model (ns: 0)
# **: NAMD (ns: 0)
# **: Nanoknife (ns: 0)
# **: Nanomagnet (ns: 0)
# **: Nanomechanical resonator (ns: 0)
# **: Nanoscopic scale (ns: 0)
# **: Narrow bipolar pulse (ns: 0)
# **: Neoclassical transport (ns: 0)
# **: Network automaton (ns: 0)
# **: Neumann's law (ns: 0)
# **: Neutron probe (ns: 0)
# **: Neutron-induced swelling (ns: 0)
# **: Newton second (ns: 0)
# **: Newton–Wigner localization (ns: 0)
# **: Newtonian limit (ns: 0)
# **: Nimrod (synchrotron) (ns: 0)
# **: Nine (purity) (ns: 0)
# **: No-broadcast theorem (ns: 0)
# **: Noise floor (ns: 0)
# **: Non-Gaussianity (ns: 0)
# **: Non-perturbative (ns: 0)
# **: Nonadiabatic transition state theory (ns: 0)
# **: Nonequilibrium partition identity (ns: 0)
# **: Nonlinear X-wave (ns: 0)
# **: Okorokov effect (ns: 0)
# **: Optical force (ns: 0)
# **: Optogalvanic effect (ns: 0)
# **: Orbiting body (ns: 0)
# **: Order operator (ns: 0)
# **: Orders of magnitude (entropy) (ns: 0)
# **: Orientational glass (ns: 0)
# **: Orthobaric density (ns: 0)
# **: Orthometric height (ns: 0)
# **: P-wave modulus (ns: 0)
# **: P3M (ns: 0)
# **: Pair potential (ns: 0)
# **: Pake doublet (ns: 0)
# **: PANDA experiment (ns: 0)
# **: Parabola of safety (ns: 0)
# **: Particle density (particle count) (ns: 0)
# **: Pasotron (ns: 0)
# **: Passive acoustics (ns: 0)
# **: Patch dynamics (physics) (ns: 0)
# **: Peierls bracket (ns: 0)
# **: Peixoto's theorem (ns: 0)
# **: Phantom energy (ns: 0)
# **: Phase conjugation (ns: 0)
# **: Phase distortion (ns: 0)
# **: Phase offset modulation (ns: 0)
# **: Phase switch (ns: 0)
# **: Phosphoroscope (ns: 0)
# **: Phoswich detector (ns: 0)
# **: Photino (ns: 0)
# **: Photo-Carnot engine (ns: 0)
# **: Photoinduced charge separation (ns: 0)
# **: Photoinduced phase transitions (ns: 0)
# **: Photoionisation cross section (ns: 0)
# **: Photoluminescence excitation (ns: 0)
# **: Photomagneton (ns: 0)
# **: Photomechanical effect (ns: 0)
# **: Photon counting (ns: 0)
# **: Photon diffusion (ns: 0)
# **: Photothermal effect (ns: 0)
# **: Physical Review Focus (ns: 0)
# **: Physical system (ns: 0)
# **: Physics and Astronomy Classification Scheme (ns: 0)
# **: Physics of computation (ns: 0)
# **: Picture (string theory) (ns: 0)
# **: Piezoelectric coefficient (ns: 0)
# **: Piola transformation (ns: 0)
# **: Planar array radar (ns: 0)
# **: Planck momentum (ns: 0)
# **: Plumber's nightmare (ns: 0)
# **: Pohlmeyer charge (ns: 0)
# **: Polar metal (ns: 0)
# **: Polarization spectroscopy (ns: 0)
# **: Pole piece (ns: 0)
# **: Pomeranchuk cooling (ns: 0)
# **: Pomeranchuk Prize (ns: 0)
# **: Pomeranchuk's theorem (ns: 0)
# **: Ponderomotive energy (ns: 0)
# **: Pople notation (ns: 0)
# **: Pöschl–Teller potential (ns: 0)
# **: Potential magnetic field (ns: 0)
# **: Power bandwidth (ns: 0)
# **: Power history (ns: 0)
# **: Preferential concentration (ns: 0)
# **: Pressure drop (ns: 0)
# **: Pressure experiment (ns: 0)
# **: Jacqueline Priestman (ns: 0)
# **: Primary constraint (ns: 0)
# **: Primordial isocurvature baryon model (ns: 0)
# **: Princeton Large Torus (ns: 0)
# **: Professor of Natural Philosophy (Glasgow) (ns: 0)
# **: Prompt gamma neutron activation analysis (ns: 0)
# **: Proof mass (ns: 0)
# **: Propagation loss (ns: 0)
# **: Protein Local Optimization Program (ns: 0)
# **: Pseudo-modal energies (ns: 0)
# **: Pseudophysics (ns: 0)
# **: Pulsed field gradient (ns: 0)
# **: Pure shear (ns: 0)
# **: QMAP (ns: 0)
# **: QSO B0839+187 (ns: 0)
# **: Quality (physics) (ns: 0)
# **: Quantum instrument (ns: 0)
# **: Quantum solid (ns: 0)
# **: Quantum solvent (ns: 0)
# **: Quasi-solid (ns: 0)
# **: Quintom scenario (ns: 0)
# **: Quiver diagram (ns: 0)
# **: R-symmetry (ns: 0)
# **: Radian per second (ns: 0)
# **: Radiation effect (ns: 0)
# **: Radiation flux (ns: 0)
# **: Radiation trapping (ns: 0)
# **: Radiative Auger effect (ns: 0)
# **: Radio noise source (ns: 0)
# **: Radio window (ns: 0)
# **: Radio-frequency induction (ns: 0)
# **: Radioisotope piezoelectric generator (ns: 0)
# **: Radiophysics (ns: 0)
# **: Radioscope (ns: 0)
# **: Rate of heat flow (ns: 0)
# **: Rayleigh dissipation function (ns: 0)
# **: Rectilinear propagation (ns: 0)
# **: Recycling antimatter (ns: 0)
# **: Reflectin (ns: 0)
# **: Refraction (sound) (ns: 0)
# **: Rehbinder effect (ns: 0)
# **: Relative angular momentum (ns: 0)
# **: Relative viscosity (ns: 0)
# **: Remission (spectroscopy) (ns: 0)
# **: Repulsive state (ns: 0)
# **: Residual property (physics) (ns: 0)
# **: Resistive skin time (ns: 0)
# **: Reverse diffusion (ns: 0)
# **: Reversible reference system propagation algorithm (ns: 0)
# **: Rheoscope (ns: 0)
# **: Riabouchinsky solid (ns: 0)
# **: Ridley–Watkins–Hilsum theory (ns: 0)
# **: Robinson oscillator (ns: 0)
# **: Robophysics (ns: 0)
# **: Rollin film (ns: 0)
# **: Rotational Brownian motion (ns: 0)
# **: Rotatum (ns: 0)
# **: Rovibronic coupling (ns: 0)
# **: Rutherford cable (ns: 0)
# **: Ruze's equation (ns: 0)
# **: Rydberg–Klein–Rees method (ns: 0)
# **: S-knot (ns: 0)
# **: Saskatoon experiment (ns: 0)
# **: List of scattering experiments (ns: 0)
# **: Scherk–Schwarz mechanism (ns: 0)
# **: Schiller layer (ns: 0)
# **: Schottky anomaly (ns: 0)
# **: Schottky effect (ns: 0)
# **: Schwarzschild criterion (ns: 0)
# **: Searle's bar method (ns: 0)
# **: Selective adsorption (ns: 0)
# **: Self-amplified spontaneous emission (ns: 0)
# **: Self-diffusion (ns: 0)
# **: Self-focusing transducers (ns: 0)
# **: Sepnet (ns: 0)
# **: Sgoldstino (ns: 0)
# **: Shake (unit) (ns: 0)
# **: Shape waves (ns: 0)
# **: Shear strength test (ns: 0)
# **: Shock waves in astrophysics (ns: 0)
# **: Short supermultiplet (ns: 0)
# **: Shortcuts to adiabaticity (ns: 0)
# **: Shortwave radiation (ns: 0)
# **: Siemens cycle (ns: 0)
# **: Signal velocity (ns: 0)
# **: Singleton field (ns: 0)
# **: Sirius (synchrotron light source) (ns: 0)
# **: Sisyphus effect (ns: 0)
# **: Slew-induced distortion (ns: 0)
# **: Slip melting point (ns: 0)
# **: Slosh baffle (ns: 0)
# **: Smith–Purcell effect (ns: 0)
# **: Snowden (physics) (ns: 0)
# **: Softening (ns: 0)
# **: Softening point (ns: 0)
# **: Solid light (ns: 0)
# **: Sommerfeld identity (ns: 0)
# **: Sound particle (ns: 0)
# **: Source field (ns: 0)
# **: SPARC (tokamak) (ns: 0)
# **: Specific force (ns: 0)
# **: Specific kinetic energy (ns: 0)
# **: Specific mechanical energy (ns: 0)
# **: Specific potential energy (ns: 0)
# **: Spectral bands (ns: 0)
# **: Spectral imaging (ns: 0)
# **: Speed prior (ns: 0)
# **: Spherical surface acoustic wave (SAW) sensor (ns: 0)
# **: Spider (polarimeter) (ns: 0)
# **: Spin gapless semiconductor (ns: 0)
# **: Spin geometry (ns: 0)
# **: Spin pumping (ns: 0)
# **: Spin spherical harmonics (ns: 0)
# **: Excitation temperature (ns: 0)
# **: Spin-polarized electron energy loss spectroscopy (ns: 0)
# **: Spinplasmonics (ns: 0)
# **: Spring pendulum (ns: 0)
# **: Spurion (ns: 0)
# **: State space (physics) (ns: 0)
# **: State-universal coupled cluster (ns: 0)
# **: Statistical field theory (ns: 0)
# **: Statistical fluctuations (ns: 0)
# **: Stilb (unit) (ns: 0)
# **: Stochastic quantization (ns: 0)
# **: Stochastic roadmap simulation (ns: 0)
# **: Stokes operators (ns: 0)
# **: Stoletov curve (ns: 0)
# **: Stoletov's law (ns: 0)
# **: Stonyhurst disks (ns: 0)
# **: Strain scanning (ns: 0)
# **: Streaming vibration current (ns: 0)
# **: String background (ns: 0)
# **: String phenomenology (ns: 0)
# **: Strong confinement limit (ns: 0)
# **: Strong gravity (ns: 0)
# **: Structure function (ns: 0)
# **: Submerged specific gravity (ns: 0)
# **: Summing localization (ns: 0)
# **: Sun valve (ns: 0)
# **: Super-Poissonian distribution (ns: 0)
# **: Supercharge (ns: 0)
# **: Superconducting steel (ns: 0)
# **: Superdeformation (ns: 0)
# **: Superferromagnetism (ns: 0)
# **: Superglass (ns: 0)
# **: Superoscillation (ns: 0)
# **: Superprism (ns: 0)
# **: Supersonic fracture (ns: 0)
# **: Superstatistics (ns: 0)
# **: Surface core level shift (ns: 0)
# **: Surface force (ns: 0)
# **: Surface freezing (ns: 0)
# **: Swan band (ns: 0)
# **: Sweet spot (acoustics) (ns: 0)
# **: Synestia (ns: 0)
# **: SYZ conjecture (ns: 0)
# **: T-J model (ns: 0)
# **: Tangent stiffness matrix (ns: 0)
# **: Target strength (ns: 0)
# **: Tendex line (ns: 0)
# **: Terradynamics (ns: 0)
# **: Test theory (ns: 0)
# **: Thermal blooming (ns: 0)
# **: Thermal contact (ns: 0)
# **: Thermal emittance (ns: 0)
# **: Thermal time scale (ns: 0)
# **: Thermal transpiration (ns: 0)
# **: Thermal velocity (ns: 0)
# **: Thouless energy (ns: 0)
# **: Three Physicists Prize (ns: 0)
# **: TianQin (ns: 0)
# **: Tidal circularization (ns: 0)
# **: Time domain electromagnetics (ns: 0)
# **: Tomlinson model (ns: 0)
# **: Topological entropy in physics (ns: 0)
# **: Toroidal Fusion Core Experiment (ns: 0)
# **: TRACE (computer program) (ns: 0)
# **: TRACER (cosmic ray detector) (ns: 0)
# **: Transfer-matrix method (ns: 0)
# **: Transformation theory (quantum mechanics) (ns: 0)
# **: Transient equilibrium (ns: 0)
# **: Transient friction loading (ns: 0)
# **: Transmission line measurement (ns: 0)
# **: Treble (sound) (ns: 0)
# **: Tropospheric wave (ns: 0)
# **: Trouton's ratio (ns: 0)
# **: Tunnel injection (ns: 0)
# **: Turbidimetry (ns: 0)
# **: Turbophoresis (ns: 0)
# **: Twisted sector (ns: 0)
# **: Twistor correspondence (ns: 0)
# **: Twistor string theory (ns: 0)
# **: Type 0 string theory (ns: 0)
# **: U-duality (ns: 0)
# **: Unidirectional coupling (ns: 0)
# **: Unitarity (physics) (ns: 0)
# **: Unitarity gauge (ns: 0)
# **: Universality class (ns: 0)
# **: Unwin Radar (ns: 0)
# **: Vacuum arc (ns: 0)
# **: Vacuum genesis (ns: 0)
# **: Vacuum Rabi oscillation (ns: 0)
# **: Vague torus (ns: 0)
# **: Vanishing Sun model (ns: 0)
# **: Vapour pressure thermometer (ns: 0)
# **: Variational bicomplex (ns: 0)
# **: Vegard's law (ns: 0)
# **: Velocity overshoot (ns: 0)
# **: Vibroscope (ns: 0)
# **: Virgocentric flow (ns: 0)
# **: Virtual black hole (ns: 0)
# **: Viscimetry (ns: 0)
# **: Visible-light photon counter (ns: 0)
# **: VNIR (ns: 0)
# **: Volume operator (ns: 0)
# **: Vortex state (ns: 0)
# **: Weak charge (ns: 0)
# **: Weak gravity conjecture (ns: 0)
# **: Wear (journal) (ns: 0)
# **: Weber bar (ns: 0)
# **: Weissenberg effect (ns: 0)
# **: Werthamer–Helfand–Hohenberg theory (ns: 0)
# **: Wess–Zumino gauge (ns: 0)
# **: Wet electrons (ns: 0)
# **: Weyl transformation (ns: 0)
# **: Wigner–Seitz radius (ns: 0)
# **: Wolff algorithm (ns: 0)
# **: Worldsheet (ns: 0)
# **: X-ray machine (ns: 0)
# **: X-ray magnetic circular dichroism (ns: 0)
# **: X-wave (ns: 0)
# **: XMASS (ns: 0)
# **: Yang–Mills–Higgs equations (ns: 0)
# **: Zero mode (ns: 0)
# **: Zetatron (ns: 0)
# **: Zonal and poloidal (ns: 0)
# **: Category:Atomic, molecular, and optical physics stubs (ns: 14)
# **: Category:Physics book stubs (ns: 14)
# **: Category:Classical mechanics stubs (ns: 14)
# **: Category:Condensed matter stubs (ns: 14)
# **: Category:Electromagnetism stubs (ns: 14)
# **: Category:Geophysics stubs (ns: 14)
# **: Category:Physics journal stubs (ns: 14)
# **: Category:Nuclear and atomic physics stubs (ns: 14)
# **: Category:Optics stubs (ns: 14)
# **: Category:Physics organization stubs (ns: 14)
# **: Category:Particle physics stubs (ns: 14)
# **: Category:Physicist stubs (ns: 14)
# **: Category:Plasma physics stubs (ns: 14)
# **: Category:Quantum physics stubs (ns: 14)
# **: Category:Relativity stubs (ns: 14)
# **: Category:Thermodynamics stubs (ns: 14)
# **: Category:Isotope stubs (ns: 14)
# **: Category:Physics stub templates (ns: 14)

# %%
import wikipediaapi
import sys
wikipediaapi.log.setLevel(level=wikipediaapi.logging.DEBUG)

# Set handler if you use Python in interactive mode
out_hdlr = wikipediaapi.logging.StreamHandler(sys.stderr)
out_hdlr.setFormatter(wikipediaapi.logging.Formatter('%(asctime)s %(message)s'))
out_hdlr.setLevel(wikipediaapi.logging.DEBUG)
wikipediaapi.log.addHandler(out_hdlr)

wiki = wikipediaapi.Wikipedia(language='en')

page_ostrava = wiki.page('Ostrava')
print(page_ostrava.summary)
# logger prints out: Request URL: http://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ostrava&explaintext=1&exsectionformat=wiki
# Out:
# 2019-06-01 13:57:08,059 Request URL: https://en.wikipedia.org/w/api.php?action=query&prop=extracts&titles=Ostrava&explaintext=1&exsectionformat=wiki
# Ostrava (Polish: Ostrawa, German: Ostrau or Mährisch Ostrau) is a city in the north-east of the Czech Republic and is the capital of the Moravian-Silesian Region. It is 15 km (9 mi) from the border with Poland, at the meeting point of four rivers: the Odra, Opava, Ostravice and Lučina. In terms of both population and area Ostrava is the third largest city in the Czech Republic, the second largest city in Moravia, and the largest city in Czech Silesia. It straddles the border of the two historic provinces of Moravia and Silesia. The population is almost 300,000 people. The wider conurbation – which also includes the towns of Bohumín, Doubrava, Havířov, Karviná, Orlová, Petřvald and Rychvald – is home to about 500,000 people, making it the largest urban area in the Czech Republic apart from the capital, Prague.
# Ostrava grew in importance due to its position at the heart of a major coalfield, becoming an important industrial centre. It was previously known as the country's "steel heart" thanks to its status as a coal-mining and metallurgical centre, but since the Velvet Revolution (the fall of communism in 1989) it has undergone radical and far-reaching changes to its economic base. Industries have been thoroughly restructured, and the last coal was mined in the city in 1994. However, remnants of the city's industrial past are visible in the Lower Vítkovice area, a former coal-mining, coke production and ironworks complex in the city centre which retains its historic industrial architecture. Lower Vítkovice has applied for inclusion in the UNESCO World Heritage List.
# Since the 1990s Ostrava has been transformed into a modern cultural city, with numerous theatres, galleries and other cultural facilities. Various cultural and sporting events take place in Ostrava throughout the year, including the Colours of Ostrava music festival, the Janáček May classical music festival, the Summer Shakespeare Festival and NATO Days. Ostrava is home to two public universities: the VŠB-Technical University and the University of Ostrava. In 2014 Ostrava was a European City of Sport. The city co-hosted (with Prague) the IIHF Ice Hockey World Championship in 2004 and 2015.
