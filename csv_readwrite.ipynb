# %%
import csv
import pandas as pd

def from_csv(csv_file):    
    df = pd.read_csv(csv_file)
    return df

def to_csv(csv_file, df):
    df.to_csv(csv_file, index=False)

def read_csv(csv_file):
    with open(csv_file, newline='') as csvfile:
        spamreader = csv.reader(csvfile)   #, delimiter=' ', quotechar='|')
        for row in spamreader:
            print(', '.join(row))
            
def save_csv(csv_file, buffer):
    with open(csv_file, newline='') as csvfile:
        spamwriter = csv.writer(csvfile) #, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        for i,v in enumerate(buffer):
            print(i,v)
            spamwriter.writerow(v)

# %%
csv_file = r"C:\Users\Jean\OneDrive\Bureau\temp20112022.csv"
buffer = from_csv(csv_file)
buffer
# Out:
#       temp
# 0    10.28
# 1     9.92
# 2     9.05
# 3     8.62
# 4     8.56
# ..     ...
# 118  12.14
# 119  12.56
# 120  12.05
# 121  11.50
# 122  11.58
#
# [123 rows x 1 columns]

# %%
list(buffer['temp'])
# Out:
# [10.28000000000003,
#  9.920000000000016,
#  9.050000000000011,
#  8.620000000000005,
#  8.560000000000002,
#  8.480000000000018,
#  7.79000000000002,
#  7.410000000000025,
#  7.700000000000045,
#  7.560000000000002,
#  7.2000000000000455,
#  6.2000000000000455,
#  6.010000000000048,
#  4.860000000000014,
#  4.910000000000025,
#  4.510000000000048,
#  4.770000000000039,
#  4.75,
#  6.090000000000032,
#  6.379999999999996,
#  6.830000000000041,
#  7.510000000000048,
#  7.700000000000045,
#  8.510000000000048,
#  9.350000000000025,
#  9.340000000000032,
#  8.830000000000041,
#  7.970000000000027,
#  7.580000000000041,
#  8.600000000000023,
#  8.03000000000003,
#  8.180000000000007,
#  8.050000000000011,
#  7.680000000000007,
#  6.890000000000043,
#  7.080000000000041,
#  6.600000000000023,
#  6.560000000000002,
#  6.310000000000002,
#  6.090000000000032,
#  6.460000000000036,
#  6.1200000000000045,
#  6.430000000000007,
#  6.830000000000041,
#  7.28000000000003,
#  7.840000000000032,
# ...

# %%
buffer = list(buffer['temp'])
buffer
# Out:
# [10.28000000000003,
#  9.920000000000016,
#  9.050000000000011,
#  8.620000000000005,
#  8.560000000000002,
#  8.480000000000018,
#  7.79000000000002,
#  7.410000000000025,
#  7.700000000000045,
#  7.560000000000002,
#  7.2000000000000455,
#  6.2000000000000455,
#  6.010000000000048,
#  4.860000000000014,
#  4.910000000000025,
#  4.510000000000048,
#  4.770000000000039,
#  4.75,
#  6.090000000000032,
#  6.379999999999996,
#  6.830000000000041,
#  7.510000000000048,
#  7.700000000000045,
#  8.510000000000048,
#  9.350000000000025,
#  9.340000000000032,
#  8.830000000000041,
#  7.970000000000027,
#  7.580000000000041,
#  8.600000000000023,
#  8.03000000000003,
#  8.180000000000007,
#  8.050000000000011,
#  7.680000000000007,
#  6.890000000000043,
#  7.080000000000041,
#  6.600000000000023,
#  6.560000000000002,
#  6.310000000000002,
#  6.090000000000032,
#  6.460000000000036,
#  6.1200000000000045,
#  6.430000000000007,
#  6.830000000000041,
#  7.28000000000003,
#  7.840000000000032,
# ...

# %%
read_csv(csv_file)
# Out:
# temp
# 10.28000000000003
# 9.920000000000016
# 9.050000000000011
# 8.620000000000005
# 8.560000000000002
# 8.480000000000018
# 7.79000000000002
# 7.410000000000025
# 7.700000000000045
# 7.560000000000002
# 7.2000000000000455
# 6.2000000000000455
# 6.010000000000048
# 4.860000000000014
# 4.910000000000025
# 4.510000000000048
# 4.770000000000039
# 4.75
# 6.090000000000032
# 6.379999999999996
# 6.830000000000041
# 7.510000000000048
# 7.700000000000045
# 8.510000000000048
# 9.350000000000025
# 9.340000000000032
# 8.830000000000041
# 7.970000000000027
# 7.580000000000041
# 8.600000000000023
# 8.03000000000003
# 8.180000000000007
# 8.050000000000011
# 7.680000000000007
# 6.890000000000043
# 7.080000000000041
# 6.600000000000023
# 6.560000000000002
# 6.310000000000002
# 6.090000000000032
# 6.460000000000036
# 6.1200000000000045
# 6.430000000000007
# 6.830000000000041
# 7.28000000000003
# 7.840000000000032
# 7.850000000000023
# 7.730000000000018
# 7.420000000000016
# 7.160000000000025
# ...

# %%
csv_file = r"C:\Users\Jean\OneDrive\Bureau\temp20112022_new.csv"
save_csv(csv_file, buffer)
# Out:
# 0 10.28000000000003
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# c:\Users\Jean\Documents\Python\jupyter\csv_readwrite.ipynb Cell 6 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Jean/Documents/Python/jupyter/csv_readwrite.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> csv_file = r"C:\Users\Jean\OneDrive\Bureau\temp20112022_new.csv"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Jean/Documents/Python/jupyter/csv_readwrite.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> save_csv(csv_file, buffer)
#
# c:\Users\Jean\Documents\Python\jupyter\csv_readwrite.ipynb Cell 6 in save_csv(csv_file, buffer)
#      <a href='vscode-notebook-cell:/c%3A/Users/Jean/Documents/Python/jupyter/csv_readwrite.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> for i,v in enumerate(buffer):
# ...
