# %%
def time2watt(t):  # t en seconde
    return 60/t

# %%
def time2kWh(t):
    return 60/t*60/1000

# %%
import numpy as np
x = np.linspace(0.5,60,100)
x
# Out:
# array([ 0.5       ,  1.1010101 ,  1.7020202 ,  2.3030303 ,  2.9040404 ,
#         3.50505051,  4.10606061,  4.70707071,  5.30808081,  5.90909091,
#         6.51010101,  7.11111111,  7.71212121,  8.31313131,  8.91414141,
#         9.51515152, 10.11616162, 10.71717172, 11.31818182, 11.91919192,
#        12.52020202, 13.12121212, 13.72222222, 14.32323232, 14.92424242,
#        15.52525253, 16.12626263, 16.72727273, 17.32828283, 17.92929293,
#        18.53030303, 19.13131313, 19.73232323, 20.33333333, 20.93434343,
#        21.53535354, 22.13636364, 22.73737374, 23.33838384, 23.93939394,
#        24.54040404, 25.14141414, 25.74242424, 26.34343434, 26.94444444,
#        27.54545455, 28.14646465, 28.74747475, 29.34848485, 29.94949495,
#        30.55050505, 31.15151515, 31.75252525, 32.35353535, 32.95454545,
#        33.55555556, 34.15656566, 34.75757576, 35.35858586, 35.95959596,
#        36.56060606, 37.16161616, 37.76262626, 38.36363636, 38.96464646,
# ...

# %%
print(time2watt(x))
# Out:
# [120.          54.49541284  35.25222552  26.05263158  20.66086957
#   17.11815562  14.61254613  12.74678112  11.30352046  10.15384615
#    9.21644686   8.4375       7.77996071   7.21749696   6.73087819
#    6.30573248   5.93110334   5.59849199   5.30120482   5.03389831
#    4.79225494   4.57274827   4.37246964   4.18899859   4.02030457
#    3.86467144   3.7206389    3.58695652   3.46254736   3.34647887
#    3.23793949   3.13621964   3.04069619   2.95081967   2.86610374
#    2.78611632   2.71047228   2.63882719   2.57087211   2.50632911
#    2.44494752   2.3865006    2.33078281   2.27760736   2.22680412
#    2.17821782   2.13170644   2.08713985   2.04439855   2.00337268
#    1.96396099   1.92607004   1.88961349   1.8545114    1.82068966
#    1.78807947   1.75661689   1.72624237   1.69690044   1.66853933
#    1.64111065   1.61456918   1.58887254   1.56398104   1.53985742
#    1.51646668   1.49377593   1.47175421   1.45037236   1.42960289
# ...

# %%
print(time2kWh(x))
# Out:
# [7.2        3.26972477 2.11513353 1.56315789 1.23965217 1.02708934
#  0.87675277 0.76480687 0.67821123 0.60923077 0.55298681 0.50625
#  0.46679764 0.43304982 0.40385269 0.37834395 0.3558662  0.33590952
#  0.31807229 0.3020339  0.2875353  0.2743649  0.26234818 0.25133992
#  0.24121827 0.23188029 0.22323833 0.21521739 0.20775284 0.20078873
#  0.19427637 0.18817318 0.18244177 0.17704918 0.17196622 0.16716698
#  0.16262834 0.15832963 0.15425233 0.15037975 0.14669685 0.14319004
#  0.13984697 0.13665644 0.13360825 0.13069307 0.12790239 0.12522839
#  0.12266391 0.12020236 0.11783766 0.1155642  0.11337681 0.11127068
#  0.10924138 0.10728477 0.10539701 0.10357454 0.10181403 0.10011236
#  0.09846664 0.09687415 0.09533235 0.09383886 0.09239145 0.090988
#  0.08962656 0.08830525 0.08702234 0.08577617 0.08456519 0.08338793
#  0.08224299 0.08112907 0.08004492 0.07898936 0.07796128 0.07695962
#  0.07598337 0.07503158 0.07410334 0.07319778 0.07231409 0.07145148
# ...
